# %% [markdown]
# ## Importation des données

# %% [markdown]
# Après avoir tenter d'essayer d'identifier les entreprises dans les textes originaux, nous nous sommes confronté à de nombreux problèmes. Suite à cela, et avec l'accord de notre encadrant Stat_app, nous avons fait le choix d'introduire le nom de certaines entreprises dans les articles originaux. Ce notebook vise à appliquer cette démarche

# %%
import pandas as pd

# %%
# Charger à partir du fichier pickle
data = pd.read_pickle('data.pkl')
data.head(5)
# Out:
#                                              Article              Date  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...  31 December 2023
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...  31 December 2023
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...  31 December 2023
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...  31 December 2023
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# ## Nettoyage des articles

# %% [markdown]
# Maintenant que nous avons les informations sur le texte (Date, Auteur, Nombre de mots etc...) Nous pouvons nous permettre de ne garder uniquement le coeur de l'article :

# %%
data.insert(1, 'Copy_Article', data['Article'])
data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                         Copy_Article              Date  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...  31 December 2023
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...  31 December 2023
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...  31 December 2023
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...  31 December 2023
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# Dans un premier temps, on supprime l'ID de l'article, qui se situe à la fin du texte

# %%
import re

# Fonction pour supprimer le texte après le motif spécifié
def supprimer_texte_apres_motif(article, motifs):
    motif = "|".join(motifs)  # Concaténer les motifs en une seule chaîne de caractères
    match = re.search(motif, article)
    if match:
        return article[:match.start()]
    else:
        return article

# Appliquer la fonction supprimer_texte_apres_motif à la colonne 'Coeur_Article' avec une liste de motifs
data['Copy_Article'] = data['Copy_Article'].apply(lambda x: supprimer_texte_apres_motif(x, ["Document J\d+", "Document NYTF\d+"]))

# %% [markdown]
# Vérification :

# %%
for i in range(1,5):
    print("Derniers caractères du", f"text_{i}", "avant suppression\n\n", data['Article'][i][-50:-1])
    print("Derniers caractères du", f"text_{i}", "après suppression\n\n", data['Copy_Article'][i][-50:-1])
    print("-----------------------------------------------------------------------------")
# Out:
# Derniers caractères du text_1 avant suppression
#
#  M21, MM22.
#
# Document NYTF000020231231ejcv0006h
#
#
# Derniers caractères du text_1 après suppression
#
#  cle appeared in print on page MM20, MM21, MM22.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_2 avant suppression
#
#  K4, MK5.
#
# Document NYTF000020231231ejcv00064
#
#
#
# Derniers caractères du text_2 après suppression
#
#  his article appeared in print on page MK4, MK5.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_3 avant suppression
#
#  age MK3.
#
# Document NYTF000020231231ejcv00063
#
#
#
# Derniers caractères du text_3 après suppression
#
#  o.
#
# This article appeared in print on page MK3.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_4 avant suppression
#
#  ge MK11.
#
# Document NYTF000020231231ejcv0005z
#
#
#
# Derniers caractères du text_4 après suppression
#
#  Š
#
# This article appeared in print on page MK11.
#
# -----------------------------------------------------------------------------

# %% [markdown]
# On supprime maintenant tout ce qui est placé avant "All Rights Reserved.", qui correspond à la partie d'information du texte (Auteur etc...)

# %%
# Fonction pour supprimer le texte après le motif spécifié
def supprimer_texte_avant_motif(article, motif):
    match = re.search(motif, article)
    if match:
        return article[match.end():]
    else:
        return article

# Appliquer la fonction supprimer_texte_apres_motif à la colonne 'Coeur_Article' avec une liste de motifs
data['Copy_Article'] = data['Copy_Article'].apply(lambda x: supprimer_texte_avant_motif(x, "All Rights Reserved."))

# %% [markdown]
# Vérification :

# %%
for i in range(1,3):
    print("Derniers caractères du", f"text_{i}", "avant suppression\n\n", data['Article'][i][0:100],"\n\n\n")
    print("Derniers caractères du", f"text_{i}", "après suppression\n\n", data['Copy_Article'][i][0:100])
    print("-----------------------------------------------------------------------------")
# Out:
# Derniers caractères du text_1 avant suppression
#
#
#
# Magazine Desk; SECTMM
# When Jim Brown and Raquel Welch, Two Sexy Stars, Crossed Paths
#
# By Wesley Mo
#
#
#
# Derniers caractères du text_1 après suppression
#
#
#
# In their one movie together, their chemistry was radical.
#
# Jim Brown & Raquel Welch B. 1936 and 1
# -----------------------------------------------------------------------------
# Derniers caractères du text_2 avant suppression
#
#
#
# Magazine Desk; SECTMK
# Talking During Movies: Totally Evil or Part of the Fun?
#
# 179 words
# 31 Decemb
#
#
#
# Derniers caractères du text_2 après suppression
#
#
#
# debatethis
#
# Talking during movies: Totally evil or part of the fun?
#
# show of hands
#
# The biggest p
# -----------------------------------------------------------------------------

# %%
data.rename(columns={'Copy_Article': 'Coeur_Article'}, inplace=True)
data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# ## Modification des articles

# %% [markdown]
# ### Fonction d'insertion de chaines de charactères dans un article

# %%
import random

def insertion_phrase_dans_article(phrase, article):
    # Trouver tous les emplacements des points dans l'article
    emplacements_points = [i for i, char in enumerate(article) if char == '.']

    # Vérifier s'il y a des points dans l'article
    if emplacements_points:
        # Choisir aléatoirement l'un des emplacements des points
        indice_insertion = random.choice(emplacements_points)
        # Insérer la phrase juste après le point choisi
        article = article[:indice_insertion+1] + " " + phrase + article[indice_insertion+1:]
    else:
        # S'il n'y a pas de point, insérer la phrase au début de l'article
        article = phrase + " " + article
    return article

# %% [markdown]
# Vérification :

# %%
phrase_a_inserer = "AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA."
article_insertion = data['Coeur_Article'][3]
article_insertion = insertion_phrase_dans_article(phrase_a_inserer, article_insertion)

# Afficher l'article avec la phrase insérée
print(article_insertion)
# Out:
#
#
# LET KIDS
#
# VOTE!
#
# by Katherine Cusumano
#
# Julia Rottenberg, 17, spent the fall of last year knocking on doors. On Election Day 2022, people in Culver City, Calif., her hometown, would have a big decision to make: Should the voting age for local elections change from 18 to 16? Julia wanted them to vote yes. ''I think a vote is one of the most direct ways that you can express an opinion and actually have some change happen,'' says Julia, who is part of an organization called Vote16 Culver City.
#
# What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources. Yes, young people are already leading political movements around these issues. AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA. But without the vote, they can't elect politicians who represent their views and make real change. ''There's a whole lot of talk about prioritizing young people and politicians saying, 'We care about your future,''' says Jessie Cai, 16, a teen organizer with Voters of Tomorrow in Maryland. Voting would be a way to hold them to their promises.
#
# In some places, the change is already underway. In the past 10 years, residents in a handful of American towns (a few in Maryland, one in Vermont and two in California) have all approved lowering the voting age to 16 in local elections. Teenagers are campaigning to do the same in states from New Jersey to Oregon. A member of Congress has even been pushing to change the federal voting age. And if you think the whole idea seems too out there, think about this: It used to be that you actually had to be 21 to vote. But during the Vietnam War, lots of people argued that if 18-year-olds were being forced to fight, they should also be able to vote. So in 1971, the age was lowered.
#
# Still, not everyone thinks 16-year-olds are ready for the responsibility -- including the voters in Culver City, where the measure lost by just 16 votes. ''I would be lying if I said it wasn't a little bit frustrating,'' Julia says. But the fact that the loss was so narrow has just made her and other Vote16 teenagers more motivated to try again this year: ''It proves to me how much each individual voice matters.'' â—Š
#
# *Thank you to the following schools: Holmes Elementary in Spokane, Wash.; Johnsontown Road Elementary in Louisville, Ky.; Frank D. Spaziano Elementary in Providence, R.I.; and Jefferson Elementary in San Diego.
#
# This article appeared in print on page MK3.

# %% [markdown]
# ### Méthode 1 :

# %% [markdown]
# Dans cette méthode, on utilise le dictionnaire environnemental anglais, à partir duquel on créer un série de phrases à trou. Chaque phrases sera aléatoirement rempli par le nom d'entreprises, ainsi que des termes du dictionnaires. On pourra retrouver des phrases au sentiment positif, négatif, ou neutre d'un point de vue environnemental. Pour chaque entreprise, on génère un nombre aléatoire de phrases la concernant. Toutes ces phrases (ne traitant que d'une seule entreprise) sont ensuite insérés dans un seul et unique article. Ainsi : 1 Article = 1 entreprise identifiée.

# %% [markdown]
# #### Création des phrases à insérer

# %%
Dico_env_en = {
    
    "clean": 1,
    "ecological": 1,
    "sustainable": 1,
    "green": 1,
    "energy-efficient": 1,
    "renewable": 1,
    "responsible": 1,
    "conservation": 1,
    "biodiversity": 1,
    "healthy": 1,
    "organic": 1,
    "eco-friendly": 1,
    "environmentally friendly": 1,
    "efficient": 1,
    "innovative": 1,
    "ethical": 1,
    "fair": 1,
    "efficiency": 1,
    "social responsibility": 1,
    "sustainable": 1,
    "solidarity": 1,
    "conscious spreading": 1,
    "sustainable": 1,
    "clean energy": 1,
    "renewable energy": 1,
    "recycling": 1,
    "energy efficiency": 1,
    "circular economy": 1,
    "solar energy": 1,
    "wind energy": 1,
    "regeneration": 1,
    "preservation": 1,
    "restoration": 1,
    "rehabilitation": 1,
    "recovery": 1,
    "restorer": 1,
    "regenerator": 1,
    "revitalization": 1,
    "positive": 1,
    "beneficial": 1,
    "valorization": 1,
    "fulfillment": 1,
    "continuous improvement": 1,
    "prosperity": 1,
    "harmony": 1,
    "integrity": 1,
    "responsible consumption": 1,
    "eco-responsible": 1,
    "eco-conscious": 1,
    "sustainability": 1,
    "recoverable": 1,
    "green energy": 1,
    "greenhouse effect": 1,
    "eco-efficient": 1,
    "eco-innovation": 1,
    "well-being": 1,
    "eco-design": 1,
    "agroecology": 1,
    "permaculture": 1,
    "eco-citizen": 1,
    "carbon neutral": 1,
    "zero waste": 1,
    "organic": 1,
    "eco-label": 1,
    "sustainable mobility": 1,
    "eco-tourism": 1,
    "eco-habitat": 1,
    "conscious consumption": 1,
    
    "pollution": -1,
    "waste": -1,
    "deforestation": -1,
    "greenhouse gas emissions": -1,
    "contamination": -1,
    "destructive": -1,
    "irresponsible": -1,
    "wasteful": -1,
    "harmful": -1,
    "toxic": -1,
    "deterioration": -1,
    "degradation": -1,
    "damaging": -1,
    "harmful": -1,
    "perilous": -1,
    "worrisome": -1,
    "catastrophic": -1,
    "catastrophe": -1,
    "dangerous": -1,
    "threat": -1,
    "risk": -1,
    "hazardous": -1,
    "harmful": -1,
    "inappropriate": -1,
    "inadequate": -1,
    "inappropriate": -1,
    "harm": -1,
    "damage": -1,
    "pollutant": -1,
    "pollute": -1,
    "deteriorate": -1,
    "disruption": -1,
    "disrespectful": -1,
    "malevolent": -1,
    "damage": -1,
    "aggressive": -1,
    "ravager": -1,
    "spoil": -1,
    "disturb": -1,
    "damage": -1,
    "irreparable": -1,
    "toxicity": -1,
    "unacceptable": -1,
    "ecological damage": -1,
    "illegal logging": -1,
    "overconsumption": -1,
    "resource plundering": -1,
    "environmental degradation": -1,
    "destroyed natural habitat": -1,
    "excessive exploitation": -1,
    "overexploitation": -1,
    "climate change": -1,
    "environmental denial": -1,
}

negation_list = ["not", "no", "never", "none", "nil", "nothing", "nobody", "negative", "without", "more", "less"]

negation_cancellation_list = ["responsible", "originally", "source"]

# %%
import pandas as pd
import random

# Listes de structures de phrases
def generate_positive_structures(company, positive_terms):
    return [
        f"The company {company} is committed to a {random.choice(positive_terms)[0]} approach to promote {random.choice(positive_terms)[0]}.",
        f"Thanks to its {random.choice(positive_terms)[0]} initiative, {company} strengthens its commitment to {random.choice(positive_terms)[0]}.",
        f"{company} implements {random.choice(positive_terms)[0]} practices to support {random.choice(positive_terms)[0]}.",
        f"As a {random.choice(positive_terms)[0]} company, {company} takes measures to encourage {random.choice(positive_terms)[0]}.",
        f"{company} communicates about its {random.choice(positive_terms)[0]} commitment and its positive contribution to {random.choice(positive_terms)[0]}.",
        f"{company} is recognized for its {random.choice(positive_terms)[0]} approach and its positive impact on {random.choice(positive_terms)[0]}.",
        f"Through its {random.choice(positive_terms)[0]} actions, {company} aims to improve {random.choice(positive_terms)[0]}.",
        f"{company} adopts a {random.choice(positive_terms)[0]} strategy to promote {random.choice(positive_terms)[0]}.",
        f"The {random.choice(positive_terms)[0]} approach of {company} reflects its commitment to {random.choice(positive_terms)[0]}.",
        f"{company} values its {random.choice(positive_terms)[0]} commitment and its respect for {random.choice(positive_terms)[0]}."
    ]

def generate_negative_structures(company, negative_terms):
    return [
        f"The company {company} is criticized for its lack of commitment to {random.choice(negative_terms)[0]}.",
        f"{company} is singled out for its {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(negative_terms)[0]} practices have raised concerns among environmentalists.",
        f"{company} faces scrutiny for its {random.choice(negative_terms)[0]} approach.",
        f"Some question {company}'s commitment due to its {random.choice(negative_terms)[0]}.",
        f"{company} is under fire for its {random.choice(negative_terms)[0]} strategy.",
        f"Concerns are raised about {company}'s {random.choice(negative_terms)[0]} practices.",
        f"{company} is criticized for its failure to address {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(negative_terms)[0]} initiative is viewed with skepticism.",
        f"{company} is blamed for its {random.choice(negative_terms)[0]} impact."
    ]

def generate_mixed_structures(company, positive_terms, negative_terms):
    return [
        f"{company} is exploring {random.choice(positive_terms)[0]} initiatives to address {random.choice(negative_terms)[0]}.",
        f"The company {company} is researching {random.choice(positive_terms)[0]} solutions for {random.choice(negative_terms)[0]}.",
        f"{company} is developing {random.choice(positive_terms)[0]} practices while managing {random.choice(negative_terms)[0]}.",
        f"The approach of {company} involves {random.choice(positive_terms)[0]} methods to mitigate {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(positive_terms)[0]} efforts are focused on {random.choice(negative_terms)[0]}.",
        f"{company} is committed to {random.choice(positive_terms)[0]} actions and addressing {random.choice(negative_terms)[0]}.",
        f"{company} integrates {random.choice(positive_terms)[0]} strategies with {random.choice(negative_terms)[0]} management.",
        f"The company {company} emphasizes {random.choice(positive_terms)[0]} practices alongside {random.choice(negative_terms)[0]}.",
        f"{company} implements {random.choice(positive_terms)[0]} measures while considering {random.choice(negative_terms)[0]}.",
        f"{company} is dedicated to {random.choice(positive_terms)[0]} approaches and {random.choice(negative_terms)[0]} initiatives."
    ]


# Fonction pour gérer les termes de négation
def handle_negation(term, score):
    if term in negation_list:
        return -score
    elif term in negation_cancellation_list:
        return 0
    else:
        return score

# Fonction pour générer une phrase sur la communication environnementale d'une entreprise
def generate_environmental_communication(company_list, env_dict, a, b):
    positive_terms = [(term, score) for term, score in env_dict.items() if score == 1]
    negative_terms = [(term, score) for term, score in env_dict.items() if score == -1]
    
    company_sentences = {}  # Dictionnaire pour regrouper les phrases par entreprise
    
    for company in company_list:
        num_sentences = random.randint(a, b)
        sentences = []
        
        for _ in range(num_sentences):
            if random.choice([True, False]):
                structures = generate_positive_structures(company, positive_terms)
            else:
                if negative_terms:
                    structures = generate_negative_structures(company, negative_terms) + generate_mixed_structures(company, positive_terms, negative_terms)
                else:
                    structures = generate_positive_structures(company, positive_terms) + generate_mixed_structures(company, positive_terms, negative_terms)

            sentence = random.choice(structures)
            
            # Gérer les termes de négation dans la phrase
            sentence_words = sentence.split()
            for i, word in enumerate(sentence_words):
                if word.lower() in [term.lower() for term, _ in positive_terms + negative_terms]:
                    original_score = next((score for term, score in positive_terms + negative_terms if term.lower() == word.lower()), None)
                    if original_score:
                        new_score = handle_negation(word.lower(), original_score)
                        if new_score != original_score:
                            replacement = next((term for term, score in env_dict.items() if score == new_score), None)
                            if replacement:
                                sentence_words[i] = replacement

            # Reconstruire la phrase modifiée
            modified_sentence = ' '.join(sentence_words)
            sentences.append(modified_sentence)
        
        company_sentences[company] = sentences
    
    return company_sentences

# %% [markdown]
# # On ne choisit que les entreprises qui ont un score de controverse non nul à partir de 2009, pour cela :

# %% [markdown]
# ## Importation des données

# %%
# !pip install openpyxl
import openpyxl

CON_E = pd.read_excel('CON_E.xlsx', engine='openpyxl')
CON_E.head()
# Out:
# Requirement already satisfied: openpyxl in /opt/mamba/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.11/site-packages (from openpyxl) (1.1.0)
#    idEntreprise    2002-01    2002-02    2002-03    2002-04    2002-05  \
# 0             1   0.000000  11.111111   8.888889   7.111111   5.688889
# 1             2  11.111111  20.000000  16.000000  12.800000  10.240000
# 2             3   0.000000   0.000000   0.000000   0.000000  11.111111
# 3             4   0.000000   0.000000   0.000000   0.000000   0.000000
# 4             5  36.111111  68.888889  91.952381  91.555556  78.165333
#
#      2002-06    2002-07    2002-08    2002-09  ...    2022-07    2022-08  \
# 0   4.551111   3.640889  14.023822  11.219058  ...  95.000456  90.878881
# 1   8.192000  17.664711  14.131769  11.305415  ...  33.356441  26.685153
# 2   8.888889   7.111111   5.688889   4.551111  ...  24.922552  19.938041
# 3   0.000000   0.000000   0.000000   0.000000  ...  21.288006  17.030405
# 4  90.417778  85.920000  92.937543  86.077611  ...  99.799505  98.728493
#
#      2022-09    2022-10    2022-11    2022-12    2023-01    2023-02  \
# 0  86.036438  81.975582  72.247132  74.625457  97.205522  90.921703
# 1  43.570345  45.967387  47.885021  38.308016  30.646413  46.739353
# 2  15.950433  12.760347  10.208277  30.388844  24.311075  19.448860
# 3  13.624324  10.899459   8.719567   6.975654   5.580523   4.464418
# 4  97.446020  96.017441  97.956816  91.698786  93.367594  99.630794
#
#      2023-03    2023-04
# 0  83.107733  80.062460
# 1  37.391482  29.913186
# 2  26.670199  32.447270
# 3   3.571535   2.857228
# 4  98.074889  96.408810
#
# [5 rows x 257 columns]

# %%
covalence_id_firms = pd.read_csv('Universe_Listed_Covalence_31.07.2023_v2_updated.csv',sep=';',on_bad_lines='skip')
covalence_id_firms.head()
# Out:
#    Unnamed: 0  idEntreprise           Company          ISIN  \
# 0           0             1        Pfizer Inc  US7170811035
# 1           1             2    Merck & Co Inc  US58933Y1055
# 2           2             3           GSK plc  GB0009252882
# 3           3             4  Eli Lilly and Co  US5324571083
# 4           4             5          Bayer AG  DE000BAY0017
#
#                               GICS industry group  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences
# 1  Pharmaceuticals, Biotechnology & Life Sciences
# 2    Unable to resolve all requested identifiers.
# 3  Pharmaceuticals, Biotechnology & Life Sciences
# 4  Pharmaceuticals, Biotechnology & Life Sciences
#
#                               GICS sub-industry  \
# 0                               Pharmaceuticals
# 1                               Pharmaceuticals
# 2  Unable to resolve all requested identifiers.
# 3                               Pharmaceuticals
# 4                               Pharmaceuticals
#
#                             Headquarters Region  \
# 0                                      Americas
# 1                                      Americas
# 2  Unable to resolve all requested identifiers.
# 3                                      Americas
# 4                                        Europe
#
#                            Headquarters Country
# 0                      United States of America
# 1                      United States of America
# 2  Unable to resolve all requested identifiers.
# 3                      United States of America
# 4                                       Germany

# %%
# Charger le fichier Excel contenant la liste des entreprises
df = pd.read_csv('Firms.csv')
df.head()
# Out:
#            ISIN           Company  \
# 0  US7170811035        Pfizer Inc
# 1  US58933Y1055    Merck & Co Inc
# 2  GB0009252882           GSK plc
# 3  US5324571083  Eli Lilly and Co
# 4  DE000BAY0017          Bayer AG
#
#                                         Country
# 0                      United States of America
# 1                      United States of America
# 2  Unable to resolve all requested identifiers.
# 3                      United States of America
# 4                                       Germany

# %% [markdown]
# ## Fusion des tables

# %%
df1 = pd.merge(covalence_id_firms, CON_E, on='idEntreprise')
df1.head()
# Out:
#    Unnamed: 0  idEntreprise           Company          ISIN  \
# 0           0             1        Pfizer Inc  US7170811035
# 1           1             2    Merck & Co Inc  US58933Y1055
# 2           2             3           GSK plc  GB0009252882
# 3           3             4  Eli Lilly and Co  US5324571083
# 4           4             5          Bayer AG  DE000BAY0017
#
#                               GICS industry group  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences
# 1  Pharmaceuticals, Biotechnology & Life Sciences
# 2    Unable to resolve all requested identifiers.
# 3  Pharmaceuticals, Biotechnology & Life Sciences
# 4  Pharmaceuticals, Biotechnology & Life Sciences
#
#                               GICS sub-industry  \
# 0                               Pharmaceuticals
# 1                               Pharmaceuticals
# 2  Unable to resolve all requested identifiers.
# 3                               Pharmaceuticals
# 4                               Pharmaceuticals
#
#                             Headquarters Region  \
# 0                                      Americas
# 1                                      Americas
# 2  Unable to resolve all requested identifiers.
# 3                                      Americas
# 4                                        Europe
#
#                            Headquarters Country    2002-01    2002-02  ...  \
# 0                      United States of America   0.000000  11.111111  ...
# 1                      United States of America  11.111111  20.000000  ...
# 2  Unable to resolve all requested identifiers.   0.000000   0.000000  ...
# 3                      United States of America   0.000000   0.000000  ...
# 4                                       Germany  36.111111  68.888889  ...
#
#      2022-07    2022-08    2022-09    2022-10    2022-11    2022-12  \
# 0  95.000456  90.878881  86.036438  81.975582  72.247132  74.625457
# 1  33.356441  26.685153  43.570345  45.967387  47.885021  38.308016
# 2  24.922552  19.938041  15.950433  12.760347  10.208277  30.388844
# 3  21.288006  17.030405  13.624324  10.899459   8.719567   6.975654
# 4  99.799505  98.728493  97.446020  96.017441  97.956816  91.698786
#
#      2023-01    2023-02    2023-03    2023-04
# 0  97.205522  90.921703  83.107733  80.062460
# 1  30.646413  46.739353  37.391482  29.913186
# 2  24.311075  19.448860  26.670199  32.447270
# 3   5.580523   4.464418   3.571535   2.857228
# 4  93.367594  99.630794  98.074889  96.408810
#
# [5 rows x 264 columns]

# %%
df1 = df1.drop(columns=df1.columns[0])
df1 = df1.drop(columns=['GICS industry group', 'GICS sub-industry', 'Headquarters Region', 'Headquarters Country'])
df1
# Out:
#       idEntreprise                                      Company          ISIN  \
# 0                1                                   Pfizer Inc  US7170811035
# 1                2                               Merck & Co Inc  US58933Y1055
# 2                3                                      GSK plc  GB0009252882
# 3                4                             Eli Lilly and Co  US5324571083
# 4                5                                     Bayer AG  DE000BAY0017
# ...            ...                                          ...           ...
# 8593         19239                     F&G Annuities & Life Inc  US30190A1043
# 8594         19240  Gujarat Mineral Development Corporation Ltd  INE131A01031
# 8595         19247                                  Borosil Ltd  INE02PY01013
# 8596         19251                         Healthcare Trust Inc  US42226B2043
# 8597         19253                           Rosetti Marino SpA  IT0001017851
#
#         2002-01    2002-02    2002-03    2002-04    2002-05    2002-06  \
# 0      0.000000  11.111111   8.888889   7.111111   5.688889   4.551111
# 1     11.111111  20.000000  16.000000  12.800000  10.240000   8.192000
# 2      0.000000   0.000000   0.000000   0.000000  11.111111   8.888889
# 3      0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     36.111111  68.888889  91.952381  91.555556  78.165333  90.417778
# ...         ...        ...        ...        ...        ...        ...
# 8593   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2002-07  ...    2022-07    2022-08    2022-09    2022-10    2022-11  \
# 0      3.640889  ...  95.000456  90.878881  86.036438  81.975582  72.247132
# 1     17.664711  ...  33.356441  26.685153  43.570345  45.967387  47.885021
# 2      7.111111  ...  24.922552  19.938041  15.950433  12.760347  10.208277
# 3      0.000000  ...  21.288006  17.030405  13.624324  10.899459   8.719567
# 4     85.920000  ...  99.799505  98.728493  97.446020  96.017441  97.956816
# ...         ...  ...        ...        ...        ...        ...        ...
# 8593   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2022-12    2023-01    2023-02    2023-03    2023-04
# 0     74.625457  97.205522  90.921703  83.107733  80.062460
# 1     38.308016  30.646413  46.739353  37.391482  29.913186
# 2     30.388844  24.311075  19.448860  26.670199  32.447270
# 3      6.975654   5.580523   4.464418   3.571535   2.857228
# 4     91.698786  93.367594  99.630794  98.074889  96.408810
# ...         ...        ...        ...        ...        ...
# 8593   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [8598 rows x 259 columns]

# %%
df1 = df1[df1['2009-01'] != 0]
df1
# Out:
#       idEntreprise                                          Company  \
# 0                1                                       Pfizer Inc
# 1                2                                   Merck & Co Inc
# 2                3                                          GSK plc
# 3                4                                 Eli Lilly and Co
# 4                5                                         Bayer AG
# ...            ...                                              ...
# 7481         16645                             Hindustan Copper Ltd
# 7685         17097            Fawaz Abdulaziz Alhokair Company SJSC
# 8233         18234                                   Iveco Group NV
# 8290         18386  China Development Bank Financial Leasing Co Ltd
# 8299         18412                            Western Mining Co Ltd
#
#               ISIN    2002-01    2002-02    2002-03    2002-04    2002-05  \
# 0     US7170811035   0.000000  11.111111   8.888889   7.111111   5.688889
# 1     US58933Y1055  11.111111  20.000000  16.000000  12.800000  10.240000
# 2     GB0009252882   0.000000   0.000000   0.000000   0.000000  11.111111
# 3     US5324571083   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     DE000BAY0017  36.111111  68.888889  91.952381  91.555556  78.165333
# ...            ...        ...        ...        ...        ...        ...
# 7481  INE531E01026   0.000000   0.000000   0.000000   0.000000   0.000000
# 7685  SA000A0LB2R6   0.000000   0.000000   0.000000   0.000000   0.000000
# 8233  NL0015000LU4   0.000000   0.000000   0.000000   0.000000   0.000000
# 8290  CNE1000027C9   0.000000   0.000000   0.000000   0.000000   0.000000
# 8299  CNE100000619   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2002-06    2002-07  ...       2022-07       2022-08       2022-09  \
# 0      4.551111   3.640889  ...  9.500046e+01  9.087888e+01  8.603644e+01
# 1      8.192000  17.664711  ...  3.335644e+01  2.668515e+01  4.357034e+01
# 2      8.888889   7.111111  ...  2.492255e+01  1.993804e+01  1.595043e+01
# 3      0.000000   0.000000  ...  2.128801e+01  1.703040e+01  1.362432e+01
# 4     90.417778  85.920000  ...  9.979950e+01  9.872849e+01  9.744602e+01
# ...         ...        ...  ...           ...           ...           ...
# 7481   0.000000   0.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 7685   0.000000   0.000000  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 8233   0.000000   0.000000  ...  3.163846e+01  2.531077e+01  2.024861e+01
# 8290  22.222222  17.777778  ...  8.493048e-01  6.794438e-01  5.435551e-01
# 8299   0.000000  11.111111  ...  5.968559e-13  4.831691e-13  3.884300e-13
#
#            2022-10       2022-11       2022-12       2023-01       2023-02  \
# 0     8.197558e+01  7.224713e+01  7.462546e+01  9.720552e+01  9.092170e+01
# 1     4.596739e+01  4.788502e+01  3.830802e+01  3.064641e+01  4.673935e+01
# 2     1.276035e+01  1.020828e+01  3.038884e+01  2.431108e+01  1.944886e+01
# 3     1.089946e+01  8.719567e+00  6.975654e+00  5.580523e+00  4.464418e+00
# 4     9.601744e+01  9.795682e+01  9.169879e+01  9.336759e+01  9.963079e+01
# ...            ...           ...           ...           ...           ...
# 7481  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7685  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8233  1.619889e+01  1.295911e+01  1.036729e+01  8.293831e+00  6.635065e+00
# 8290  4.348441e-01  3.478752e-01  2.783002e-01  2.226402e-01  1.781121e-01
# 8299  3.031649e-13  2.368476e-13  1.989520e-13  1.610564e-13  1.136868e-13
#
#            2023-03       2023-04
# 0     8.310773e+01  8.006246e+01
# 1     3.739148e+01  2.991319e+01
# 2     2.667020e+01  3.244727e+01
# 3     3.571535e+00  2.857228e+00
# 4     9.807489e+01  9.640881e+01
# ...            ...           ...
# 7481  0.000000e+00  0.000000e+00
# 7685  0.000000e+00  0.000000e+00
# 8233  5.308052e+00  4.246442e+00
# 8290  1.424897e-01  1.139918e-01
# 8299  1.042129e-13  8.526513e-14
#
# [398 rows x 259 columns]

# %%
# Sélectionner 100 entreprises au hasard
random_companies = df1['Company'].sample(n=100, random_state=42).tolist()

# Utiliser la fonction pour générer les phrases
a = 3
b = 5
company_sentences = generate_environmental_communication(random_companies, Dico_env_en, a, b)

# Afficher les phrases générées par entreprise
for company, sentences in company_sentences.items():
    print(f"{company}:")
    for idx, sentence in enumerate(sentences, 1):
        print(f"  {idx}. {sentence}")

# %%
# Sélectionner 100 entreprises au hasard avec leurs ISIN
random_companies = df[['Company', 'ISIN']].sample(n=100, random_state=42)

# Utiliser la fonction pour générer les phrases
a = 3
b = 5
company_sentences = generate_environmental_communication(random_companies['Company'].tolist(), Dico_env_en, a, b)

# Convertir le dictionnaire company_sentences en DataFrame
df_sentences = pd.DataFrame([(company, sentence) for company, sentences in company_sentences.items() for sentence in sentences], 
                            columns=['Company', 'Sentence'])

# Effectuer une jointure pour ajouter les ISIN à chaque entreprise
df_final = pd.merge(df_sentences, random_companies, on='Company', how='left')

# Afficher les phrases générées par entreprise avec leur ISIN
for idx, row in df_final.iterrows():
    print(f"{row['Company']} (ISIN: {row['ISIN']}):")
    print(f"  {idx + 1}. {row['Sentence']}")
    print('-' * 50)
# Out:
# Kirloskar Brothers Ltd (ISIN: INE732A01036):
#   1. Kirloskar Brothers Ltd is dedicated to sustainability approaches and pollution initiatives.
# --------------------------------------------------
# Kirloskar Brothers Ltd (ISIN: INE732A01036):
#   2. Kirloskar Brothers Ltd communicates about its well-being commitment and its positive contribution to restoration.
# --------------------------------------------------
# Kirloskar Brothers Ltd (ISIN: INE732A01036):
#   3. Kirloskar Brothers Ltd's harmony efforts are focused on overconsumption.
# --------------------------------------------------
# Seer Inc (ISIN: US81578P1066):
#   4. Seer Inc is exploring continuous improvement initiatives to address worrisome.
# --------------------------------------------------
# Seer Inc (ISIN: US81578P1066):
#   5. The recoverable approach of Seer Inc reflects its commitment to efficient.
# --------------------------------------------------
# Seer Inc (ISIN: US81578P1066):
#   6. Seer Inc implements innovative practices to support conscious spreading.
# --------------------------------------------------
# Seer Inc (ISIN: US81578P1066):
#   7. Through its fulfillment actions, Seer Inc aims to improve regeneration.
# --------------------------------------------------
# Seer Inc (ISIN: US81578P1066):
#   8. Seer Inc is committed to eco-tourism actions and addressing malevolent.
# --------------------------------------------------
# Samsung Life Insurance Co Ltd (ISIN: KR7032830002):
#   9. Samsung Life Insurance Co Ltd is recognized for its permaculture approach and its positive impact on wind energy.
# --------------------------------------------------
# Samsung Life Insurance Co Ltd (ISIN: KR7032830002):
#   10. Samsung Life Insurance Co Ltd is developing solar energy practices while managing excessive exploitation.
# --------------------------------------------------
# Samsung Life Insurance Co Ltd (ISIN: KR7032830002):
#   11. The company Samsung Life Insurance Co Ltd is researching responsible solutions for deterioration.
# --------------------------------------------------
# Kontoor Brands Inc (ISIN: US50050N1037):
#   12. Concerns are raised about Kontoor Brands Inc's inappropriate practices.
# --------------------------------------------------
# Kontoor Brands Inc (ISIN: US50050N1037):
#   13. Kontoor Brands Inc is committed to organic actions and addressing malevolent.
# --------------------------------------------------
# Kontoor Brands Inc (ISIN: US50050N1037):
#   14. Kontoor Brands Inc integrates greenhouse effect strategies with dangerous management.
# --------------------------------------------------
# Kontoor Brands Inc (ISIN: US50050N1037):
#   15. Kontoor Brands Inc is dedicated to energy efficiency approaches and greenhouse gas emissions initiatives.
# --------------------------------------------------
# Tauron Polska Energia SA (ISIN: PLTAURN00011):
#   16. Concerns are raised about Tauron Polska Energia SA's contamination practices.
# --------------------------------------------------
# Tauron Polska Energia SA (ISIN: PLTAURN00011):
#   17. Tauron Polska Energia SA is developing eco-innovation practices while managing aggressive.
# --------------------------------------------------
# Tauron Polska Energia SA (ISIN: PLTAURN00011):
#   18. Tauron Polska Energia SA values its agroecology commitment and its respect for eco-conscious.
# --------------------------------------------------
# Tauron Polska Energia SA (ISIN: PLTAURN00011):
#   19. The company Tauron Polska Energia SA is researching conservation solutions for unacceptable.
# --------------------------------------------------
# Recordati Industria Chimica e Farmaceutica SpA (ISIN: IT0003828271):
#   20. As a conscious spreading company, Recordati Industria Chimica e Farmaceutica SpA takes measures to encourage conscious consumption.
# --------------------------------------------------
# Recordati Industria Chimica e Farmaceutica SpA (ISIN: IT0003828271):
#   21. The company Recordati Industria Chimica e Farmaceutica SpA is criticized for its lack of commitment to inadequate.
# --------------------------------------------------
# Recordati Industria Chimica e Farmaceutica SpA (ISIN: IT0003828271):
#   22. Recordati Industria Chimica e Farmaceutica SpA adopts a eco-habitat strategy to promote environmentally friendly.
# --------------------------------------------------
# Recordati Industria Chimica e Farmaceutica SpA (ISIN: IT0003828271):
#   23. Recordati Industria Chimica e Farmaceutica SpA communicates about its rehabilitation commitment and its positive contribution to valorization.
# --------------------------------------------------
# Repligen Corp (ISIN: US7599161095):
#   24. Repligen Corp adopts a conservation strategy to promote green.
# --------------------------------------------------
# Repligen Corp (ISIN: US7599161095):
#   25. The approach of Repligen Corp involves recycling methods to mitigate pollution.
# --------------------------------------------------
# Repligen Corp (ISIN: US7599161095):
#   26. Repligen Corp is singled out for its waste.
# --------------------------------------------------
# Repligen Corp (ISIN: US7599161095):
#   27. The company Repligen Corp is committed to a responsible consumption approach to promote eco-design.
# --------------------------------------------------
# Repligen Corp (ISIN: US7599161095):
#   28. As a eco-citizen company, Repligen Corp takes measures to encourage eco-efficient.
# --------------------------------------------------
# Apollo Commercial Real Estate Finance Inc (ISIN: US03762U1051):
#   29. Apollo Commercial Real Estate Finance Inc implements zero waste practices to support biodiversity.
# --------------------------------------------------
# Apollo Commercial Real Estate Finance Inc (ISIN: US03762U1051):
#   30. Apollo Commercial Real Estate Finance Inc is dedicated to conservation approaches and overexploitation initiatives.
# --------------------------------------------------
# Apollo Commercial Real Estate Finance Inc (ISIN: US03762U1051):
#   31. Apollo Commercial Real Estate Finance Inc is committed to solar energy actions and addressing hazardous.
# --------------------------------------------------
# Zhuzhou Hongda Electronics Corp Ltd (ISIN: CNE1000035L3):
#   32. Zhuzhou Hongda Electronics Corp Ltd's irresponsible practices have raised concerns among environmentalists.
# --------------------------------------------------
# Zhuzhou Hongda Electronics Corp Ltd (ISIN: CNE1000035L3):
#   33. Zhuzhou Hongda Electronics Corp Ltd communicates about its permaculture commitment and its positive contribution to fair.
# --------------------------------------------------
# Zhuzhou Hongda Electronics Corp Ltd (ISIN: CNE1000035L3):
#   34. Zhuzhou Hongda Electronics Corp Ltd is dedicated to responsible consumption approaches and environmental degradation initiatives.
# --------------------------------------------------
# Zhuzhou Hongda Electronics Corp Ltd (ISIN: CNE1000035L3):
#   35. The recycling approach of Zhuzhou Hongda Electronics Corp Ltd reflects its commitment to fulfillment.
# --------------------------------------------------
# Zhuzhou Hongda Electronics Corp Ltd (ISIN: CNE1000035L3):
#   36. Zhuzhou Hongda Electronics Corp Ltd is singled out for its pollute.
# --------------------------------------------------
# 3i Group plc (ISIN: GB00B1YW4409):
#   37. 3i Group plc communicates about its social responsibility commitment and its positive contribution to green.
# --------------------------------------------------
# 3i Group plc (ISIN: GB00B1YW4409):
#   38. 3i Group plc is recognized for its eco-responsible approach and its positive impact on sustainability.
# --------------------------------------------------
# 3i Group plc (ISIN: GB00B1YW4409):
#   39. 3i Group plc's deforestation initiative is viewed with skepticism.
# --------------------------------------------------
# 3i Group plc (ISIN: GB00B1YW4409):
#   40. The eco-friendly approach of 3i Group plc reflects its commitment to ecological.
# --------------------------------------------------
# 3i Group plc (ISIN: GB00B1YW4409):
#   41. 3i Group plc's healthy efforts are focused on irreparable.
# --------------------------------------------------
# Mitsubishi Logistics Corp (ISIN: JP3902000003):
#   42. Mitsubishi Logistics Corp integrates integrity strategies with wasteful management.
# --------------------------------------------------
# Mitsubishi Logistics Corp (ISIN: JP3902000003):
#   43. Mitsubishi Logistics Corp implements revitalization practices to support sustainable.
# --------------------------------------------------
# Mitsubishi Logistics Corp (ISIN: JP3902000003):
#   44. Mitsubishi Logistics Corp implements wind energy practices to support conservation.
# --------------------------------------------------
# Mitsubishi Logistics Corp (ISIN: JP3902000003):
#   45. The clean approach of Mitsubishi Logistics Corp reflects its commitment to social responsibility.
# --------------------------------------------------
# Zamp SA (ISIN: BRZAMPACNOR5):
#   46. Zamp SA implements eco-innovation measures while considering damaging.
# --------------------------------------------------
# Zamp SA (ISIN: BRZAMPACNOR5):
#   47. The company Zamp SA is criticized for its lack of commitment to pollution.
# --------------------------------------------------
# Zamp SA (ISIN: BRZAMPACNOR5):
#   48. Through its recycling actions, Zamp SA aims to improve conservation.
# --------------------------------------------------
# Zamp SA (ISIN: BRZAMPACNOR5):
#   49. Zamp SA is recognized for its innovative approach and its positive impact on green energy.
# --------------------------------------------------
# Aaon Inc (ISIN: US0003602069):
#   50. Aaon Inc implements circular economy practices to support environmentally friendly.
# --------------------------------------------------
# Aaon Inc (ISIN: US0003602069):
#   51. Aaon Inc communicates about its greenhouse effect commitment and its positive contribution to eco-label.
# --------------------------------------------------
# Aaon Inc (ISIN: US0003602069):
#   52. The company Aaon Inc is criticized for its lack of commitment to deterioration.
# --------------------------------------------------
# Aaon Inc (ISIN: US0003602069):
#   53. Aaon Inc is recognized for its conscious spreading approach and its positive impact on organic.
# --------------------------------------------------
# Valneva SE (ISIN: FR0004056851):
#   54. Valneva SE integrates regeneration strategies with wasteful management.
# --------------------------------------------------
# Valneva SE (ISIN: FR0004056851):
#   55. Some question Valneva SE's commitment due to its environmental denial.
# --------------------------------------------------
# Valneva SE (ISIN: FR0004056851):
#   56. Valneva SE implements healthy measures while considering disturb.
# --------------------------------------------------
# Valneva SE (ISIN: FR0004056851):
#   57. The company Valneva SE is criticized for its lack of commitment to damage.
# --------------------------------------------------
# Valneva SE (ISIN: FR0004056851):
#   58. Through its recycling actions, Valneva SE aims to improve continuous improvement.
# --------------------------------------------------
# Emami Ltd (ISIN: INE548C01032):
#   59. The approach of Emami Ltd involves wind energy methods to mitigate pollution.
# --------------------------------------------------
# Emami Ltd (ISIN: INE548C01032):
#   60. Emami Ltd's catastrophe initiative is viewed with skepticism.
# --------------------------------------------------
# Emami Ltd (ISIN: INE548C01032):
#   61. Emami Ltd is committed to solidarity actions and addressing destructive.
# --------------------------------------------------
# Emami Ltd (ISIN: INE548C01032):
#   62. Emami Ltd is blamed for its waste impact.
# --------------------------------------------------
# Emami Ltd (ISIN: INE548C01032):
#   63. Emami Ltd is developing eco-tourism practices while managing irreparable.
# --------------------------------------------------
# Prospect Capital Corp (ISIN: US74348T1025):
#   64. Prospect Capital Corp is recognized for its agroecology approach and its positive impact on organic.
# --------------------------------------------------
# Prospect Capital Corp (ISIN: US74348T1025):
#   65. Prospect Capital Corp is blamed for its greenhouse gas emissions impact.
# --------------------------------------------------
# Prospect Capital Corp (ISIN: US74348T1025):
#   66. The company Prospect Capital Corp is criticized for its lack of commitment to excessive exploitation.
# --------------------------------------------------
# Prospect Capital Corp (ISIN: US74348T1025):
#   67. The company Prospect Capital Corp is committed to a eco-responsible approach to promote eco-innovation.
# --------------------------------------------------
# Owens & Minor Inc (ISIN: US6907321029):
#   68. Owens & Minor Inc communicates about its responsible consumption commitment and its positive contribution to regeneration.
# --------------------------------------------------
# Owens & Minor Inc (ISIN: US6907321029):
#   69. Thanks to its efficiency initiative, Owens & Minor Inc strengthens its commitment to well-being.
# --------------------------------------------------
# Owens & Minor Inc (ISIN: US6907321029):
#   70. Owens & Minor Inc is exploring restorer initiatives to address contamination.
# --------------------------------------------------
# Owens & Minor Inc (ISIN: US6907321029):
#   71. Owens & Minor Inc's pollute initiative is viewed with skepticism.
# --------------------------------------------------
# Owens & Minor Inc (ISIN: US6907321029):
#   72. Owens & Minor Inc values its solar energy commitment and its respect for well-being.
# --------------------------------------------------
# Sino Thai Engineering and Construction PCL (ISIN: TH0307010Z09):
#   73. The wind energy approach of Sino Thai Engineering and Construction PCL reflects its commitment to fair.
# --------------------------------------------------
# Sino Thai Engineering and Construction PCL (ISIN: TH0307010Z09):
#   74. Sino Thai Engineering and Construction PCL is exploring conscious consumption initiatives to address perilous.
# --------------------------------------------------
# Sino Thai Engineering and Construction PCL (ISIN: TH0307010Z09):
#   75. Sino Thai Engineering and Construction PCL's illegal logging practices have raised concerns among environmentalists.
# --------------------------------------------------
# Sino Thai Engineering and Construction PCL (ISIN: TH0307010Z09):
#   76. Through its green energy actions, Sino Thai Engineering and Construction PCL aims to improve social responsibility.
# --------------------------------------------------
# Eventbrite Inc (ISIN: US29975E1091):
#   77. Thanks to its recoverable initiative, Eventbrite Inc strengthens its commitment to eco-citizen.
# --------------------------------------------------
# Eventbrite Inc (ISIN: US29975E1091):
#   78. Eventbrite Inc communicates about its sustainability commitment and its positive contribution to greenhouse effect.
# --------------------------------------------------
# Eventbrite Inc (ISIN: US29975E1091):
#   79. Eventbrite Inc is under fire for its risk strategy.
# --------------------------------------------------
# Eventbrite Inc (ISIN: US29975E1091):
#   80. As a prosperity company, Eventbrite Inc takes measures to encourage energy-efficient.
# --------------------------------------------------
# Eventbrite Inc (ISIN: US29975E1091):
#   81. Eventbrite Inc is dedicated to eco-innovation approaches and destructive initiatives.
# --------------------------------------------------
# Samsung SDI Co Ltd (ISIN: KR7006400006):
#   82. Samsung SDI Co Ltd faces scrutiny for its excessive exploitation approach.
# --------------------------------------------------
# Samsung SDI Co Ltd (ISIN: KR7006400006):
#   83. Samsung SDI Co Ltd implements renewable energy practices to support harmony.
# --------------------------------------------------
# Samsung SDI Co Ltd (ISIN: KR7006400006):
#   84. Samsung SDI Co Ltd adopts a eco-design strategy to promote zero waste.
# --------------------------------------------------
# Samsung SDI Co Ltd (ISIN: KR7006400006):
#   85. Samsung SDI Co Ltd is exploring permaculture initiatives to address pollution.
# --------------------------------------------------
# KWG Group Holdings Ltd (ISIN: KYG532241042):
#   86. KWG Group Holdings Ltd implements biodiversity practices to support sustainability.
# --------------------------------------------------
# KWG Group Holdings Ltd (ISIN: KYG532241042):
#   87. KWG Group Holdings Ltd faces scrutiny for its toxic approach.
# --------------------------------------------------
# KWG Group Holdings Ltd (ISIN: KYG532241042):
#   88. KWG Group Holdings Ltd implements eco-conscious measures while considering ravager.
# --------------------------------------------------
# KWG Group Holdings Ltd (ISIN: KYG532241042):
#   89. The company KWG Group Holdings Ltd is committed to a social responsibility approach to promote eco-citizen.
# --------------------------------------------------
# Mayora Indah Tbk PT (ISIN: ID1000060007):
#   90. Mayora Indah Tbk PT values its recycling commitment and its respect for greenhouse effect.
# --------------------------------------------------
# Mayora Indah Tbk PT (ISIN: ID1000060007):
#   91. Mayora Indah Tbk PT integrates recoverable strategies with deterioration management.
# --------------------------------------------------
# Mayora Indah Tbk PT (ISIN: ID1000060007):
#   92. Thanks to its recovery initiative, Mayora Indah Tbk PT strengthens its commitment to social responsibility.
# --------------------------------------------------
# Mayora Indah Tbk PT (ISIN: ID1000060007):
#   93. The company Mayora Indah Tbk PT is researching healthy solutions for overconsumption.
# --------------------------------------------------
# Mayora Indah Tbk PT (ISIN: ID1000060007):
#   94. The company Mayora Indah Tbk PT is committed to a rehabilitation approach to promote circular economy.
# --------------------------------------------------
# Tokuyama Corp (ISIN: JP3625000009):
#   95. Tokuyama Corp is criticized for its failure to address dangerous.
# --------------------------------------------------
# Tokuyama Corp (ISIN: JP3625000009):
#   96. Tokuyama Corp values its conscious spreading commitment and its respect for fair.
# --------------------------------------------------
# Tokuyama Corp (ISIN: JP3625000009):
#   97. Tokuyama Corp communicates about its wind energy commitment and its positive contribution to eco-friendly.
# --------------------------------------------------
# Sberbank Rossii PAO (ISIN: RU0009029540):
#   98. The company Sberbank Rossii PAO emphasizes well-being practices alongside destroyed natural habitat.
# --------------------------------------------------
# Sberbank Rossii PAO (ISIN: RU0009029540):
#   99. Sberbank Rossii PAO is developing preservation practices while managing harm.
# --------------------------------------------------
# Sberbank Rossii PAO (ISIN: RU0009029540):
#   100. Through its biodiversity actions, Sberbank Rossii PAO aims to improve preservation.
# --------------------------------------------------
# Sberbank Rossii PAO (ISIN: RU0009029540):
#   101. Sberbank Rossii PAO implements renewable energy measures while considering deterioration.
# --------------------------------------------------
# Sberbank Rossii PAO (ISIN: RU0009029540):
#   102. The company Sberbank Rossii PAO is committed to a energy efficiency approach to promote sustainable.
# --------------------------------------------------
# Catalent Inc (ISIN: US1488061029):
#   103. Catalent Inc communicates about its eco-conscious commitment and its positive contribution to regenerator.
# --------------------------------------------------
# Catalent Inc (ISIN: US1488061029):
#   104. Catalent Inc's contamination initiative is viewed with skepticism.
# --------------------------------------------------
# Catalent Inc (ISIN: US1488061029):
#   105. Some question Catalent Inc's commitment due to its ecological damage.
# --------------------------------------------------
# Catalent Inc (ISIN: US1488061029):
#   106. Catalent Inc values its responsible consumption commitment and its respect for ethical.
# --------------------------------------------------
# Catalent Inc (ISIN: US1488061029):
#   107. Catalent Inc is blamed for its threat impact.
# --------------------------------------------------
# Greenpanel Industries Ltd (ISIN: INE08ZM01014):
#   108. Greenpanel Industries Ltd is recognized for its clean approach and its positive impact on revitalization.
# --------------------------------------------------
# Greenpanel Industries Ltd (ISIN: INE08ZM01014):
#   109. Greenpanel Industries Ltd communicates about its clean energy commitment and its positive contribution to renewable.
# --------------------------------------------------
# Greenpanel Industries Ltd (ISIN: INE08ZM01014):
#   110. As a wind energy company, Greenpanel Industries Ltd takes measures to encourage eco-conscious.
# --------------------------------------------------
# Greenpanel Industries Ltd (ISIN: INE08ZM01014):
#   111. Greenpanel Industries Ltd is developing responsible practices while managing overconsumption.
# --------------------------------------------------
# Greenpanel Industries Ltd (ISIN: INE08ZM01014):
#   112. As a beneficial company, Greenpanel Industries Ltd takes measures to encourage prosperity.
# --------------------------------------------------
# Mahindra and Mahindra Ltd (ISIN: INE101A01026):
#   113. Mahindra and Mahindra Ltd implements sustainable mobility measures while considering spoil.
# --------------------------------------------------
# Mahindra and Mahindra Ltd (ISIN: INE101A01026):
#   114. Mahindra and Mahindra Ltd integrates eco-responsible strategies with pollutant management.
# --------------------------------------------------
# Mahindra and Mahindra Ltd (ISIN: INE101A01026):
#   115. Mahindra and Mahindra Ltd is under fire for its climate change strategy.
# --------------------------------------------------
# Mahindra and Mahindra Ltd (ISIN: INE101A01026):
#   116. Mahindra and Mahindra Ltd values its regenerator commitment and its respect for eco-efficient.
# --------------------------------------------------
# Mahindra and Mahindra Ltd (ISIN: INE101A01026):
#   117. As a carbon neutral company, Mahindra and Mahindra Ltd takes measures to encourage eco-innovation.
# --------------------------------------------------
# Tribal (ISIN: GB0030181522):
#   118. Tribal communicates about its eco-habitat commitment and its positive contribution to regeneration.
# --------------------------------------------------
# Tribal (ISIN: GB0030181522):
#   119. Tribal is under fire for its risk strategy.
# --------------------------------------------------
# Tribal (ISIN: GB0030181522):
#   120. Tribal integrates eco-design strategies with ecological damage management.
# --------------------------------------------------
# Tribal (ISIN: GB0030181522):
#   121. The eco-design approach of Tribal reflects its commitment to eco-label.
# --------------------------------------------------
# Tribal (ISIN: GB0030181522):
#   122. The company Tribal is committed to a eco-citizen approach to promote organic.
# --------------------------------------------------
# UWC Bhd (ISIN: MYL5292OO007):
#   123. UWC Bhd adopts a sustainability strategy to promote eco-friendly.
# --------------------------------------------------
# UWC Bhd (ISIN: MYL5292OO007):
#   124. UWC Bhd implements efficiency practices to support preservation.
# --------------------------------------------------
# UWC Bhd (ISIN: MYL5292OO007):
#   125. UWC Bhd communicates about its renewable energy commitment and its positive contribution to conscious spreading.
# --------------------------------------------------
# Park Ohio Holdings Corp (ISIN: US7006661000):
#   126. Park Ohio Holdings Corp is recognized for its wind energy approach and its positive impact on ethical.
# --------------------------------------------------
# Park Ohio Holdings Corp (ISIN: US7006661000):
#   127. The sustainable approach of Park Ohio Holdings Corp reflects its commitment to prosperity.
# --------------------------------------------------
# Park Ohio Holdings Corp (ISIN: US7006661000):
#   128. Park Ohio Holdings Corp is recognized for its recoverable approach and its positive impact on recoverable.
# --------------------------------------------------
# Itera ASA (ISIN: NO0010001118):
#   129. As a zero waste company, Itera ASA takes measures to encourage responsible consumption.
# --------------------------------------------------
# Itera ASA (ISIN: NO0010001118):
#   130. Itera ASA implements eco-innovation measures while considering contamination.
# --------------------------------------------------
# Itera ASA (ISIN: NO0010001118):
#   131. Itera ASA is criticized for its failure to address pollutant.
# --------------------------------------------------
# Sam Chun Dang Pharm Co Ltd (ISIN: KR7000250001):
#   132. As a green energy company, Sam Chun Dang Pharm Co Ltd takes measures to encourage eco-friendly.
# --------------------------------------------------
# Sam Chun Dang Pharm Co Ltd (ISIN: KR7000250001):
#   133. Sam Chun Dang Pharm Co Ltd is criticized for its failure to address overconsumption.
# --------------------------------------------------
# Sam Chun Dang Pharm Co Ltd (ISIN: KR7000250001):
#   134. Sam Chun Dang Pharm Co Ltd integrates renewable energy strategies with worrisome management.
# --------------------------------------------------
# Sam Chun Dang Pharm Co Ltd (ISIN: KR7000250001):
#   135. Sam Chun Dang Pharm Co Ltd is under fire for its perilous strategy.
# --------------------------------------------------
# Sam Chun Dang Pharm Co Ltd (ISIN: KR7000250001):
#   136. Through its regeneration actions, Sam Chun Dang Pharm Co Ltd aims to improve beneficial.
# --------------------------------------------------
# Old Republic International Corp (ISIN: US6802231042):
#   137. The company Old Republic International Corp emphasizes eco-habitat practices alongside irresponsible.
# --------------------------------------------------
# Old Republic International Corp (ISIN: US6802231042):
#   138. Old Republic International Corp is singled out for its aggressive.
# --------------------------------------------------
# Old Republic International Corp (ISIN: US6802231042):
#   139. Old Republic International Corp adopts a fulfillment strategy to promote zero waste.
# --------------------------------------------------
# Old Republic International Corp (ISIN: US6802231042):
#   140. Old Republic International Corp faces scrutiny for its pollutant approach.
# --------------------------------------------------
# Old Republic International Corp (ISIN: US6802231042):
#   141. Old Republic International Corp's catastrophic practices have raised concerns among environmentalists.
# --------------------------------------------------
# V-mart Retail Ltd (ISIN: INE665J01013):
#   142. V-mart Retail Ltd values its eco-habitat commitment and its respect for eco-efficient.
# --------------------------------------------------
# V-mart Retail Ltd (ISIN: INE665J01013):
#   143. As a carbon neutral company, V-mart Retail Ltd takes measures to encourage restoration.
# --------------------------------------------------
# V-mart Retail Ltd (ISIN: INE665J01013):
#   144. As a sustainable company, V-mart Retail Ltd takes measures to encourage energy efficiency.
# --------------------------------------------------
# V-mart Retail Ltd (ISIN: INE665J01013):
#   145. V-mart Retail Ltd is singled out for its damage.
# --------------------------------------------------
# V-mart Retail Ltd (ISIN: INE665J01013):
#   146. V-mart Retail Ltd values its integrity commitment and its respect for recoverable.
# --------------------------------------------------
# Truly International (ISIN: KYG910191363):
#   147. Truly International is dedicated to organic approaches and irresponsible initiatives.
# --------------------------------------------------
# Truly International (ISIN: KYG910191363):
#   148. Some question Truly International's commitment due to its risk.
# --------------------------------------------------
# Truly International (ISIN: KYG910191363):
#   149. Thanks to its eco-responsible initiative, Truly International strengthens its commitment to organic.
# --------------------------------------------------
# Nixu Oyj (ISIN: FI0009008387):
#   150. Nixu Oyj implements efficient practices to support renewable energy.
# --------------------------------------------------
# Nixu Oyj (ISIN: FI0009008387):
#   151. Nixu Oyj faces scrutiny for its excessive exploitation approach.
# --------------------------------------------------
# Nixu Oyj (ISIN: FI0009008387):
#   152. Nixu Oyj adopts a valorization strategy to promote responsible consumption.
# --------------------------------------------------
# Nixu Oyj (ISIN: FI0009008387):
#   153. Nixu Oyj is singled out for its inadequate.
# --------------------------------------------------
# Nixu Oyj (ISIN: FI0009008387):
#   154. The company Nixu Oyj is criticized for its lack of commitment to climate change.
# --------------------------------------------------
# Jiangxi Zhengbang Technology Co Ltd (ISIN: CNE1000006H2):
#   155. Jiangxi Zhengbang Technology Co Ltd is dedicated to well-being approaches and harm initiatives.
# --------------------------------------------------
# Jiangxi Zhengbang Technology Co Ltd (ISIN: CNE1000006H2):
#   156. Jiangxi Zhengbang Technology Co Ltd values its fair commitment and its respect for valorization.
# --------------------------------------------------
# Jiangxi Zhengbang Technology Co Ltd (ISIN: CNE1000006H2):
#   157. Jiangxi Zhengbang Technology Co Ltd implements sustainability practices to support fair.
# --------------------------------------------------
# Ourpalm (ISIN: CNE100001DH2):
#   158. The eco-tourism approach of Ourpalm reflects its commitment to eco-label.
# --------------------------------------------------
# Ourpalm (ISIN: CNE100001DH2):
#   159. As a eco-habitat company, Ourpalm takes measures to encourage zero waste.
# --------------------------------------------------
# Ourpalm (ISIN: CNE100001DH2):
#   160. Ourpalm values its responsible commitment and its respect for regeneration.
# --------------------------------------------------
# Ourpalm (ISIN: CNE100001DH2):
#   161. Ourpalm implements continuous improvement measures while considering dangerous.
# --------------------------------------------------
# Ourpalm (ISIN: CNE100001DH2):
#   162. Ourpalm is committed to energy efficiency actions and addressing deforestation.
# --------------------------------------------------
# Newell Brands Inc (ISIN: US6512291062):
#   163. Newell Brands Inc values its green energy commitment and its respect for healthy.
# --------------------------------------------------
# Newell Brands Inc (ISIN: US6512291062):
#   164. Through its integrity actions, Newell Brands Inc aims to improve eco-conscious.
# --------------------------------------------------
# Newell Brands Inc (ISIN: US6512291062):
#   165. Newell Brands Inc is under fire for its dangerous strategy.
# --------------------------------------------------
# Newell Brands Inc (ISIN: US6512291062):
#   166. Newell Brands Inc adopts a eco-responsible strategy to promote clean.
# --------------------------------------------------
# Shanghai Lingang Holdings Co Ltd (ISIN: CNE000000C74):
#   167. The company Shanghai Lingang Holdings Co Ltd is committed to a positive approach to promote valorization.
# --------------------------------------------------
# Shanghai Lingang Holdings Co Ltd (ISIN: CNE000000C74):
#   168. Shanghai Lingang Holdings Co Ltd is dedicated to eco-tourism approaches and deteriorate initiatives.
# --------------------------------------------------
# Shanghai Lingang Holdings Co Ltd (ISIN: CNE000000C74):
#   169. Shanghai Lingang Holdings Co Ltd implements zero waste measures while considering deteriorate.
# --------------------------------------------------
# Shanghai Lingang Holdings Co Ltd (ISIN: CNE000000C74):
#   170. Shanghai Lingang Holdings Co Ltd is singled out for its perilous.
# --------------------------------------------------
# Cigna Corp (ISIN: US1255231003):
#   171. Cigna Corp values its recoverable commitment and its respect for clean.
# --------------------------------------------------
# Cigna Corp (ISIN: US1255231003):
#   172. Thanks to its ethical initiative, Cigna Corp strengthens its commitment to solar energy.
# --------------------------------------------------
# Cigna Corp (ISIN: US1255231003):
#   173. Cigna Corp is dedicated to energy-efficient approaches and contamination initiatives.
# --------------------------------------------------
# Cigna Corp (ISIN: US1255231003):
#   174. Cigna Corp is developing sustainable mobility practices while managing toxicity.
# --------------------------------------------------
# Sundrug Co Ltd (ISIN: JP3336600006):
#   175. Through its renewable actions, Sundrug Co Ltd aims to improve eco-responsible.
# --------------------------------------------------
# Sundrug Co Ltd (ISIN: JP3336600006):
#   176. As a renewable company, Sundrug Co Ltd takes measures to encourage environmentally friendly.
# --------------------------------------------------
# Sundrug Co Ltd (ISIN: JP3336600006):
#   177. Sundrug Co Ltd adopts a green strategy to promote sustainability.
# --------------------------------------------------
# Frontken Corporation Bhd (ISIN: MYQ0128OO007):
#   178. Through its sustainability actions, Frontken Corporation Bhd aims to improve renewable energy.
# --------------------------------------------------
# Frontken Corporation Bhd (ISIN: MYQ0128OO007):
#   179. Frontken Corporation Bhd is developing ethical practices while managing overexploitation.
# --------------------------------------------------
# Frontken Corporation Bhd (ISIN: MYQ0128OO007):
#   180. Frontken Corporation Bhd is criticized for its failure to address deteriorate.
# --------------------------------------------------
# Kadokawa Corp (ISIN: JP3214350005):
#   181. Kadokawa Corp is under fire for its pollution strategy.
# --------------------------------------------------
# Kadokawa Corp (ISIN: JP3214350005):
#   182. Kadokawa Corp values its solar energy commitment and its respect for eco-innovation.
# --------------------------------------------------
# Kadokawa Corp (ISIN: JP3214350005):
#   183. Kadokawa Corp is criticized for its failure to address toxicity.
# --------------------------------------------------
# Siemens Ltd (ISIN: INE003A01024):
#   184. Siemens Ltd is exploring circular economy initiatives to address waste.
# --------------------------------------------------
# Siemens Ltd (ISIN: INE003A01024):
#   185. Siemens Ltd is recognized for its green energy approach and its positive impact on restoration.
# --------------------------------------------------
# Siemens Ltd (ISIN: INE003A01024):
#   186. Thanks to its conscious spreading initiative, Siemens Ltd strengthens its commitment to environmentally friendly.
# --------------------------------------------------
# Plains All American Pipeline LP (ISIN: US7265031051):
#   187. Plains All American Pipeline LP implements well-being practices to support greenhouse effect.
# --------------------------------------------------
# Plains All American Pipeline LP (ISIN: US7265031051):
#   188. Plains All American Pipeline LP values its integrity commitment and its respect for responsible.
# --------------------------------------------------
# Plains All American Pipeline LP (ISIN: US7265031051):
#   189. Plains All American Pipeline LP is recognized for its continuous improvement approach and its positive impact on integrity.
# --------------------------------------------------
# Plains All American Pipeline LP (ISIN: US7265031051):
#   190. Plains All American Pipeline LP's pollutant practices have raised concerns among environmentalists.
# --------------------------------------------------
# Guangzhou Yuexiu Financial Holdings Group Co Ltd (ISIN: CNE0000013M0):
#   191. Thanks to its permaculture initiative, Guangzhou Yuexiu Financial Holdings Group Co Ltd strengthens its commitment to permaculture.
# --------------------------------------------------
# Guangzhou Yuexiu Financial Holdings Group Co Ltd (ISIN: CNE0000013M0):
#   192. The company Guangzhou Yuexiu Financial Holdings Group Co Ltd is criticized for its lack of commitment to waste.
# --------------------------------------------------
# Guangzhou Yuexiu Financial Holdings Group Co Ltd (ISIN: CNE0000013M0):
#   193. Guangzhou Yuexiu Financial Holdings Group Co Ltd's illegal logging practices have raised concerns among environmentalists.
# --------------------------------------------------
# BAIC Motor Corp Ltd (ISIN: CNE100001TJ4):
#   194. BAIC Motor Corp Ltd's perilous initiative is viewed with skepticism.
# --------------------------------------------------
# BAIC Motor Corp Ltd (ISIN: CNE100001TJ4):
#   195. BAIC Motor Corp Ltd adopts a renewable energy strategy to promote responsible.
# --------------------------------------------------
# BAIC Motor Corp Ltd (ISIN: CNE100001TJ4):
#   196. Concerns are raised about BAIC Motor Corp Ltd's overexploitation practices.
# --------------------------------------------------
# BAIC Motor Corp Ltd (ISIN: CNE100001TJ4):
#   197. BAIC Motor Corp Ltd's renewable energy efforts are focused on deterioration.
# --------------------------------------------------
# BAIC Motor Corp Ltd (ISIN: CNE100001TJ4):
#   198. Concerns are raised about BAIC Motor Corp Ltd's threat practices.
# --------------------------------------------------
# CEZ as (ISIN: CZ0005112300):
#   199. The company CEZ as is committed to a positive approach to promote agroecology.
# --------------------------------------------------
# CEZ as (ISIN: CZ0005112300):
#   200. Concerns are raised about CEZ as's greenhouse gas emissions practices.
# --------------------------------------------------
# CEZ as (ISIN: CZ0005112300):
#   201. CEZ as is singled out for its irresponsible.
# --------------------------------------------------
# Shanying International Holdings (ISIN: CNE0000019B0):
#   202. As a eco-innovation company, Shanying International Holdings takes measures to encourage responsible.
# --------------------------------------------------
# Shanying International Holdings (ISIN: CNE0000019B0):
#   203. Shanying International Holdings is under fire for its inappropriate strategy.
# --------------------------------------------------
# Shanying International Holdings (ISIN: CNE0000019B0):
#   204. Concerns are raised about Shanying International Holdings's destructive practices.
# --------------------------------------------------
# Silvercrest Asset Management Group Inc (ISIN: US8283591092):
#   205. Silvercrest Asset Management Group Inc integrates continuous improvement strategies with deteriorate management.
# --------------------------------------------------
# Silvercrest Asset Management Group Inc (ISIN: US8283591092):
#   206. Silvercrest Asset Management Group Inc communicates about its conservation commitment and its positive contribution to restoration.
# --------------------------------------------------
# Silvercrest Asset Management Group Inc (ISIN: US8283591092):
#   207. Silvercrest Asset Management Group Inc faces scrutiny for its inadequate approach.
# --------------------------------------------------
# Silvercrest Asset Management Group Inc (ISIN: US8283591092):
#   208. Silvercrest Asset Management Group Inc's climate change initiative is viewed with skepticism.
# --------------------------------------------------
# Silvercrest Asset Management Group Inc (ISIN: US8283591092):
#   209. Silvercrest Asset Management Group Inc is criticized for its failure to address ecological damage.
# --------------------------------------------------
# Selcuk Ecza Deposu Ticaret ve Sanayi AS (ISIN: TRESLEC00014):
#   210. Thanks to its integrity initiative, Selcuk Ecza Deposu Ticaret ve Sanayi AS strengthens its commitment to zero waste.
# --------------------------------------------------
# Selcuk Ecza Deposu Ticaret ve Sanayi AS (ISIN: TRESLEC00014):
#   211. As a ecological company, Selcuk Ecza Deposu Ticaret ve Sanayi AS takes measures to encourage social responsibility.
# --------------------------------------------------
# Selcuk Ecza Deposu Ticaret ve Sanayi AS (ISIN: TRESLEC00014):
#   212. Selcuk Ecza Deposu Ticaret ve Sanayi AS faces scrutiny for its climate change approach.
# --------------------------------------------------
# Selcuk Ecza Deposu Ticaret ve Sanayi AS (ISIN: TRESLEC00014):
#   213. The sustainable mobility approach of Selcuk Ecza Deposu Ticaret ve Sanayi AS reflects its commitment to conscious consumption.
# --------------------------------------------------
# Selcuk Ecza Deposu Ticaret ve Sanayi AS (ISIN: TRESLEC00014):
#   214. The company Selcuk Ecza Deposu Ticaret ve Sanayi AS is committed to a efficiency approach to promote social responsibility.
# --------------------------------------------------
# Universal Health Services Inc (ISIN: US9139031002):
#   215. Universal Health Services Inc values its conscious consumption commitment and its respect for sustainable mobility.
# --------------------------------------------------
# Universal Health Services Inc (ISIN: US9139031002):
#   216. Universal Health Services Inc adopts a eco-citizen strategy to promote biodiversity.
# --------------------------------------------------
# Universal Health Services Inc (ISIN: US9139031002):
#   217. Universal Health Services Inc is committed to efficiency actions and addressing resource plundering.
# --------------------------------------------------
# Kajima Corp (ISIN: JP3210200006):
#   218. The eco-friendly approach of Kajima Corp reflects its commitment to preservation.
# --------------------------------------------------
# Kajima Corp (ISIN: JP3210200006):
#   219. Kajima Corp adopts a sustainable mobility strategy to promote organic.
# --------------------------------------------------
# Kajima Corp (ISIN: JP3210200006):
#   220. Through its preservation actions, Kajima Corp aims to improve wind energy.
# --------------------------------------------------
# Lightwave Logic Inc (ISIN: US5322751042):
#   221. Lightwave Logic Inc values its recycling commitment and its respect for integrity.
# --------------------------------------------------
# Lightwave Logic Inc (ISIN: US5322751042):
#   222. Lightwave Logic Inc's organic efforts are focused on environmental degradation.
# --------------------------------------------------
# Lightwave Logic Inc (ISIN: US5322751042):
#   223. Through its carbon neutral actions, Lightwave Logic Inc aims to improve ecological.
# --------------------------------------------------
# Methanex Corp (ISIN: CA59151K1084):
#   224. Methanex Corp implements conscious consumption measures while considering destructive.
# --------------------------------------------------
# Methanex Corp (ISIN: CA59151K1084):
#   225. The eco-label approach of Methanex Corp reflects its commitment to healthy.
# --------------------------------------------------
# Methanex Corp (ISIN: CA59151K1084):
#   226. Methanex Corp's recovery efforts are focused on inappropriate.
# --------------------------------------------------
# Methanex Corp (ISIN: CA59151K1084):
#   227. The company Methanex Corp is criticized for its lack of commitment to resource plundering.
# --------------------------------------------------
# Powerchip Semiconductor Manufacturing Corp (ISIN: TW0006770001):
#   228. Powerchip Semiconductor Manufacturing Corp values its circular economy commitment and its respect for eco-innovation.
# --------------------------------------------------
# Powerchip Semiconductor Manufacturing Corp (ISIN: TW0006770001):
#   229. Powerchip Semiconductor Manufacturing Corp communicates about its recycling commitment and its positive contribution to green.
# --------------------------------------------------
# Powerchip Semiconductor Manufacturing Corp (ISIN: TW0006770001):
#   230. The company Powerchip Semiconductor Manufacturing Corp is committed to a preservation approach to promote conscious consumption.
# --------------------------------------------------
# Powerchip Semiconductor Manufacturing Corp (ISIN: TW0006770001):
#   231. Powerchip Semiconductor Manufacturing Corp implements ecological practices to support restorer.
# --------------------------------------------------
# Powerchip Semiconductor Manufacturing Corp (ISIN: TW0006770001):
#   232. Powerchip Semiconductor Manufacturing Corp values its clean energy commitment and its respect for permaculture.
# --------------------------------------------------
# General Electric Co (ISIN: US3696041033):
#   233. The approach of General Electric Co involves positive methods to mitigate harmful.
# --------------------------------------------------
# General Electric Co (ISIN: US3696041033):
#   234. General Electric Co's sustainable efforts are focused on inadequate.
# --------------------------------------------------
# General Electric Co (ISIN: US3696041033):
#   235. The company General Electric Co is researching valorization solutions for ecological damage.
# --------------------------------------------------
# General Electric Co (ISIN: US3696041033):
#   236. The company General Electric Co is researching circular economy solutions for contamination.
# --------------------------------------------------
# Ardent Leisure Group Ltd (ISIN: AU0000027484):
#   237. As a fair company, Ardent Leisure Group Ltd takes measures to encourage green energy.
# --------------------------------------------------
# Ardent Leisure Group Ltd (ISIN: AU0000027484):
#   238. Ardent Leisure Group Ltd integrates ecological strategies with pollution management.
# --------------------------------------------------
# Ardent Leisure Group Ltd (ISIN: AU0000027484):
#   239. As a continuous improvement company, Ardent Leisure Group Ltd takes measures to encourage recoverable.
# --------------------------------------------------
# Ardent Leisure Group Ltd (ISIN: AU0000027484):
#   240. Ardent Leisure Group Ltd values its sustainable commitment and its respect for conscious consumption.
# --------------------------------------------------
# Ardent Leisure Group Ltd (ISIN: AU0000027484):
#   241. Ardent Leisure Group Ltd is developing efficient practices while managing risk.
# --------------------------------------------------
# GXO Logistics Inc (ISIN: US36262G1013):
#   242. Some question GXO Logistics Inc's commitment due to its illegal logging.
# --------------------------------------------------
# GXO Logistics Inc (ISIN: US36262G1013):
#   243. GXO Logistics Inc values its fair commitment and its respect for valorization.
# --------------------------------------------------
# GXO Logistics Inc (ISIN: US36262G1013):
#   244. GXO Logistics Inc values its responsible commitment and its respect for positive.
# --------------------------------------------------
# GXO Logistics Inc (ISIN: US36262G1013):
#   245. GXO Logistics Inc is criticized for its failure to address wasteful.
# --------------------------------------------------
# GXO Logistics Inc (ISIN: US36262G1013):
#   246. GXO Logistics Inc is recognized for its well-being approach and its positive impact on biodiversity.
# --------------------------------------------------
# Contact Energy Ltd (ISIN: NZCENE0001S6):
#   247. Concerns are raised about Contact Energy Ltd's deteriorate practices.
# --------------------------------------------------
# Contact Energy Ltd (ISIN: NZCENE0001S6):
#   248. Concerns are raised about Contact Energy Ltd's overexploitation practices.
# --------------------------------------------------
# Contact Energy Ltd (ISIN: NZCENE0001S6):
#   249. Contact Energy Ltd communicates about its eco-citizen commitment and its positive contribution to ecological.
# --------------------------------------------------
# Teleste Oyj (ISIN: FI0009007728):
#   250. Through its eco-tourism actions, Teleste Oyj aims to improve responsible.
# --------------------------------------------------
# Teleste Oyj (ISIN: FI0009007728):
#   251. Teleste Oyj integrates recoverable strategies with deterioration management.
# --------------------------------------------------
# Teleste Oyj (ISIN: FI0009007728):
#   252. Concerns are raised about Teleste Oyj's greenhouse gas emissions practices.
# --------------------------------------------------
# Teleste Oyj (ISIN: FI0009007728):
#   253. Thanks to its regenerator initiative, Teleste Oyj strengthens its commitment to solar energy.
# --------------------------------------------------
# Gateway Real Estate AG (ISIN: DE000A0JJTG7):
#   254. Gateway Real Estate AG is developing preservation practices while managing pollute.
# --------------------------------------------------
# Gateway Real Estate AG (ISIN: DE000A0JJTG7):
# ...
# --------------------------------------------------
# Qatar National Bank QPSC (ISIN: QA0006929895):
#   322. Qatar National Bank QPSC values its clean energy commitment and its respect for eco-conscious.
# --------------------------------------------------
# Qatar National Bank QPSC (ISIN: QA0006929895):
#   323. Qatar National Bank QPSC's environmental denial practices have raised concerns among environmentalists.
# --------------------------------------------------
# Rain Industries Ltd (ISIN: INE855B01025):
#   324. As a recycling company, Rain Industries Ltd takes measures to encourage agroecology.
# --------------------------------------------------
# Rain Industries Ltd (ISIN: INE855B01025):
#   325. Rain Industries Ltd is recognized for its eco-conscious approach and its positive impact on ecological.
# --------------------------------------------------
# Rain Industries Ltd (ISIN: INE855B01025):
#   326. Rain Industries Ltd communicates about its healthy commitment and its positive contribution to circular economy.
# --------------------------------------------------
# Shenzhen Airport Co Ltd (ISIN: CNE000000VK1):
#   327. Shenzhen Airport Co Ltd values its eco-tourism commitment and its respect for innovative.
# --------------------------------------------------
# Shenzhen Airport Co Ltd (ISIN: CNE000000VK1):
#   328. Shenzhen Airport Co Ltd integrates innovative strategies with greenhouse gas emissions management.
# --------------------------------------------------
# Shenzhen Airport Co Ltd (ISIN: CNE000000VK1):
#   329. Shenzhen Airport Co Ltd adopts a restorer strategy to promote energy-efficient.
# --------------------------------------------------
# Shenzhen Airport Co Ltd (ISIN: CNE000000VK1):
#   330. Shenzhen Airport Co Ltd is exploring harmony initiatives to address catastrophic.
# --------------------------------------------------
# Shenzhen Airport Co Ltd (ISIN: CNE000000VK1):
#   331. Shenzhen Airport Co Ltd's inadequate initiative is viewed with skepticism.
# --------------------------------------------------
# Autobio Diagnostics Co Ltd (ISIN: CNE100002GC4):
#   332. Autobio Diagnostics Co Ltd's irreparable practices have raised concerns among environmentalists.
# --------------------------------------------------
# Autobio Diagnostics Co Ltd (ISIN: CNE100002GC4):
#   333. Autobio Diagnostics Co Ltd communicates about its prosperity commitment and its positive contribution to fair.
# --------------------------------------------------
# Autobio Diagnostics Co Ltd (ISIN: CNE100002GC4):
#   334. Concerns are raised about Autobio Diagnostics Co Ltd's harm practices.
# --------------------------------------------------
# Aegon NV (ISIN: NL0000303709):
#   335. Thanks to its eco-innovation initiative, Aegon NV strengthens its commitment to carbon neutral.
# --------------------------------------------------
# Aegon NV (ISIN: NL0000303709):
#   336. Aegon NV is recognized for its regeneration approach and its positive impact on well-being.
# --------------------------------------------------
# Aegon NV (ISIN: NL0000303709):
#   337. Aegon NV's illegal logging initiative is viewed with skepticism.
# --------------------------------------------------
# Aegon NV (ISIN: NL0000303709):
#   338. Aegon NV values its prosperity commitment and its respect for prosperity.
# --------------------------------------------------
# Aegon NV (ISIN: NL0000303709):
#   339. Aegon NV is recognized for its restorer approach and its positive impact on sustainable mobility.
# --------------------------------------------------
# Carlisle Companies Inc (ISIN: US1423391002):
#   340. Carlisle Companies Inc integrates ethical strategies with toxic management.
# --------------------------------------------------
# Carlisle Companies Inc (ISIN: US1423391002):
#   341. Carlisle Companies Inc communicates about its efficiency commitment and its positive contribution to efficiency.
# --------------------------------------------------
# Carlisle Companies Inc (ISIN: US1423391002):
#   342. Concerns are raised about Carlisle Companies Inc's disruption practices.
# --------------------------------------------------
# Carlisle Companies Inc (ISIN: US1423391002):
#   343. Carlisle Companies Inc is committed to sustainable mobility actions and addressing contamination.
# --------------------------------------------------
# Pool Corp (ISIN: US73278L1052):
#   344. The company Pool Corp is criticized for its lack of commitment to resource plundering.
# --------------------------------------------------
# Pool Corp (ISIN: US73278L1052):
#   345. Some question Pool Corp's commitment due to its spoil.
# --------------------------------------------------
# Pool Corp (ISIN: US73278L1052):
#   346. Pool Corp is exploring zero waste initiatives to address hazardous.
# --------------------------------------------------
# Tidewater Midstream and Infrastructure Ltd (ISIN: CA8864531097):
#   347. Tidewater Midstream and Infrastructure Ltd implements green practices to support ecological.
# --------------------------------------------------
# Tidewater Midstream and Infrastructure Ltd (ISIN: CA8864531097):
#   348. Tidewater Midstream and Infrastructure Ltd faces scrutiny for its pollution approach.
# --------------------------------------------------
# Tidewater Midstream and Infrastructure Ltd (ISIN: CA8864531097):
#   349. Through its recoverable actions, Tidewater Midstream and Infrastructure Ltd aims to improve biodiversity.
# --------------------------------------------------
# Maten Petroleum AO (ISIN: KZ1C00000868):
#   350. Maten Petroleum AO is under fire for its dangerous strategy.
# --------------------------------------------------
# Maten Petroleum AO (ISIN: KZ1C00000868):
#   351. Maten Petroleum AO integrates green energy strategies with irresponsible management.
# --------------------------------------------------
# Maten Petroleum AO (ISIN: KZ1C00000868):
#   352. The company Maten Petroleum AO is committed to a eco-habitat approach to promote eco-design.
# --------------------------------------------------
# Maten Petroleum AO (ISIN: KZ1C00000868):
#   353. Maten Petroleum AO communicates about its renewable commitment and its positive contribution to regenerator.
# --------------------------------------------------
# Regional Management Corp (ISIN: US75902K1060):
#   354. Regional Management Corp is dedicated to efficiency approaches and deforestation initiatives.
# --------------------------------------------------
# Regional Management Corp (ISIN: US75902K1060):
#   355. Regional Management Corp is singled out for its environmental degradation.
# --------------------------------------------------
# Regional Management Corp (ISIN: US75902K1060):
#   356. Through its recovery actions, Regional Management Corp aims to improve environmentally friendly.
# --------------------------------------------------
# Regional Management Corp (ISIN: US75902K1060):
#   357. Regional Management Corp adopts a innovative strategy to promote rehabilitation.
# --------------------------------------------------
# Regional Management Corp (ISIN: US75902K1060):
#   358. Regional Management Corp's wind energy efforts are focused on contamination.
# --------------------------------------------------
# Soitec SA (ISIN: FR0013227113):
#   359. The company Soitec SA is committed to a efficient approach to promote renewable energy.
# --------------------------------------------------
# Soitec SA (ISIN: FR0013227113):
#   360. Thanks to its rehabilitation initiative, Soitec SA strengthens its commitment to eco-habitat.
# --------------------------------------------------
# Soitec SA (ISIN: FR0013227113):
#   361. Soitec SA values its clean energy commitment and its respect for conscious consumption.
# --------------------------------------------------
# Soitec SA (ISIN: FR0013227113):
#   362. As a environmentally friendly company, Soitec SA takes measures to encourage renewable.
# --------------------------------------------------
# Soitec SA (ISIN: FR0013227113):
#   363. Thanks to its well-being initiative, Soitec SA strengthens its commitment to eco-efficient.
# --------------------------------------------------
# Neurocrine Biosciences Inc (ISIN: US64125C1099):
#   364. Neurocrine Biosciences Inc is singled out for its overconsumption.
# --------------------------------------------------
# Neurocrine Biosciences Inc (ISIN: US64125C1099):
#   365. Neurocrine Biosciences Inc's resource plundering initiative is viewed with skepticism.
# --------------------------------------------------
# Neurocrine Biosciences Inc (ISIN: US64125C1099):
#   366. Neurocrine Biosciences Inc's permaculture efforts are focused on worrisome.
# --------------------------------------------------
# Neurocrine Biosciences Inc (ISIN: US64125C1099):
#   367. Neurocrine Biosciences Inc implements eco-label measures while considering harmful.
# --------------------------------------------------
# PacWest Bancorp (ISIN: US6952631033):
#   368. PacWest Bancorp implements green energy measures while considering deforestation.
# --------------------------------------------------
# PacWest Bancorp (ISIN: US6952631033):
#   369. PacWest Bancorp faces scrutiny for its irresponsible approach.
# --------------------------------------------------
# PacWest Bancorp (ISIN: US6952631033):
#   370. PacWest Bancorp implements zero waste practices to support fair.
# --------------------------------------------------
# PacWest Bancorp (ISIN: US6952631033):
#   371. PacWest Bancorp is recognized for its well-being approach and its positive impact on rehabilitation.
# --------------------------------------------------
# PacWest Bancorp (ISIN: US6952631033):
#   372. PacWest Bancorp adopts a valorization strategy to promote well-being.
# --------------------------------------------------
# Financiere Moncey SA (ISIN: FR0000076986):
#   373. The company Financiere Moncey SA is committed to a positive approach to promote clean.
# --------------------------------------------------
# Financiere Moncey SA (ISIN: FR0000076986):
#   374. Financiere Moncey SA is committed to healthy actions and addressing overexploitation.
# --------------------------------------------------
# Financiere Moncey SA (ISIN: FR0000076986):
#   375. As a eco-conscious company, Financiere Moncey SA takes measures to encourage regenerator.
# --------------------------------------------------
# Financiere Moncey SA (ISIN: FR0000076986):
#   376. Financiere Moncey SA is recognized for its circular economy approach and its positive impact on well-being.
# --------------------------------------------------
# AeroVironment Inc (ISIN: US0080731088):
#   377. AeroVironment Inc integrates ethical strategies with destroyed natural habitat management.
# --------------------------------------------------
# AeroVironment Inc (ISIN: US0080731088):
#   378. As a recovery company, AeroVironment Inc takes measures to encourage regeneration.
# --------------------------------------------------
# AeroVironment Inc (ISIN: US0080731088):
#   379. AeroVironment Inc implements recovery practices to support organic.
# --------------------------------------------------
# AeroVironment Inc (ISIN: US0080731088):
#   380. Concerns are raised about AeroVironment Inc's irresponsible practices.
# --------------------------------------------------
# AeroVironment Inc (ISIN: US0080731088):
#   381. AeroVironment Inc is committed to clean energy actions and addressing catastrophic.
# --------------------------------------------------
# WuXi Biologics (Cayman) Inc (ISIN: KYG970081090):
#   382. WuXi Biologics (Cayman) Inc is criticized for its failure to address inappropriate.
# --------------------------------------------------
# WuXi Biologics (Cayman) Inc (ISIN: KYG970081090):
#   383. The company WuXi Biologics (Cayman) Inc is researching rehabilitation solutions for spoil.
# --------------------------------------------------
# WuXi Biologics (Cayman) Inc (ISIN: KYG970081090):
#   384. WuXi Biologics (Cayman) Inc is dedicated to valorization approaches and dangerous initiatives.
# --------------------------------------------------
# WuXi Biologics (Cayman) Inc (ISIN: KYG970081090):
#   385. WuXi Biologics (Cayman) Inc's eco-friendly efforts are focused on pollution.
# --------------------------------------------------
# WuXi Biologics (Cayman) Inc (ISIN: KYG970081090):
#   386. WuXi Biologics (Cayman) Inc communicates about its conscious spreading commitment and its positive contribution to social responsibility.
# --------------------------------------------------
# Saputo Inc (ISIN: CA8029121057):
#   387. As a eco-label company, Saputo Inc takes measures to encourage fair.
# --------------------------------------------------
# Saputo Inc (ISIN: CA8029121057):
#   388. Saputo Inc's recycling efforts are focused on pollution.
# --------------------------------------------------
# Saputo Inc (ISIN: CA8029121057):
#   389. Saputo Inc integrates clean energy strategies with disrespectful management.
# --------------------------------------------------
# Air China Ltd (ISIN: CNE000001NN0):
#   390. As a sustainability company, Air China Ltd takes measures to encourage beneficial.
# --------------------------------------------------
# Air China Ltd (ISIN: CNE000001NN0):
#   391. The approach of Air China Ltd involves eco-efficient methods to mitigate contamination.
# --------------------------------------------------
# Air China Ltd (ISIN: CNE000001NN0):
#   392. Air China Ltd implements efficient practices to support eco-label.
# --------------------------------------------------
# Air China Ltd (ISIN: CNE000001NN0):
#   393. The company Air China Ltd is committed to a well-being approach to promote integrity.
# --------------------------------------------------
# Air China Ltd (ISIN: CNE000001NN0):
#   394. Air China Ltd is dedicated to eco-responsible approaches and harmful initiatives.
# --------------------------------------------------
# Eurofins Scientific SE (ISIN: FR0000038259):
#   395. Eurofins Scientific SE communicates about its healthy commitment and its positive contribution to well-being.
# --------------------------------------------------
# Eurofins Scientific SE (ISIN: FR0000038259):
#   396. The company Eurofins Scientific SE is committed to a regeneration approach to promote renewable energy.
# --------------------------------------------------
# Eurofins Scientific SE (ISIN: FR0000038259):
#   397. Eurofins Scientific SE communicates about its responsible commitment and its positive contribution to energy-efficient.
# --------------------------------------------------
# Eurofins Scientific SE (ISIN: FR0000038259):
#   398. The company Eurofins Scientific SE is committed to a continuous improvement approach to promote eco-innovation.
# --------------------------------------------------
# Eurofins Scientific SE (ISIN: FR0000038259):
#   399. Eurofins Scientific SE is singled out for its inappropriate.
# --------------------------------------------------
# Brilliance China Automotive Holdings Ltd (ISIN: BMG1368B1028):
#   400. Brilliance China Automotive Holdings Ltd integrates conservation strategies with waste management.
# --------------------------------------------------
# Brilliance China Automotive Holdings Ltd (ISIN: BMG1368B1028):
#   401. Brilliance China Automotive Holdings Ltd's spoil practices have raised concerns among environmentalists.
# --------------------------------------------------
# Brilliance China Automotive Holdings Ltd (ISIN: BMG1368B1028):
#   402. Through its conscious consumption actions, Brilliance China Automotive Holdings Ltd aims to improve sustainable.
# --------------------------------------------------
# Tarsus Pharmaceuticals Inc (ISIN: US87650L1035):
#   403. Tarsus Pharmaceuticals Inc adopts a conscious consumption strategy to promote conscious consumption.
# --------------------------------------------------
# Tarsus Pharmaceuticals Inc (ISIN: US87650L1035):
#   404. Tarsus Pharmaceuticals Inc communicates about its circular economy commitment and its positive contribution to preservation.
# --------------------------------------------------
# Tarsus Pharmaceuticals Inc (ISIN: US87650L1035):
#   405. Tarsus Pharmaceuticals Inc is singled out for its resource plundering.
# --------------------------------------------------

# %% [markdown]
# On cherche maintenant à insérer une phrase dans le texte, cette insertion se fera de manière aléatoire, la phrase suivra un point. Ainsi, on pourra mettre dans cette phrase le nom d'une entreprise.

# %%
# Créer une nouvelle colonne "Entreprise_Insérée" dans le DataFrame
data['Entreprise_Insérée_1'] = None

# Remplir la colonne avec les noms des entreprises
for idx, (company, _) in enumerate(company_sentences.items()):
    data.at[idx, 'Entreprise_Insérée_1'] = company

# Afficher les premières lignes du DataFrame pour vérification
data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID           Entreprise_Insérée_1
# 0    NYTF000020240104ejcv0000d         Kirloskar Brothers Ltd
# 1    NYTF000020231231ejcv0006h                       Seer Inc
# 2   NYTF000020231231ejcv00064   Samsung Life Insurance Co Ltd
# 3   NYTF000020231231ejcv00063              Kontoor Brands Inc
# 4   NYTF000020231231ejcv0005z        Tauron Polska Energia SA

# %%
# Créer une nouvelle colonne "ISIN" dans le DataFrame
data['ISIN'] = None

# Remplir la colonne avec les ISIN correspondants aux noms des entreprises
for idx, (company, isin) in enumerate(zip(random_companies['Company'], random_companies['ISIN'])):
    data.loc[data['Entreprise_Insérée_1'] == company, 'ISIN'] = isin

# Afficher les premières lignes du DataFrame pour vérification
data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID           Entreprise_Insérée_1          ISIN
# 0    NYTF000020240104ejcv0000d         Kirloskar Brothers Ltd  INE732A01036
# 1    NYTF000020231231ejcv0006h                       Seer Inc  US81578P1066
# 2   NYTF000020231231ejcv00064   Samsung Life Insurance Co Ltd  KR7032830002
# 3   NYTF000020231231ejcv00063              Kontoor Brands Inc  US50050N1037
# 4   NYTF000020231231ejcv0005z        Tauron Polska Energia SA  PLTAURN00011

# %%
# Créer une nouvelle colonne pour les articles avec phrases insérées
data['Coeur_Article_Inséré_1'] = ""

# Insérer les phrases générées dans les articles
for company, sentences in company_sentences.items():
    article = data[data['Entreprise_Insérée_1'] == company]['Coeur_Article'].iloc[0]  # Récupérer l'article associé à l'entreprise
    for sentence in sentences:
        article = insertion_phrase_dans_article(sentence, article)
    data.loc[data['Entreprise_Insérée_1'] == company, 'Coeur_Article_Inséré_1'] = article  # Mettre à jour l'article dans la nouvelle colonne

data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID           Entreprise_Insérée_1          ISIN  \
# 0    NYTF000020240104ejcv0000d         Kirloskar Brothers Ltd  INE732A01036
# 1    NYTF000020231231ejcv0006h                       Seer Inc  US81578P1066
# 2   NYTF000020231231ejcv00064   Samsung Life Insurance Co Ltd  KR7032830002
# 3   NYTF000020231231ejcv00063              Kontoor Brands Inc  US50050N1037
# 4   NYTF000020231231ejcv0005z        Tauron Polska Energia SA  PLTAURN00011
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %%
# Enregistrer en tant que fichier pickle pour conserver les types de données
data.to_pickle('data_avec_entreprises_1.pkl')

# %% [markdown]
# ### Méthode 2

# %% [markdown]
# Ici, on cherche juste à insérer de manière aléatoire, le nom d'entreprises dans un article. Pour cela, on créer une fonction qui tire au sort le nombre d'entreprises à insérer dans un article donné, puis on insert toutes ces entreprises dans les articles. Ici : 1 article = plusieurs entreprises

# %% [markdown]
# On choisit aléatoirement le nombre d'entreprises à insérer dans le texte (en contrôlant que ce nombre soit borné : on pourra nous même définir les bornes)

# %%
import pandas as pd

# Liste de noms d'entreprises
noms_entreprises = pd.read_csv('Firms.csv')['Company'].tolist()

# Fonction pour sélectionner aléatoirement un nombre d'entreprises entre a et b
def choisir_entreprises(a, b):
    # Assurez-vous que b est inférieur ou égal à la longueur de la liste des noms d'entreprises
    b = min(b, len(noms_entreprises))
    # Choisissez un nombre aléatoire d'entreprises compris entre a et b
    nb_entreprises = random.randint(a, b)
    return random.sample(noms_entreprises, nb_entreprises)

choisir_entreprises(1,2)
# Out:
# ['City Bank Ltd', 'Fomento Economico Mexicano SAB de CV']

# %% [markdown]
# On insert toutes ces entreprises dans un texte

# %%
entreprises_a_inserer = choisir_entreprises(1,2)
article_insertion = data['Coeur_Article'][8]

for entreprise in entreprises_a_inserer:
    article_insertion = insertion_phrase_dans_article(entreprise, article_insertion)
    
print(entreprises_a_inserer, article_insertion)
# Out:
# ['Tricon Residential Inc']
#
# A Few Days Full of Trouble: Revelations on the Journey to Justice for My Cousin and Best Friend, Emmett Till, by the Rev. Wheeler Parker Jr. and Christopher Benson. (One World, 432 pp., $18.99.) ''I have known the truth,'' Parker writes again and again in this moving memoir, recounting his family's devastation at the 1955 lynching of his cousin, his life as a minister resisting racism and the aftermath of the F.B.I.'s 2018 "reawakening'' of Till's murder case.
#
# Age of Vice, by Deepti Kapoor. (Riverhead, 560 pp., $20.) Kapoor's thriller ushers readers through the underbelly of contemporary New Delhi. It follows Ajay, a servant of a powerful crime family, charged with protecting their eldest son. But as a journalist narrows in on the family's misdeeds amid a deadly incident, Ajay must increasingly shield himself. Tricon Residential Inc
#
# Roses, in the Mouth of a Lion, by Bushra Rehman. (Flatiron, 288 pp., $17.99.) In 1980s Queens, Razia bristles at the rigid expectations of her immigrant community and finds queer love at her Manhattan high school. When an aunty's observation imperils Razia's newfound freedom, Rehman complicates conceptions of culture. In this warm New York novel, ''individuals are allowed to be surprising, even to themselves,'' our reviewer wrote.
#
# Saving Time: Discovering a Life Beyond Productivity Culture, by Jenny Odell. (Random House, 416 pp., $20.) The author of ''How to Do Nothing'' returns with a meditation on the ways modern society puts pressure on time. Using a day she spent in the Bay Area as a frame to consider labor, leisure, colonialism and climate, Odell argues for a radical shift in how we conceptualize both agency and change.
#
# How to Sell a Haunted House, by Grady Hendrix. (Berkley, 448 pp., $18.) When Louise's parents unexpectedly die, she agrees to help her brother Matt sell their house. Waiting there for them is Pupkin, a puppet who was their mother's oldest friend; who has ''all the sly traits of a vindictive, psychopathic sibling,'' according to our horror columnist Danielle Trussoni; and who has no intention of letting Louise and Matt grieve in peace.
#
# Beaverland: How One Weird Rodent Made America, by Leila Philip. (Twelve, 352 pp., $19.99.) Touching on their sacred status with some Indigenous groups, the pre-colonial fur trade that nearly rendered them extinct and present-day conservation efforts, Philip mounts an impassioned defense of beavers. Like people, they are animals ''that radically transform their environment,'' she writes.
#
# This article appeared in print on page BR20.

# %% [markdown]
# #### Automatisation pour tout les articles

# %%
import warnings
warnings.filterwarnings("ignore")

nb_min_entreprise_par_article = 1
nb_max_entreprise_par_article = 2
liste_articles = data['Coeur_Article'].tolist()
data['Article_avec_entreprises_2'] = None
data['Entreprises_inserees_2'] = None


for article in liste_articles:
    numero_article = liste_articles.index(article)
    entreprises_a_inserer = choisir_entreprises(nb_min_entreprise_par_article, nb_max_entreprise_par_article)
    
    for entreprise in entreprises_a_inserer:
        article = insertion_phrase_dans_article(entreprise, article)
        
    data['Entreprises_inserees_2'][numero_article] = entreprises_a_inserer
    data['Article_avec_entreprises_2'][numero_article] = article

data.insert(1,'Entreprises_inserées_2', data['Entreprises_inserees_2'])
data.pop('Entreprises_inserees_2')

data.insert(2,'Articles_avec_entreprises_2', data['Article_avec_entreprises_2'])
data.pop('Article_avec_entreprises_2')

data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                               Entreprises_inserées_2  \
# 0    [Haohua Chemical Science & Technology Corp Ltd]
# 1  [Sensys Gatso Group AB, Banque Cantonale Vaudo...
# 2                  [Canfor Corp, Halfords Group PLC]
# 3  [Victory Capital Holdings Inc, China Yuhua Edu...
# 4  [Princeton Bancorp Inc, Financial Institutions...
#
#                          Articles_avec_entreprises_2  \
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID           Entreprise_Insérée_1          ISIN  \
# 0    NYTF000020240104ejcv0000d         Kirloskar Brothers Ltd  INE732A01036
# 1    NYTF000020231231ejcv0006h                       Seer Inc  US81578P1066
# 2   NYTF000020231231ejcv00064   Samsung Life Insurance Co Ltd  KR7032830002
# 3   NYTF000020231231ejcv00063              Kontoor Brands Inc  US50050N1037
# 4   NYTF000020231231ejcv0005z        Tauron Polska Energia SA  PLTAURN00011
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %%
data_avec_entreprises = data
data_avec_entreprises.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                               Entreprises_inserées_2  \
# 0    [Haohua Chemical Science & Technology Corp Ltd]
# 1  [Sensys Gatso Group AB, Banque Cantonale Vaudo...
# 2                  [Canfor Corp, Halfords Group PLC]
# 3  [Victory Capital Holdings Inc, China Yuhua Edu...
# 4  [Princeton Bancorp Inc, Financial Institutions...
#
#                          Articles_avec_entreprises_2  \
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID           Entreprise_Insérée_1          ISIN  \
# 0    NYTF000020240104ejcv0000d         Kirloskar Brothers Ltd  INE732A01036
# 1    NYTF000020231231ejcv0006h                       Seer Inc  US81578P1066
# 2   NYTF000020231231ejcv00064   Samsung Life Insurance Co Ltd  KR7032830002
# 3   NYTF000020231231ejcv00063              Kontoor Brands Inc  US50050N1037
# 4   NYTF000020231231ejcv0005z        Tauron Polska Energia SA  PLTAURN00011
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %% [markdown]
# ## Exportation du nouveau tableau des données

# %%
# Enregistrer en tant que fichier pickle pour conserver les types de données
data_avec_entreprises.to_pickle('data_avec_entreprises_2.pkl')

# %% [markdown]
# # Cohérence de texte

# %% [markdown]
# On prends un texte au hasard, et on regarde si les phrases insérees sont cohérentes entre elles, et avec le texte

# %%
print("L'entreprise identifie pour ce texte est :",data['Entreprise_Insérée_1'][3], data['Coeur_Article_Inséré_1'][3])
# Out:
# L'entreprise identifie pour ce texte est : Kontoor Brands Inc
#
# LET KIDS
#
# VOTE!
#
# by Katherine Cusumano
#
# Julia Rottenberg, 17, spent the fall of last year knocking on doors. Kontoor Brands Inc is committed to organic actions and addressing malevolent. On Election Day 2022, people in Culver City, Calif. Concerns are raised about Kontoor Brands Inc's inappropriate practices. Kontoor Brands Inc is dedicated to energy efficiency approaches and greenhouse gas emissions initiatives., her hometown, would have a big decision to make: Should the voting age for local elections change from 18 to 16? Julia wanted them to vote yes. ''I think a vote is one of the most direct ways that you can express an opinion and actually have some change happen,'' says Julia, who is part of an organization called Vote16 Culver City.
#
# What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources. Yes, young people are already leading political movements around these issues. But without the vote, they can't elect politicians who represent their views and make real change. ''There's a whole lot of talk about prioritizing young people and politicians saying, 'We care about your future,''' says Jessie Cai, 16, a teen organizer with Voters of Tomorrow in Maryland. Voting would be a way to hold them to their promises.
#
# In some places, the change is already underway. In the past 10 years, residents in a handful of American towns (a few in Maryland, one in Vermont and two in California) have all approved lowering the voting age to 16 in local elections. Teenagers are campaigning to do the same in states from New Jersey to Oregon. A member of Congress has even been pushing to change the federal voting age. And if you think the whole idea seems too out there, think about this: It used to be that you actually had to be 21 to vote. Kontoor Brands Inc integrates greenhouse effect strategies with dangerous management. But during the Vietnam War, lots of people argued that if 18-year-olds were being forced to fight, they should also be able to vote. So in 1971, the age was lowered.
#
# Still, not everyone thinks 16-year-olds are ready for the responsibility -- including the voters in Culver City, where the measure lost by just 16 votes. ''I would be lying if I said it wasn't a little bit frustrating,'' Julia says. But the fact that the loss was so narrow has just made her and other Vote16 teenagers more motivated to try again this year: ''It proves to me how much each individual voice matters.'' â—Š
#
# *Thank you to the following schools: Holmes Elementary in Spokane, Wash.; Johnsontown Road Elementary in Louisville, Ky.; Frank D. Spaziano Elementary in Providence, R.I.; and Jefferson Elementary in San Diego.
#
# This article appeared in print on page MK3.

# %% [markdown]
# Les phrases insérées sont :
#
#   1. As a beneficial company, Kontoor Brands Inc takes measures to encourage eco-innovation.
#   2. As a clean company, Kontoor Brands Inc takes measures to encourage energy-efficient.
#   3. Kontoor Brands Inc is recognized for its sustainability approach and its positive impact on clean energy.
#   4. The revitalization approach of Kontoor Brands Inc reflects its commitment to fulfillment.
#
# ou en français :
#
#    1. En tant qu'entreprise bénéfique, Kontoor Brands Inc prend des mesures pour encourager l'éco-innovation.
#    2. En tant qu'entreprise propre, Kontoor Brands Inc prend des mesures pour encourager l'efficacité énergétique.
#    3. Kontoor Brands Inc est reconnue pour son approche en matière de durabilité et son impact positif sur l'énergie propre.
#    4. L'approche de revitalisation de Kontoor Brands Inc reflète son engagement envers l'accomplissement.
#
# Analyse :
#
#     1. La première partie de la phrase de ne semble pas faire sens. En revanche, on identifie clairement un message vert en seconde partie de phrase (ici c'est plutôt une analyse qu'une communication).
#
#     2. Le début de phrase semble plus adapté, sans vraiment savoir précisément ce que l'on cherche à décrire. Est-ce une entreprise propre dans le sens écologique du terme ? Dans le sens hygiénique ? On ne sait pas... Tout comme la première phrase, la fin de celle ci semble montrer une image verte de l'entreprise.
#
#     3. Toujours pas de communication, plutôt une affirmation qu'autre chose, mais la phrase fait sens à 100%, et laisse une image positive de l'entreprise.
#
#     4. Aucun sens...
#
#
# Est ce que l'insertion d'une phrase dans un texte comme celui çi fait sens ? Dans un premier temps, on résume l'article, sans tenir compte des phrases insérées :
#
# L'article du New York Times, "LET KIDS VOTE!" par Katherine Cusumano, traite du débat sur l'abaissement de l'âge de vote à 16 ans pour les élections locales aux États-Unis. Julia Rottenberg, 17 ans, a milité pour cette cause à Culver City, en Californie, avec l'organisation Vote16 Culver City. L'argument principal est que les jeunes sont affectés par des décisions majeures sans avoir leur mot à dire, notamment sur des questions comme le changement climatique ou la violence par arme à feu. Bien que certaines villes aient déjà abaissé l'âge de vote, cette proposition a été rejetée à Culver City. Malgré cela, les jeunes militants restent déterminés à continuer leur combat.
#
# La première conclusion que nous pourrions tirer, est que nous n'avons identifié aucune entreprise dans ce texte. En revanche, le thème du changement climatique est abordé ("What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources."), mais avec légerté : le sujet principale reste le droit de vote des jeunes, et non la question écologique. Il semble peu pertinant ici qu'on ait cité la communication verte d'une entreprise comme Kontoor Brands Inc dans un article comme celui ci. De plus, l'insertion de ces phrases s'est fait de manière aléatoire : elles ne sont pas associé / proche de la citation sur le passage avec la situation climatique.
#
# Pour résumé, on s'appuye ici sur un article ne citant aucune entreprise, dont le sujet tourne autour de l'age du droit de vote, avec une très légère évocation du changement climatique. Enfin, nous transformons cet article en insérant des phrases qui semblent présenter une cohérence moyenne, et une tendance à positiver la verdure de l'entreprise.
