# %% [markdown]
# ## Importation des données

# %% [markdown]
# Après avoir tenter d'essayer d'identifier les entreprises dans les textes originaux, nous nous sommes confronté à de nombreux problèmes. Suite à cela, et avec l'accord de notre encadrant Stat_app, nous avons fait le choix d'introduire le nom de certaines entreprises dans les articles originaux. Ce notebook vise à appliquer cette démarche

# %%
import pandas as pd

# %%
# Charger à partir du fichier pickle
data = pd.read_pickle('data.pkl')
data.head(5)
# Out:
#                                              Article              Date  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...  31 December 2023
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...  31 December 2023
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...  31 December 2023
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...  31 December 2023
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# ## Nettoyage des articles

# %% [markdown]
# Maintenant que nous avons les informations sur le texte (Date, Auteur, Nombre de mots etc...) Nous pouvons nous permettre de ne garder uniquement le coeur de l'article :

# %%
data.insert(1, 'Copy_Article', data['Article'])
data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                         Copy_Article              Date  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...  31 December 2023
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...  31 December 2023
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...  31 December 2023
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...  31 December 2023
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# Dans un premier temps, on supprime l'ID de l'article, qui se situe à la fin du texte

# %%
import re

# Fonction pour supprimer le texte après le motif spécifié
def supprimer_texte_apres_motif(article, motifs):
    motif = "|".join(motifs)  # Concaténer les motifs en une seule chaîne de caractères
    match = re.search(motif, article)
    if match:
        return article[:match.start()]
    else:
        return article

# Appliquer la fonction supprimer_texte_apres_motif à la colonne 'Coeur_Article' avec une liste de motifs
data['Copy_Article'] = data['Copy_Article'].apply(lambda x: supprimer_texte_apres_motif(x, ["Document J\d+", "Document NYTF\d+"]))

# %% [markdown]
# Vérification :

# %%
for i in range(1,5):
    print("Derniers caractères du", f"text_{i}", "avant suppression\n\n", data['Article'][i][-50:-1])
    print("Derniers caractères du", f"text_{i}", "après suppression\n\n", data['Copy_Article'][i][-50:-1])
    print("-----------------------------------------------------------------------------")
# Out:
# Derniers caractères du text_1 avant suppression
#
#  M21, MM22.
#
# Document NYTF000020231231ejcv0006h
#
#
# Derniers caractères du text_1 après suppression
#
#  cle appeared in print on page MM20, MM21, MM22.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_2 avant suppression
#
#  K4, MK5.
#
# Document NYTF000020231231ejcv00064
#
#
#
# Derniers caractères du text_2 après suppression
#
#  his article appeared in print on page MK4, MK5.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_3 avant suppression
#
#  age MK3.
#
# Document NYTF000020231231ejcv00063
#
#
#
# Derniers caractères du text_3 après suppression
#
#  o.
#
# This article appeared in print on page MK3.
#
# -----------------------------------------------------------------------------
# Derniers caractères du text_4 avant suppression
#
#  ge MK11.
#
# Document NYTF000020231231ejcv0005z
#
#
#
# Derniers caractères du text_4 après suppression
#
#  Š
#
# This article appeared in print on page MK11.
#
# -----------------------------------------------------------------------------

# %% [markdown]
# On supprime maintenant tout ce qui est placé avant "All Rights Reserved.", qui correspond à la partie d'information du texte (Auteur etc...)

# %%
# Fonction pour supprimer le texte après le motif spécifié
def supprimer_texte_avant_motif(article, motif):
    match = re.search(motif, article)
    if match:
        return article[match.end():]
    else:
        return article

# Appliquer la fonction supprimer_texte_apres_motif à la colonne 'Coeur_Article' avec une liste de motifs
data['Copy_Article'] = data['Copy_Article'].apply(lambda x: supprimer_texte_avant_motif(x, "All Rights Reserved."))

# %% [markdown]
# Vérification :

# %%
for i in range(1,3):
    print("Derniers caractères du", f"text_{i}", "avant suppression\n\n", data['Article'][i][0:100],"\n\n\n")
    print("Derniers caractères du", f"text_{i}", "après suppression\n\n", data['Copy_Article'][i][0:100])
    print("-----------------------------------------------------------------------------")
# Out:
# Derniers caractères du text_1 avant suppression
#
#
#
# Magazine Desk; SECTMM
# When Jim Brown and Raquel Welch, Two Sexy Stars, Crossed Paths
#
# By Wesley Mo
#
#
#
# Derniers caractères du text_1 après suppression
#
#
#
# In their one movie together, their chemistry was radical.
#
# Jim Brown & Raquel Welch B. 1936 and 1
# -----------------------------------------------------------------------------
# Derniers caractères du text_2 avant suppression
#
#
#
# Magazine Desk; SECTMK
# Talking During Movies: Totally Evil or Part of the Fun?
#
# 179 words
# 31 Decemb
#
#
#
# Derniers caractères du text_2 après suppression
#
#
#
# debatethis
#
# Talking during movies: Totally evil or part of the fun?
#
# show of hands
#
# The biggest p
# -----------------------------------------------------------------------------

# %%
data.rename(columns={'Copy_Article': 'Coeur_Article'}, inplace=True)
data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z

# %% [markdown]
# ## Modification des articles

# %% [markdown]
# ### Fonction d'insertion de chaines de charactères dans un article

# %%
import random

def insertion_phrase_dans_article(phrase, article):
    # Trouver tous les emplacements des points dans l'article
    emplacements_points = [i for i, char in enumerate(article) if char == '.']

    # Vérifier s'il y a des points dans l'article
    if emplacements_points:
        # Choisir aléatoirement l'un des emplacements des points
        indice_insertion = random.choice(emplacements_points)
        # Insérer la phrase juste après le point choisi
        article = article[:indice_insertion+1] + " " + phrase + article[indice_insertion+1:]
    else:
        # S'il n'y a pas de point, insérer la phrase au début de l'article
        article = phrase + " " + article
    return article

# %% [markdown]
# Vérification :

# %%
phrase_a_inserer = "AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA."
article_insertion = data['Coeur_Article'][3]
article_insertion = insertion_phrase_dans_article(phrase_a_inserer, article_insertion)

# Afficher l'article avec la phrase insérée
print(article_insertion)
# Out:
#
#
# LET KIDS
#
# VOTE!
#
# by Katherine Cusumano
#
# Julia Rottenberg, 17, spent the fall of last year knocking on doors. On Election Day 2022, people in Culver City, Calif., her hometown, would have a big decision to make: Should the voting age for local elections change from 18 to 16? Julia wanted them to vote yes. ''I think a vote is one of the most direct ways that you can express an opinion and actually have some change happen,'' says Julia, who is part of an organization called Vote16 Culver City.
#
# What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources. Yes, young people are already leading political movements around these issues. But without the vote, they can't elect politicians who represent their views and make real change. AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA. ''There's a whole lot of talk about prioritizing young people and politicians saying, 'We care about your future,''' says Jessie Cai, 16, a teen organizer with Voters of Tomorrow in Maryland. Voting would be a way to hold them to their promises.
#
# In some places, the change is already underway. In the past 10 years, residents in a handful of American towns (a few in Maryland, one in Vermont and two in California) have all approved lowering the voting age to 16 in local elections. Teenagers are campaigning to do the same in states from New Jersey to Oregon. A member of Congress has even been pushing to change the federal voting age. And if you think the whole idea seems too out there, think about this: It used to be that you actually had to be 21 to vote. But during the Vietnam War, lots of people argued that if 18-year-olds were being forced to fight, they should also be able to vote. So in 1971, the age was lowered.
#
# Still, not everyone thinks 16-year-olds are ready for the responsibility -- including the voters in Culver City, where the measure lost by just 16 votes. ''I would be lying if I said it wasn't a little bit frustrating,'' Julia says. But the fact that the loss was so narrow has just made her and other Vote16 teenagers more motivated to try again this year: ''It proves to me how much each individual voice matters.'' â—Š
#
# *Thank you to the following schools: Holmes Elementary in Spokane, Wash.; Johnsontown Road Elementary in Louisville, Ky.; Frank D. Spaziano Elementary in Providence, R.I.; and Jefferson Elementary in San Diego.
#
# This article appeared in print on page MK3.

# %% [markdown]
# ### Méthode 1 :

# %% [markdown]
# Dans cette méthode, on utilise le dictionnaire environnemental anglais, à partir duquel on créer un série de phrases à trou. Chaque phrases sera aléatoirement rempli par le nom d'entreprises, ainsi que des termes du dictionnaires. On pourra retrouver des phrases au sentiment positif, négatif, ou neutre d'un point de vue environnemental. Pour chaque entreprise, on génère un nombre aléatoire de phrases la concernant. Toutes ces phrases (ne traitant que d'une seule entreprise) sont ensuite insérés dans un seul et unique article. Ainsi : 1 Article = 1 entreprise identifiée.

# %% [markdown]
# #### Création des phrases à insérer

# %%
Dico_env_en = {
    
    "clean": 1,
    "ecological": 1,
    "sustainable": 1,
    "green": 1,
    "energy-efficient": 1,
    "renewable": 1,
    "responsible": 1,
    "conservation": 1,
    "biodiversity": 1,
    "healthy": 1,
    "organic": 1,
    "eco-friendly": 1,
    "environmentally friendly": 1,
    "efficient": 1,
    "innovative": 1,
    "ethical": 1,
    "fair": 1,
    "efficiency": 1,
    "social responsibility": 1,
    "sustainable": 1,
    "solidarity": 1,
    "conscious spreading": 1,
    "sustainable": 1,
    "clean energy": 1,
    "renewable energy": 1,
    "recycling": 1,
    "energy efficiency": 1,
    "circular economy": 1,
    "solar energy": 1,
    "wind energy": 1,
    "regeneration": 1,
    "preservation": 1,
    "restoration": 1,
    "rehabilitation": 1,
    "recovery": 1,
    "restorer": 1,
    "regenerator": 1,
    "revitalization": 1,
    "positive": 1,
    "beneficial": 1,
    "valorization": 1,
    "fulfillment": 1,
    "continuous improvement": 1,
    "prosperity": 1,
    "harmony": 1,
    "integrity": 1,
    "responsible consumption": 1,
    "eco-responsible": 1,
    "eco-conscious": 1,
    "sustainability": 1,
    "recoverable": 1,
    "green energy": 1,
    "greenhouse effect": 1,
    "eco-efficient": 1,
    "eco-innovation": 1,
    "well-being": 1,
    "eco-design": 1,
    "agroecology": 1,
    "permaculture": 1,
    "eco-citizen": 1,
    "carbon neutral": 1,
    "zero waste": 1,
    "organic": 1,
    "eco-label": 1,
    "sustainable mobility": 1,
    "eco-tourism": 1,
    "eco-habitat": 1,
    "conscious consumption": 1,
    
    "pollution": -1,
    "waste": -1,
    "deforestation": -1,
    "greenhouse gas emissions": -1,
    "contamination": -1,
    "destructive": -1,
    "irresponsible": -1,
    "wasteful": -1,
    "harmful": -1,
    "toxic": -1,
    "deterioration": -1,
    "degradation": -1,
    "damaging": -1,
    "harmful": -1,
    "perilous": -1,
    "worrisome": -1,
    "catastrophic": -1,
    "catastrophe": -1,
    "dangerous": -1,
    "threat": -1,
    "risk": -1,
    "hazardous": -1,
    "harmful": -1,
    "inappropriate": -1,
    "inadequate": -1,
    "inappropriate": -1,
    "harm": -1,
    "damage": -1,
    "pollutant": -1,
    "pollute": -1,
    "deteriorate": -1,
    "disruption": -1,
    "disrespectful": -1,
    "malevolent": -1,
    "damage": -1,
    "aggressive": -1,
    "ravager": -1,
    "spoil": -1,
    "disturb": -1,
    "damage": -1,
    "irreparable": -1,
    "toxicity": -1,
    "unacceptable": -1,
    "ecological damage": -1,
    "illegal logging": -1,
    "overconsumption": -1,
    "resource plundering": -1,
    "environmental degradation": -1,
    "destroyed natural habitat": -1,
    "excessive exploitation": -1,
    "overexploitation": -1,
    "climate change": -1,
    "environmental denial": -1,
}

negation_list = ["not", "no", "never", "none", "nil", "nothing", "nobody", "negative", "without", "more", "less"]

negation_cancellation_list = ["responsible", "originally", "source"]

# %%
import pandas as pd
import random

# Listes de structures de phrases
def generate_positive_structures(company, positive_terms):
    return [
        f"The company {company} is committed to a {random.choice(positive_terms)[0]} approach to promote {random.choice(positive_terms)[0]}.",
        f"Thanks to its {random.choice(positive_terms)[0]} initiative, {company} strengthens its commitment to {random.choice(positive_terms)[0]}.",
        f"{company} implements {random.choice(positive_terms)[0]} practices to support {random.choice(positive_terms)[0]}.",
        f"As a {random.choice(positive_terms)[0]} company, {company} takes measures to encourage {random.choice(positive_terms)[0]}.",
        f"{company} communicates about its {random.choice(positive_terms)[0]} commitment and its positive contribution to {random.choice(positive_terms)[0]}.",
        f"{company} is recognized for its {random.choice(positive_terms)[0]} approach and its positive impact on {random.choice(positive_terms)[0]}.",
        f"Through its {random.choice(positive_terms)[0]} actions, {company} aims to improve {random.choice(positive_terms)[0]}.",
        f"{company} adopts a {random.choice(positive_terms)[0]} strategy to promote {random.choice(positive_terms)[0]}.",
        f"The {random.choice(positive_terms)[0]} approach of {company} reflects its commitment to {random.choice(positive_terms)[0]}.",
        f"{company} values its {random.choice(positive_terms)[0]} commitment and its respect for {random.choice(positive_terms)[0]}."
    ]

def generate_negative_structures(company, negative_terms):
    return [
        f"The company {company} is criticized for its lack of commitment to {random.choice(negative_terms)[0]}.",
        f"{company} is singled out for its {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(negative_terms)[0]} practices have raised concerns among environmentalists.",
        f"{company} faces scrutiny for its {random.choice(negative_terms)[0]} approach.",
        f"Some question {company}'s commitment due to its {random.choice(negative_terms)[0]}.",
        f"{company} is under fire for its {random.choice(negative_terms)[0]} strategy.",
        f"Concerns are raised about {company}'s {random.choice(negative_terms)[0]} practices.",
        f"{company} is criticized for its failure to address {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(negative_terms)[0]} initiative is viewed with skepticism.",
        f"{company} is blamed for its {random.choice(negative_terms)[0]} impact."
    ]

def generate_mixed_structures(company, positive_terms, negative_terms):
    return [
        f"{company} is exploring {random.choice(positive_terms)[0]} initiatives to address {random.choice(negative_terms)[0]}.",
        f"The company {company} is researching {random.choice(positive_terms)[0]} solutions for {random.choice(negative_terms)[0]}.",
        f"{company} is developing {random.choice(positive_terms)[0]} practices while managing {random.choice(negative_terms)[0]}.",
        f"The approach of {company} involves {random.choice(positive_terms)[0]} methods to mitigate {random.choice(negative_terms)[0]}.",
        f"{company}'s {random.choice(positive_terms)[0]} efforts are focused on {random.choice(negative_terms)[0]}.",
        f"{company} is committed to {random.choice(positive_terms)[0]} actions and addressing {random.choice(negative_terms)[0]}.",
        f"{company} integrates {random.choice(positive_terms)[0]} strategies with {random.choice(negative_terms)[0]} management.",
        f"The company {company} emphasizes {random.choice(positive_terms)[0]} practices alongside {random.choice(negative_terms)[0]}.",
        f"{company} implements {random.choice(positive_terms)[0]} measures while considering {random.choice(negative_terms)[0]}.",
        f"{company} is dedicated to {random.choice(positive_terms)[0]} approaches and {random.choice(negative_terms)[0]} initiatives."
    ]


# Fonction pour gérer les termes de négation
def handle_negation(term, score):
    if term in negation_list:
        return -score
    elif term in negation_cancellation_list:
        return 0
    else:
        return score

# Fonction pour générer une phrase sur la communication environnementale d'une entreprise
def generate_environmental_communication(company_list, env_dict, a, b):
    positive_terms = [(term, score) for term, score in env_dict.items() if score == 1]
    negative_terms = [(term, score) for term, score in env_dict.items() if score == -1]
    
    company_sentences = {}  # Dictionnaire pour regrouper les phrases par entreprise
    
    for company in company_list:
        num_sentences = random.randint(a, b)
        sentences = []
        
        for _ in range(num_sentences):
            if random.choice([True, False]):
                structures = generate_positive_structures(company, positive_terms)
            else:
                if negative_terms:
                    structures = generate_negative_structures(company, negative_terms) + generate_mixed_structures(company, positive_terms, negative_terms)
                else:
                    structures = generate_positive_structures(company, positive_terms) + generate_mixed_structures(company, positive_terms, negative_terms)

            sentence = random.choice(structures)
            
            # Gérer les termes de négation dans la phrase
            sentence_words = sentence.split()
            for i, word in enumerate(sentence_words):
                if word.lower() in [term.lower() for term, _ in positive_terms + negative_terms]:
                    original_score = next((score for term, score in positive_terms + negative_terms if term.lower() == word.lower()), None)
                    if original_score:
                        new_score = handle_negation(word.lower(), original_score)
                        if new_score != original_score:
                            replacement = next((term for term, score in env_dict.items() if score == new_score), None)
                            if replacement:
                                sentence_words[i] = replacement

            # Reconstruire la phrase modifiée
            modified_sentence = ' '.join(sentence_words)
            sentences.append(modified_sentence)
        
        company_sentences[company] = sentences
    
    return company_sentences

# %% [markdown]
# #### Sélection aléatoire des entreprises

# %% [markdown]
# Dans un premier temps, nous avions selectionné 100 entreprises, prises aux hasard parmis le jeu de données entier que nous avions. Plus tard dans notre projet, nous nous sommes rendu compte qu'une trop grande parti de ces entreprises ne disposaient pas de score de controverse environemental. Cela nous empêché de continuer à travailler. Pour cette raison, nous piochons aléatoirement des entreprises parmis toutes celles qui sont mises à notre disposition, à la condition qu'elles aient bien un score de controverse à partir de 2009 (ie leur score n'est pas 0). On verra ensuite qu'une entreprise qui possède un score à une date t, a une grande chance d'en avoir un aux dates futures (sauf rares exceptions : est ce parce que l'entreprise a coulé ?)

# %% [markdown]
# ##### Importation des données

# %%
# !pip install openpyxl
import openpyxl

CON_E = pd.read_excel('CON_E.xlsx', engine='openpyxl')
CON_E.head()
# Out:
# Requirement already satisfied: openpyxl in /opt/mamba/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.11/site-packages (from openpyxl) (1.1.0)
#    idEntreprise    2002-01    2002-02    2002-03    2002-04    2002-05  \
# 0             1   0.000000  11.111111   8.888889   7.111111   5.688889
# 1             2  11.111111  20.000000  16.000000  12.800000  10.240000
# 2             3   0.000000   0.000000   0.000000   0.000000  11.111111
# 3             4   0.000000   0.000000   0.000000   0.000000   0.000000
# 4             5  36.111111  68.888889  91.952381  91.555556  78.165333
#
#      2002-06    2002-07    2002-08    2002-09  ...    2022-07    2022-08  \
# 0   4.551111   3.640889  14.023822  11.219058  ...  95.000456  90.878881
# 1   8.192000  17.664711  14.131769  11.305415  ...  33.356441  26.685153
# 2   8.888889   7.111111   5.688889   4.551111  ...  24.922552  19.938041
# 3   0.000000   0.000000   0.000000   0.000000  ...  21.288006  17.030405
# 4  90.417778  85.920000  92.937543  86.077611  ...  99.799505  98.728493
#
#      2022-09    2022-10    2022-11    2022-12    2023-01    2023-02  \
# 0  86.036438  81.975582  72.247132  74.625457  97.205522  90.921703
# 1  43.570345  45.967387  47.885021  38.308016  30.646413  46.739353
# 2  15.950433  12.760347  10.208277  30.388844  24.311075  19.448860
# 3  13.624324  10.899459   8.719567   6.975654   5.580523   4.464418
# 4  97.446020  96.017441  97.956816  91.698786  93.367594  99.630794
#
#      2023-03    2023-04
# 0  83.107733  80.062460
# 1  37.391482  29.913186
# 2  26.670199  32.447270
# 3   3.571535   2.857228
# 4  98.074889  96.408810
#
# [5 rows x 257 columns]

# %%
covalence_id_firms = pd.read_csv('Universe_Listed_Covalence_31.07.2023_v2_updated.csv',sep=';',on_bad_lines='skip')
covalence_id_firms.head()
# Out:
#    Unnamed: 0  idEntreprise           Company          ISIN  \
# 0           0             1        Pfizer Inc  US7170811035
# 1           1             2    Merck & Co Inc  US58933Y1055
# 2           2             3           GSK plc  GB0009252882
# 3           3             4  Eli Lilly and Co  US5324571083
# 4           4             5          Bayer AG  DE000BAY0017
#
#                               GICS industry group  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences
# 1  Pharmaceuticals, Biotechnology & Life Sciences
# 2    Unable to resolve all requested identifiers.
# 3  Pharmaceuticals, Biotechnology & Life Sciences
# 4  Pharmaceuticals, Biotechnology & Life Sciences
#
#                               GICS sub-industry  \
# 0                               Pharmaceuticals
# 1                               Pharmaceuticals
# 2  Unable to resolve all requested identifiers.
# 3                               Pharmaceuticals
# 4                               Pharmaceuticals
#
#                             Headquarters Region  \
# 0                                      Americas
# 1                                      Americas
# 2  Unable to resolve all requested identifiers.
# 3                                      Americas
# 4                                        Europe
#
#                            Headquarters Country
# 0                      United States of America
# 1                      United States of America
# 2  Unable to resolve all requested identifiers.
# 3                      United States of America
# 4                                       Germany

# %% [markdown]
# ##### Fusion des tables

# %%
df1 = pd.merge(covalence_id_firms, CON_E, on='idEntreprise')
df1.head()
# Out:
#    Unnamed: 0  idEntreprise           Company          ISIN  \
# 0           0             1        Pfizer Inc  US7170811035
# 1           1             2    Merck & Co Inc  US58933Y1055
# 2           2             3           GSK plc  GB0009252882
# 3           3             4  Eli Lilly and Co  US5324571083
# 4           4             5          Bayer AG  DE000BAY0017
#
#                               GICS industry group  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences
# 1  Pharmaceuticals, Biotechnology & Life Sciences
# 2    Unable to resolve all requested identifiers.
# 3  Pharmaceuticals, Biotechnology & Life Sciences
# 4  Pharmaceuticals, Biotechnology & Life Sciences
#
#                               GICS sub-industry  \
# 0                               Pharmaceuticals
# 1                               Pharmaceuticals
# 2  Unable to resolve all requested identifiers.
# 3                               Pharmaceuticals
# 4                               Pharmaceuticals
#
#                             Headquarters Region  \
# 0                                      Americas
# 1                                      Americas
# 2  Unable to resolve all requested identifiers.
# 3                                      Americas
# 4                                        Europe
#
#                            Headquarters Country    2002-01    2002-02  ...  \
# 0                      United States of America   0.000000  11.111111  ...
# 1                      United States of America  11.111111  20.000000  ...
# 2  Unable to resolve all requested identifiers.   0.000000   0.000000  ...
# 3                      United States of America   0.000000   0.000000  ...
# 4                                       Germany  36.111111  68.888889  ...
#
#      2022-07    2022-08    2022-09    2022-10    2022-11    2022-12  \
# 0  95.000456  90.878881  86.036438  81.975582  72.247132  74.625457
# 1  33.356441  26.685153  43.570345  45.967387  47.885021  38.308016
# 2  24.922552  19.938041  15.950433  12.760347  10.208277  30.388844
# 3  21.288006  17.030405  13.624324  10.899459   8.719567   6.975654
# 4  99.799505  98.728493  97.446020  96.017441  97.956816  91.698786
#
#      2023-01    2023-02    2023-03    2023-04
# 0  97.205522  90.921703  83.107733  80.062460
# 1  30.646413  46.739353  37.391482  29.913186
# 2  24.311075  19.448860  26.670199  32.447270
# 3   5.580523   4.464418   3.571535   2.857228
# 4  93.367594  99.630794  98.074889  96.408810
#
# [5 rows x 264 columns]

# %%
df1 = df1.drop(columns=df1.columns[0])
df1 = df1.drop(columns=['GICS industry group', 'GICS sub-industry', 'Headquarters Region', 'Headquarters Country'])
df1
# Out:
#       idEntreprise                                      Company          ISIN  \
# 0                1                                   Pfizer Inc  US7170811035
# 1                2                               Merck & Co Inc  US58933Y1055
# 2                3                                      GSK plc  GB0009252882
# 3                4                             Eli Lilly and Co  US5324571083
# 4                5                                     Bayer AG  DE000BAY0017
# ...            ...                                          ...           ...
# 8593         19239                     F&G Annuities & Life Inc  US30190A1043
# 8594         19240  Gujarat Mineral Development Corporation Ltd  INE131A01031
# 8595         19247                                  Borosil Ltd  INE02PY01013
# 8596         19251                         Healthcare Trust Inc  US42226B2043
# 8597         19253                           Rosetti Marino SpA  IT0001017851
#
#         2002-01    2002-02    2002-03    2002-04    2002-05    2002-06  \
# 0      0.000000  11.111111   8.888889   7.111111   5.688889   4.551111
# 1     11.111111  20.000000  16.000000  12.800000  10.240000   8.192000
# 2      0.000000   0.000000   0.000000   0.000000  11.111111   8.888889
# 3      0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 4     36.111111  68.888889  91.952381  91.555556  78.165333  90.417778
# ...         ...        ...        ...        ...        ...        ...
# 8593   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2002-07  ...    2022-07    2022-08    2022-09    2022-10    2022-11  \
# 0      3.640889  ...  95.000456  90.878881  86.036438  81.975582  72.247132
# 1     17.664711  ...  33.356441  26.685153  43.570345  45.967387  47.885021
# 2      7.111111  ...  24.922552  19.938041  15.950433  12.760347  10.208277
# 3      0.000000  ...  21.288006  17.030405  13.624324  10.899459   8.719567
# 4     85.920000  ...  99.799505  98.728493  97.446020  96.017441  97.956816
# ...         ...  ...        ...        ...        ...        ...        ...
# 8593   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000  ...   0.000000   0.000000   0.000000   0.000000   0.000000
#
#         2022-12    2023-01    2023-02    2023-03    2023-04
# 0     74.625457  97.205522  90.921703  83.107733  80.062460
# 1     38.308016  30.646413  46.739353  37.391482  29.913186
# 2     30.388844  24.311075  19.448860  26.670199  32.447270
# 3      6.975654   5.580523   4.464418   3.571535   2.857228
# 4     91.698786  93.367594  99.630794  98.074889  96.408810
# ...         ...        ...        ...        ...        ...
# 8593   0.000000   0.000000   0.000000   0.000000   0.000000
# 8594   0.000000   0.000000   0.000000   0.000000   0.000000
# 8595   0.000000   0.000000   0.000000   0.000000   0.000000
# 8596   0.000000   0.000000   0.000000   0.000000   0.000000
# 8597   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [8598 rows x 259 columns]

# %%
df1 = df1[df1['2009-01'] != 0]
df1[['idEntreprise','2009-01','2009-02']]
# Out:
#       idEntreprise       2009-01       2009-02
# 0                1  2.983779e+01  2.387023e+01
# 1                2  6.086388e+00  1.598022e+01
# 2                3  1.980426e+00  1.584341e+00
# 3                4  2.522675e+01  2.018140e+01
# 4                5  6.528102e+01  6.658151e+01
# ...            ...           ...           ...
# 7481         16645  1.100391e-02  8.803129e-03
# 7685         17097  1.209893e-03  9.679143e-04
# 8233         18234  8.888889e+00  7.111111e+00
# 8290         18386  4.907909e-07  3.926327e-07
# 8299         18412  3.067443e-07  2.453954e-07
#
# [398 rows x 3 columns]

# %% [markdown]
# On voit ici que seulement 398 entreprises parmis les 8598 initiales, possèdent un score de controverse à partir de 2009

# %% [markdown]
# #### Application de la génération des phrases aléatoires

# %%
# Sélectionner 100 entreprises au hasard
random_companies = df1['Company'].sample(n=100, random_state=42).tolist()

# Utiliser la fonction pour générer les phrases
a = 3
b = 5
company_sentences = generate_environmental_communication(random_companies, Dico_env_en, a, b)

# Afficher les phrases générées par entreprise
for company, sentences in company_sentences.items():
    print(f"{company}:")
    for idx, sentence in enumerate(sentences, 1):
        print(f"  {idx}. {sentence}")
# Out:
# International Paper Co:
#   1. International Paper Co is criticized for its failure to address damage.
#   2. International Paper Co adopts a fair strategy to promote eco-citizen.
#   3. International Paper Co communicates about its conscious consumption commitment and its positive contribution to eco-habitat.
# China Development Bank Financial Leasing Co Ltd:
#   1. China Development Bank Financial Leasing Co Ltd is singled out for its pollutant.
#   2. Some question China Development Bank Financial Leasing Co Ltd's commitment due to its greenhouse gas emissions.
#   3. China Development Bank Financial Leasing Co Ltd implements eco-habitat practices to support eco-innovation.
#   4. The company China Development Bank Financial Leasing Co Ltd is researching positive solutions for worrisome.
# Southern Co:
#   1. Some question Southern Co's commitment due to its aggressive.
#   2. The company Southern Co is committed to a renewable approach to promote efficiency.
#   3. Southern Co is blamed for its dangerous impact.
#   4. The company Southern Co emphasizes eco-citizen practices alongside overconsumption.
#   5. Southern Co values its recoverable commitment and its respect for energy-efficient.
# Sappi Ltd:
#   1. The eco-conscious approach of Sappi Ltd reflects its commitment to agroecology.
#   2. Sappi Ltd faces scrutiny for its disruption approach.
#   3. Sappi Ltd adopts a circular economy strategy to promote eco-friendly.
# Johnson Controls International PLC:
#   1. Johnson Controls International PLC is under fire for its disruption strategy.
#   2. Concerns are raised about Johnson Controls International PLC's disruption practices.
#   3. Johnson Controls International PLC implements conservation practices to support eco-friendly.
#   4. Johnson Controls International PLC communicates about its biodiversity commitment and its positive contribution to recovery.
#   5. The company Johnson Controls International PLC is committed to a recoverable approach to promote restoration.
# Skanska AB:
#   1. Skanska AB values its eco-conscious commitment and its respect for regeneration.
#   2. The company Skanska AB is committed to a green energy approach to promote preservation.
#   3. The company Skanska AB is criticized for its lack of commitment to environmental denial.
#   4. Skanska AB implements revitalization practices to support green.
# Tata Motors Ltd:
#   1. Tata Motors Ltd's pollutant initiative is viewed with skepticism.
#   2. The company Tata Motors Ltd emphasizes positive practices alongside resource plundering.
#   3. Concerns are raised about Tata Motors Ltd's disruption practices.
# Alstom SA:
#   1. The company Alstom SA is committed to a conservation approach to promote solidarity.
#   2. The company Alstom SA is committed to a regenerator approach to promote fair.
#   3. Alstom SA implements sustainability measures while considering resource plundering.
# Clear Channel Outdoor Holdings Inc:
#   1. Clear Channel Outdoor Holdings Inc's restorer efforts are focused on overexploitation.
#   2. Clear Channel Outdoor Holdings Inc is singled out for its irreparable.
#   3. Clear Channel Outdoor Holdings Inc is under fire for its overexploitation strategy.
# Marks and Spencer Group PLC:
#   1. The sustainable approach of Marks and Spencer Group PLC reflects its commitment to efficiency.
#   2. Marks and Spencer Group PLC faces scrutiny for its harm approach.
#   3. As a carbon neutral company, Marks and Spencer Group PLC takes measures to encourage revitalization.
#   4. Marks and Spencer Group PLC is dedicated to green approaches and disruption initiatives.
#   5. Marks and Spencer Group PLC is exploring solidarity initiatives to address disruption.
# Roche Holding AG:
#   1. Concerns are raised about Roche Holding AG's pollutant practices.
#   2. Roche Holding AG's irresponsible initiative is viewed with skepticism.
#   3. Roche Holding AG's waste practices have raised concerns among environmentalists.
#   4. Roche Holding AG is recognized for its solar energy approach and its positive impact on prosperity.
# Xinjiang Goldwind Science & Technology Co Ltd:
#   1. Xinjiang Goldwind Science & Technology Co Ltd values its responsible commitment and its respect for green energy.
#   2. Xinjiang Goldwind Science & Technology Co Ltd communicates about its responsible commitment and its positive contribution to greenhouse effect.
#   3. Xinjiang Goldwind Science & Technology Co Ltd adopts a ethical strategy to promote recycling.
#   4. Xinjiang Goldwind Science & Technology Co Ltd's deforestation initiative is viewed with skepticism.
# Microsoft Corp:
#   1. Microsoft Corp is criticized for its failure to address spoil.
#   2. The company Microsoft Corp is researching restorer solutions for destructive.
#   3. Microsoft Corp implements healthy measures while considering irreparable.
#   4. The company Microsoft Corp is committed to a social responsibility approach to promote restoration.
#   5. The solidarity approach of Microsoft Corp reflects its commitment to regenerator.
# Eastman Kodak Co:
#   1. Eastman Kodak Co implements green energy practices to support biodiversity.
#   2. As a eco-habitat company, Eastman Kodak Co takes measures to encourage permaculture.
#   3. The company Eastman Kodak Co is committed to a recycling approach to promote valorization.
#   4. Eastman Kodak Co communicates about its integrity commitment and its positive contribution to green.
# China Steel Corp:
#   1. China Steel Corp is recognized for its conscious spreading approach and its positive impact on biodiversity.
#   2. China Steel Corp's irreparable practices have raised concerns among environmentalists.
#   3. China Steel Corp is committed to wind energy actions and addressing destroyed natural habitat.
#   4. China Steel Corp is singled out for its contamination.
# BP plc:
#   1. BP plc is recognized for its integrity approach and its positive impact on energy-efficient.
#   2. BP plc is recognized for its rehabilitation approach and its positive impact on eco-design.
#   3. The ecological approach of BP plc reflects its commitment to positive.
#   4. The company BP plc is committed to a environmentally friendly approach to promote organic.
#   5. BP plc is blamed for its malevolent impact.
# Qualcomm Inc:
#   1. Qualcomm Inc's greenhouse gas emissions initiative is viewed with skepticism.
#   2. Qualcomm Inc faces scrutiny for its catastrophic approach.
#   3. Qualcomm Inc is exploring biodiversity initiatives to address damaging.
#   4. Qualcomm Inc communicates about its harmony commitment and its positive contribution to greenhouse effect.
# Estee Lauder Companies Inc:
#   1. The company Estee Lauder Companies Inc is committed to a renewable approach to promote restoration.
#   2. Estee Lauder Companies Inc is singled out for its contamination.
#   3. Through its eco-label actions, Estee Lauder Companies Inc aims to improve organic.
#   4. Estee Lauder Companies Inc values its fair commitment and its respect for wind energy.
#   5. Estee Lauder Companies Inc adopts a restorer strategy to promote conscious spreading.
# Hitachi Ltd:
#   1. Concerns are raised about Hitachi Ltd's pollution practices.
#   2. Hitachi Ltd's conscious spreading efforts are focused on irreparable.
#   3. As a energy efficiency company, Hitachi Ltd takes measures to encourage green.
# Weyerhaeuser Co:
#   1. Weyerhaeuser Co's efficient efforts are focused on destroyed natural habitat.
#   2. Weyerhaeuser Co faces scrutiny for its damage approach.
#   3. The company Weyerhaeuser Co is criticized for its lack of commitment to malevolent.
# PepsiCo Inc:
#   1. Some question PepsiCo Inc's commitment due to its excessive exploitation.
#   2. PepsiCo Inc is under fire for its ravager strategy.
#   3. The company PepsiCo Inc is committed to a solidarity approach to promote recoverable.
#   4. PepsiCo Inc is recognized for its efficiency approach and its positive impact on agroecology.
#   5. The company PepsiCo Inc is criticized for its lack of commitment to unacceptable.
# Siemens AG:
#   1. Siemens AG integrates clean strategies with disrespectful management.
#   2. As a regenerator company, Siemens AG takes measures to encourage sustainability.
#   3. Siemens AG's resource plundering initiative is viewed with skepticism.
# Stelco Holdings Inc:
#   1. Stelco Holdings Inc adopts a integrity strategy to promote sustainable mobility.
#   2. Stelco Holdings Inc is recognized for its conservation approach and its positive impact on healthy.
#   3. The recoverable approach of Stelco Holdings Inc reflects its commitment to rehabilitation.
# Enel Generacion Chile SA:
#   1. Enel Generacion Chile SA is under fire for its spoil strategy.
#   2. As a prosperity company, Enel Generacion Chile SA takes measures to encourage efficient.
#   3. Enel Generacion Chile SA values its social responsibility commitment and its respect for social responsibility.
# Pfizer Inc:
#   1. Through its eco-responsible actions, Pfizer Inc aims to improve eco-tourism.
#   2. Pfizer Inc implements organic practices to support eco-tourism.
#   3. The company Pfizer Inc emphasizes continuous improvement practices alongside degradation.
#   4. Pfizer Inc values its regeneration commitment and its respect for eco-tourism.
# Fawaz Abdulaziz Alhokair Company SJSC:
#   1. Fawaz Abdulaziz Alhokair Company SJSC is exploring greenhouse effect initiatives to address excessive exploitation.
#   2. Fawaz Abdulaziz Alhokair Company SJSC adopts a harmony strategy to promote eco-friendly.
#   3. Concerns are raised about Fawaz Abdulaziz Alhokair Company SJSC's illegal logging practices.
# Motorola Solutions Inc:
#   1. Thanks to its conscious consumption initiative, Motorola Solutions Inc strengthens its commitment to eco-innovation.
#   2. Motorola Solutions Inc is singled out for its toxic.
#   3. The company Motorola Solutions Inc is committed to a environmentally friendly approach to promote responsible consumption.
#   4. Motorola Solutions Inc is recognized for its solidarity approach and its positive impact on eco-citizen.
#   5. The company Motorola Solutions Inc is researching integrity solutions for illegal logging.
# Julius Baer Gruppe AG:
#   1. Julius Baer Gruppe AG adopts a eco-friendly strategy to promote eco-responsible.
#   2. Julius Baer Gruppe AG is dedicated to eco-citizen approaches and environmental denial initiatives.
#   3. Julius Baer Gruppe AG is committed to zero waste actions and addressing threat.
#   4. As a conscious consumption company, Julius Baer Gruppe AG takes measures to encourage responsible.
# General Mills Inc:
#   1. General Mills Inc is exploring sustainable mobility initiatives to address perilous.
#   2. The company General Mills Inc emphasizes agroecology practices alongside unacceptable.
#   3. General Mills Inc communicates about its restorer commitment and its positive contribution to eco-efficient.
#   4. Through its energy-efficient actions, General Mills Inc aims to improve carbon neutral.
#   5. General Mills Inc faces scrutiny for its aggressive approach.
# Petroleo Brasileiro SA Petrobras:
#   1. Petroleo Brasileiro SA Petrobras communicates about its fair commitment and its positive contribution to eco-tourism.
#   2. Petroleo Brasileiro SA Petrobras is developing recoverable practices while managing irreparable.
#   3. Petroleo Brasileiro SA Petrobras is dedicated to continuous improvement approaches and overexploitation initiatives.
#   4. Petroleo Brasileiro SA Petrobras is singled out for its climate change.
# Hindustan Copper Ltd:
#   1. Hindustan Copper Ltd's disturb initiative is viewed with skepticism.
#   2. Hindustan Copper Ltd implements positive practices to support integrity.
#   3. The restorer approach of Hindustan Copper Ltd reflects its commitment to valorization.
#   4. Hindustan Copper Ltd values its harmony commitment and its respect for eco-citizen.
# Exelon Corp:
#   1. Exelon Corp is under fire for its spoil strategy.
#   2. Some question Exelon Corp's commitment due to its damage.
#   3. Exelon Corp is under fire for its damage strategy.
#   4. The eco-habitat approach of Exelon Corp reflects its commitment to recoverable.
# Berkshire Hathaway Inc:
#   1. Berkshire Hathaway Inc is recognized for its renewable energy approach and its positive impact on efficient.
#   2. Concerns are raised about Berkshire Hathaway Inc's pollute practices.
#   3. Berkshire Hathaway Inc is committed to clean actions and addressing harmful.
# BT Group PLC:
#   1. Through its restoration actions, BT Group PLC aims to improve innovative.
#   2. BT Group PLC is recognized for its efficient approach and its positive impact on clean.
#   3. BT Group PLC's hazardous practices have raised concerns among environmentalists.
#   4. BT Group PLC implements harmony measures while considering overconsumption.
# United States Steel Corp:
#   1. Concerns are raised about United States Steel Corp's catastrophic practices.
#   2. The company United States Steel Corp is committed to a beneficial approach to promote rehabilitation.
#   3. The company United States Steel Corp is criticized for its lack of commitment to toxic.
# Occidental Petroleum Corp:
#   1. The company Occidental Petroleum Corp is committed to a restoration approach to promote conservation.
#   2. Occidental Petroleum Corp implements preservation practices to support preservation.
#   3. Occidental Petroleum Corp's malevolent practices have raised concerns among environmentalists.
#   4. Occidental Petroleum Corp is blamed for its unacceptable impact.
# Boeing Co:
#   1. Boeing Co adopts a healthy strategy to promote restoration.
#   2. Boeing Co is exploring positive initiatives to address catastrophe.
#   3. Thanks to its permaculture initiative, Boeing Co strengthens its commitment to ecological.
#   4. As a conscious spreading company, Boeing Co takes measures to encourage efficiency.
#   5. Boeing Co is criticized for its failure to address waste.
# Reckitt Benckiser Group plc:
#   1. Thanks to its prosperity initiative, Reckitt Benckiser Group plc strengthens its commitment to restoration.
#   2. The company Reckitt Benckiser Group plc is researching revitalization solutions for pollute.
#   3. Reckitt Benckiser Group plc communicates about its harmony commitment and its positive contribution to regeneration.
# National Australia Bank Ltd:
#   1. National Australia Bank Ltd faces scrutiny for its irresponsible approach.
#   2. National Australia Bank Ltd communicates about its integrity commitment and its positive contribution to eco-tourism.
#   3. National Australia Bank Ltd communicates about its beneficial commitment and its positive contribution to recycling.
#   4. National Australia Bank Ltd's overconsumption initiative is viewed with skepticism.
#   5. The company National Australia Bank Ltd emphasizes greenhouse effect practices alongside hazardous.
# Subaru Corp:
#   1. Concerns are raised about Subaru Corp's catastrophic practices.
#   2. Subaru Corp's green energy efforts are focused on overexploitation.
#   3. Concerns are raised about Subaru Corp's harmful practices.
#   4. Subaru Corp is recognized for its greenhouse effect approach and its positive impact on fair.
#   5. Subaru Corp faces scrutiny for its damage approach.
# Kia Corp:
#   1. The approach of Kia Corp involves eco-design methods to mitigate harmful.
#   2. Kia Corp is blamed for its wasteful impact.
#   3. Kia Corp is singled out for its spoil.
#   4. Kia Corp is under fire for its destructive strategy.
#   5. Kia Corp is singled out for its destructive.
# Walt Disney Co:
#   1. Walt Disney Co is criticized for its failure to address toxic.
#   2. The environmentally friendly approach of Walt Disney Co reflects its commitment to healthy.
#   3. Walt Disney Co is recognized for its revitalization approach and its positive impact on innovative.
#   4. Walt Disney Co adopts a rehabilitation strategy to promote eco-label.
#   5. The valorization approach of Walt Disney Co reflects its commitment to green.
# American International Group Inc:
#   1. American International Group Inc integrates green energy strategies with overexploitation management.
#   2. The company American International Group Inc is researching regenerator solutions for dangerous.
#   3. American International Group Inc implements integrity measures while considering harm.
#   4. American International Group Inc is under fire for its illegal logging strategy.
#   5. American International Group Inc is dedicated to eco-label approaches and malevolent initiatives.
# Shell PLC:
#   1. Shell PLC's sustainability efforts are focused on damaging.
#   2. The company Shell PLC is committed to a recoverable approach to promote eco-label.
#   3. Some question Shell PLC's commitment due to its hazardous.
#   4. As a energy-efficient company, Shell PLC takes measures to encourage recoverable.
#   5. Shell PLC is criticized for its failure to address overexploitation.
# NEC Corp:
#   1. NEC Corp is exploring renewable energy initiatives to address perilous.
#   2. NEC Corp's wasteful practices have raised concerns among environmentalists.
#   3. NEC Corp's integrity efforts are focused on overconsumption.
#   4. NEC Corp's malevolent initiative is viewed with skepticism.
#   5. Thanks to its valorization initiative, NEC Corp strengthens its commitment to ethical.
# Avient Corp:
#   1. The wind energy approach of Avient Corp reflects its commitment to circular economy.
#   2. Avient Corp values its eco-responsible commitment and its respect for regeneration.
#   3. Avient Corp's toxicity practices have raised concerns among environmentalists.
#   4. Avient Corp is recognized for its eco-tourism approach and its positive impact on environmentally friendly.
# Toyota Motor Corp:
#   1. Toyota Motor Corp is dedicated to revitalization approaches and threat initiatives.
#   2. Toyota Motor Corp is developing regeneration practices while managing harm.
#   3. As a green energy company, Toyota Motor Corp takes measures to encourage zero waste.
#   4. The company Toyota Motor Corp emphasizes carbon neutral practices alongside malevolent.
#   5. Toyota Motor Corp is dedicated to responsible approaches and excessive exploitation initiatives.
# Aeon Co Ltd:
#   1. Aeon Co Ltd adopts a green strategy to promote energy efficiency.
#   2. As a eco-citizen company, Aeon Co Ltd takes measures to encourage restoration.
#   3. Aeon Co Ltd implements eco-friendly practices to support ethical.
# Starbucks Corp:
#   1. Starbucks Corp is recognized for its social responsibility approach and its positive impact on wind energy.
#   2. Starbucks Corp implements eco-design practices to support recovery.
#   3. Starbucks Corp is recognized for its rehabilitation approach and its positive impact on conscious consumption.
#   4. The approach of Starbucks Corp involves continuous improvement methods to mitigate hazardous.
# STMicroelectronics NV:
#   1. STMicroelectronics NV's valorization efforts are focused on risk.
#   2. The approach of STMicroelectronics NV involves revitalization methods to mitigate spoil.
#   3. The company STMicroelectronics NV emphasizes valorization practices alongside environmental degradation.
#   4. STMicroelectronics NV's disruption initiative is viewed with skepticism.
# Deutsche Bank AG:
#   1. Deutsche Bank AG is under fire for its aggressive strategy.
#   2. The company Deutsche Bank AG is researching solar energy solutions for illegal logging.
#   3. Deutsche Bank AG is recognized for its responsible approach and its positive impact on ethical.
#   4. The clean approach of Deutsche Bank AG reflects its commitment to beneficial.
#   5. Deutsche Bank AG is criticized for its failure to address catastrophe.
# Enel SpA:
#   1. Through its greenhouse effect actions, Enel SpA aims to improve green.
#   2. Through its social responsibility actions, Enel SpA aims to improve social responsibility.
#   3. Enel SpA integrates harmony strategies with contamination management.
#   4. Enel SpA implements biodiversity practices to support eco-conscious.
# West Japan Railway Co:
#   1. As a conscious consumption company, West Japan Railway Co takes measures to encourage energy efficiency.
#   2. Concerns are raised about West Japan Railway Co's catastrophic practices.
#   3. West Japan Railway Co is under fire for its malevolent strategy.
# Engie SA:
#   1. Concerns are raised about Engie SA's unacceptable practices.
#   2. As a eco-tourism company, Engie SA takes measures to encourage conscious consumption.
#   3. Engie SA is developing rehabilitation practices while managing environmental degradation.
#   4. Concerns are raised about Engie SA's wasteful practices.
# Intercontinental Hotels Group plc:
#   1. The company Intercontinental Hotels Group plc is committed to a conservation approach to promote prosperity.
#   2. Intercontinental Hotels Group plc values its well-being commitment and its respect for eco-habitat.
#   3. Intercontinental Hotels Group plc implements revitalization practices to support eco-citizen.
#   4. Intercontinental Hotels Group plc values its social responsibility commitment and its respect for continuous improvement.
#   5. Intercontinental Hotels Group plc adopts a social responsibility strategy to promote eco-responsible.
# Deutsche Lufthansa AG:
#   1. Deutsche Lufthansa AG is committed to carbon neutral actions and addressing threat.
#   2. Deutsche Lufthansa AG is exploring green initiatives to address waste.
#   3. Deutsche Lufthansa AG values its green commitment and its respect for energy efficiency.
#   4. Deutsche Lufthansa AG implements ecological practices to support fair.
# Ampol Ltd:
#   1. Ampol Ltd is under fire for its deterioration strategy.
#   2. Ampol Ltd is singled out for its risk.
#   3. Ampol Ltd values its sustainable mobility commitment and its respect for environmentally friendly.
# Ajinomoto Co Inc:
#   1. Some question Ajinomoto Co Inc's commitment due to its ecological damage.
#   2. The company Ajinomoto Co Inc is committed to a fulfillment approach to promote eco-efficient.
#   3. The approach of Ajinomoto Co Inc involves fair methods to mitigate worrisome.
# Heineken NV:
#   1. Thanks to its rehabilitation initiative, Heineken NV strengthens its commitment to eco-citizen.
#   2. The company Heineken NV is researching clean energy solutions for inadequate.
#   3. The eco-habitat approach of Heineken NV reflects its commitment to responsible consumption.
#   4. Heineken NV is criticized for its failure to address overconsumption.
#   5. The company Heineken NV is committed to a eco-responsible approach to promote energy-efficient.
# Banco Bilbao Vizcaya Argentaria SA:
#   1. Banco Bilbao Vizcaya Argentaria SA's worrisome initiative is viewed with skepticism.
#   2. Banco Bilbao Vizcaya Argentaria SA is criticized for its failure to address disruption.
#   3. Banco Bilbao Vizcaya Argentaria SA values its energy-efficient commitment and its respect for energy efficiency.
#   4. Through its regeneration actions, Banco Bilbao Vizcaya Argentaria SA aims to improve rehabilitation.
#   5. Banco Bilbao Vizcaya Argentaria SA adopts a fair strategy to promote energy-efficient.
# JPMorgan Chase & Co:
#   1. JPMorgan Chase & Co values its greenhouse effect commitment and its respect for social responsibility.
#   2. JPMorgan Chase & Co implements renewable practices to support greenhouse effect.
#   3. JPMorgan Chase & Co adopts a solidarity strategy to promote regenerator.
# Bed Bath & Beyond Inc:
#   1. The company Bed Bath & Beyond Inc is committed to a efficiency approach to promote prosperity.
#   2. The approach of Bed Bath & Beyond Inc involves renewable methods to mitigate ecological damage.
#   3. Some question Bed Bath & Beyond Inc's commitment due to its ravager.
#   4. As a eco-conscious company, Bed Bath & Beyond Inc takes measures to encourage fair.
# Xerox Holdings Corp:
#   1. The company Xerox Holdings Corp is committed to a recovery approach to promote organic.
#   2. Xerox Holdings Corp's spoil initiative is viewed with skepticism.
#   3. The company Xerox Holdings Corp emphasizes ethical practices alongside overexploitation.
#   4. Xerox Holdings Corp is recognized for its fair approach and its positive impact on environmentally friendly.
# Hershey Co:
#   1. Hershey Co's dangerous practices have raised concerns among environmentalists.
#   2. Hershey Co implements sustainable mobility practices to support regenerator.
#   3. Thanks to its sustainable mobility initiative, Hershey Co strengthens its commitment to permaculture.
# Barclays plc:
#   1. The company Barclays plc is criticized for its lack of commitment to damage.
#   2. As a continuous improvement company, Barclays plc takes measures to encourage renewable.
#   3. Thanks to its eco-habitat initiative, Barclays plc strengthens its commitment to recycling.
#   4. Barclays plc is singled out for its disrespectful.
#   5. Barclays plc adopts a energy-efficient strategy to promote solidarity.
# Philip Morris International Inc:
#   1. The carbon neutral approach of Philip Morris International Inc reflects its commitment to fair.
#   2. Philip Morris International Inc faces scrutiny for its overconsumption approach.
#   3. Concerns are raised about Philip Morris International Inc's damaging practices.
# Credit Agricole SA:
#   1. Credit Agricole SA is under fire for its overconsumption strategy.
#   2. The eco-friendly approach of Credit Agricole SA reflects its commitment to regenerator.
#   3. Credit Agricole SA is recognized for its eco-design approach and its positive impact on regenerator.
#   4. Credit Agricole SA is committed to restoration actions and addressing unacceptable.
# ANZ Group Holdings Ltd:
#   1. ANZ Group Holdings Ltd adopts a well-being strategy to promote beneficial.
#   2. ANZ Group Holdings Ltd's catastrophe initiative is viewed with skepticism.
#   3. ANZ Group Holdings Ltd values its biodiversity commitment and its respect for environmentally friendly.
# Alphabet Inc:
#   1. Alphabet Inc faces scrutiny for its damage approach.
#   2. Alphabet Inc is recognized for its rehabilitation approach and its positive impact on eco-tourism.
#   3. The company Alphabet Inc is criticized for its lack of commitment to illegal logging.
#   4. Alphabet Inc is developing conservation practices while managing perilous.
#   5. Alphabet Inc is recognized for its organic approach and its positive impact on restoration.
# Raytheon Technologies Corp:
#   1. Raytheon Technologies Corp implements conscious spreading practices to support efficient.
#   2. Raytheon Technologies Corp's environmentally friendly efforts are focused on degradation.
#   3. Raytheon Technologies Corp values its beneficial commitment and its respect for fulfillment.
#   4. Raytheon Technologies Corp faces scrutiny for its greenhouse gas emissions approach.
#   5. The company Raytheon Technologies Corp is committed to a healthy approach to promote conscious spreading.
# Korea Electric Power Corp:
#   1. Thanks to its renewable energy initiative, Korea Electric Power Corp strengthens its commitment to greenhouse effect.
#   2. The company Korea Electric Power Corp is researching clean solutions for wasteful.
#   3. The company Korea Electric Power Corp is criticized for its lack of commitment to irreparable.
# Bridgestone Corp:
#   1. Bridgestone Corp is under fire for its waste strategy.
#   2. The circular economy approach of Bridgestone Corp reflects its commitment to eco-efficient.
#   3. Bridgestone Corp communicates about its healthy commitment and its positive contribution to fulfillment.
#   4. The approach of Bridgestone Corp involves ecological methods to mitigate destructive.
# Novartis AG:
#   1. Through its restorer actions, Novartis AG aims to improve fulfillment.
#   2. Novartis AG communicates about its restorer commitment and its positive contribution to efficiency.
#   3. Novartis AG is singled out for its disrespectful.
#   4. Novartis AG adopts a eco-conscious strategy to promote environmentally friendly.
# Mercedes-Benz Group AG:
#   1. Mercedes-Benz Group AG's excessive exploitation practices have raised concerns among environmentalists.
#   2. Mercedes-Benz Group AG is exploring renewable energy initiatives to address harmful.
#   3. The company Mercedes-Benz Group AG emphasizes prosperity practices alongside damaging.
# Coface SA:
#   1. Through its healthy actions, Coface SA aims to improve sustainability.
#   2. The ethical approach of Coface SA reflects its commitment to rehabilitation.
#   3. Thanks to its eco-tourism initiative, Coface SA strengthens its commitment to carbon neutral.
#   4. Coface SA's pollute initiative is viewed with skepticism.
#   5. Thanks to its recoverable initiative, Coface SA strengthens its commitment to preservation.
# ArcelorMittal SA:
#   1. ArcelorMittal SA adopts a renewable energy strategy to promote energy efficiency.
#   2. ArcelorMittal SA is criticized for its failure to address deforestation.
#   3. Concerns are raised about ArcelorMittal SA's harmful practices.
#   4. Concerns are raised about ArcelorMittal SA's pollute practices.
#   5. As a green company, ArcelorMittal SA takes measures to encourage eco-label.
# Thomson Reuters Corp:
#   1. Thomson Reuters Corp is dedicated to clean approaches and irresponsible initiatives.
#   2. The company Thomson Reuters Corp is researching eco-citizen solutions for toxic.
#   3. Thomson Reuters Corp implements ecological practices to support recovery.
# Stellantis NV:
#   1. Stellantis NV is blamed for its greenhouse gas emissions impact.
#   2. Stellantis NV values its fulfillment commitment and its respect for harmony.
#   3. As a responsible consumption company, Stellantis NV takes measures to encourage green energy.
#   4. Stellantis NV implements sustainable practices to support solar energy.
# PETRONAS Chemicals Group Bhd:
#   1. PETRONAS Chemicals Group Bhd is dedicated to restoration approaches and climate change initiatives.
#   2. PETRONAS Chemicals Group Bhd communicates about its eco-responsible commitment and its positive contribution to well-being.
#   3. The company PETRONAS Chemicals Group Bhd emphasizes sustainability practices alongside pollute.
#   4. PETRONAS Chemicals Group Bhd is recognized for its eco-citizen approach and its positive impact on ethical.
#   5. Thanks to its integrity initiative, PETRONAS Chemicals Group Bhd strengthens its commitment to sustainable.
# Telkom SA SOC Ltd:
#   1. Telkom SA SOC Ltd is blamed for its destroyed natural habitat impact.
#   2. Telkom SA SOC Ltd is singled out for its irresponsible.
#   3. As a conscious consumption company, Telkom SA SOC Ltd takes measures to encourage revitalization.
#   4. Telkom SA SOC Ltd adopts a eco-label strategy to promote efficiency.
#   5. The preservation approach of Telkom SA SOC Ltd reflects its commitment to solidarity.
# Eli Lilly and Co:
#   1. Eli Lilly and Co is committed to recycling actions and addressing disruption.
#   2. Eli Lilly and Co implements environmentally friendly practices to support harmony.
#   3. As a green energy company, Eli Lilly and Co takes measures to encourage harmony.
#   4. Eli Lilly and Co integrates preservation strategies with contamination management.
# HSBC Holdings plc:
#   1. HSBC Holdings plc adopts a eco-friendly strategy to promote responsible consumption.
#   2. The biodiversity approach of HSBC Holdings plc reflects its commitment to solar energy.
#   3. Concerns are raised about HSBC Holdings plc's disruption practices.
# AT&T Inc:
#   1. The company AT&T Inc is researching ecological solutions for deforestation.
#   2. AT&T Inc is under fire for its spoil strategy.
#   3. AT&T Inc adopts a restorer strategy to promote eco-habitat.
# Abrdn PLC:
#   1. Abrdn PLC adopts a eco-citizen strategy to promote recovery.
#   2. The company Abrdn PLC is committed to a circular economy approach to promote organic.
#   3. The approach of Abrdn PLC involves regeneration methods to mitigate inadequate.
# Carlsberg A/S:
#   1. Carlsberg A/S faces scrutiny for its disruption approach.
#   2. The approach of Carlsberg A/S involves biodiversity methods to mitigate excessive exploitation.
#   3. The company Carlsberg A/S is researching recoverable solutions for worrisome.
#   4. Carlsberg A/S is recognized for its recovery approach and its positive impact on carbon neutral.
#   5. Carlsberg A/S communicates about its recycling commitment and its positive contribution to agroecology.
# Solvay SA:
#   1. Concerns are raised about Solvay SA's dangerous practices.
#   2. Solvay SA is singled out for its environmental degradation.
#   3. Thanks to its conscious spreading initiative, Solvay SA strengthens its commitment to energy-efficient.
#   4. Solvay SA is recognized for its eco-conscious approach and its positive impact on ethical.
#   5. Solvay SA is under fire for its malevolent strategy.
# ConocoPhillips:
#   1. ConocoPhillips faces scrutiny for its spoil approach.
#   2. Through its fulfillment actions, ConocoPhillips aims to improve regenerator.
#   3. The carbon neutral approach of ConocoPhillips reflects its commitment to carbon neutral.
#   4. Through its prosperity actions, ConocoPhillips aims to improve eco-innovation.
# Toronto-Dominion Bank:
#   1. The company Toronto-Dominion Bank is researching efficiency solutions for spoil.
#   2. The company Toronto-Dominion Bank is criticized for its lack of commitment to deteriorate.
#   3. Toronto-Dominion Bank adopts a conscious consumption strategy to promote healthy.
#   4. Toronto-Dominion Bank's harmful practices have raised concerns among environmentalists.
#   5. The approach of Toronto-Dominion Bank involves energy efficiency methods to mitigate contamination.
# Baker Hughes Co:
#   1. The company Baker Hughes Co is committed to a eco-efficient approach to promote integrity.
#   2. Baker Hughes Co implements eco-habitat measures while considering overexploitation.
#   3. Thanks to its renewable energy initiative, Baker Hughes Co strengthens its commitment to permaculture.
#   4. Baker Hughes Co is under fire for its inadequate strategy.
# UBS Group AG:
#   1. Some question UBS Group AG's commitment due to its destructive.
#   2. UBS Group AG values its social responsibility commitment and its respect for innovative.
#   3. UBS Group AG is blamed for its climate change impact.
#   4. UBS Group AG is committed to solar energy actions and addressing environmental degradation.
# AP Moeller - Maersk A/S:
#   1. AP Moeller - Maersk A/S is blamed for its destroyed natural habitat impact.
#   2. AP Moeller - Maersk A/S implements clean energy practices to support green energy.
#   3. AP Moeller - Maersk A/S is blamed for its irresponsible impact.
#   4. AP Moeller - Maersk A/S implements eco-responsible practices to support fair.
# Telenor ASA:
#   1. Telenor ASA values its energy efficiency commitment and its respect for eco-citizen.
#   2. Telenor ASA's irresponsible practices have raised concerns among environmentalists.
#   3. Telenor ASA is criticized for its failure to address harmful.
#   4. The company Telenor ASA is committed to a sustainability approach to promote eco-conscious.
# Eni SpA:
#   1. As a clean energy company, Eni SpA takes measures to encourage recovery.
#   2. Eni SpA is under fire for its harmful strategy.
#   3. Thanks to its agroecology initiative, Eni SpA strengthens its commitment to solidarity.
#   4. Eni SpA faces scrutiny for its threat approach.
# Carnival Corp:
#   1. The company Carnival Corp is criticized for its lack of commitment to greenhouse gas emissions.
#   2. Carnival Corp's eco-responsible efforts are focused on disturb.
#   3. Carnival Corp is dedicated to eco-innovation approaches and environmental denial initiatives.
# Nan Ya Plastics Corp:
#   1. Nan Ya Plastics Corp communicates about its recycling commitment and its positive contribution to energy efficiency.
#   2. The approach of Nan Ya Plastics Corp involves solar energy methods to mitigate greenhouse gas emissions.
#   3. Nan Ya Plastics Corp's greenhouse effect efforts are focused on environmental denial.
# Sanofi SA:
#   1. The eco-efficient approach of Sanofi SA reflects its commitment to permaculture.
#   2. The company Sanofi SA is researching clean energy solutions for ecological damage.
#   3. Sanofi SA is blamed for its damaging impact.
#   4. Sanofi SA is dedicated to eco-responsible approaches and destructive initiatives.
# Conagra Brands Inc:
#   1. Conagra Brands Inc is recognized for its eco-tourism approach and its positive impact on rehabilitation.
#   2. Conagra Brands Inc's pollute practices have raised concerns among environmentalists.
#   3. Conagra Brands Inc faces scrutiny for its pollute approach.
# Southwest Airlines Co:
#   1. Southwest Airlines Co is recognized for its conscious spreading approach and its positive impact on valorization.
#   2. Some question Southwest Airlines Co's commitment due to its irresponsible.
#   3. The company Southwest Airlines Co is committed to a eco-tourism approach to promote harmony.
#   4. As a permaculture company, Southwest Airlines Co takes measures to encourage eco-habitat.
#   5. Concerns are raised about Southwest Airlines Co's ravager practices.
# Mitsui & Co Ltd:
#   1. The approach of Mitsui & Co Ltd involves integrity methods to mitigate degradation.
#   2. Mitsui & Co Ltd integrates positive strategies with aggressive management.
#   3. Mitsui & Co Ltd is recognized for its sustainability approach and its positive impact on energy-efficient.
#   4. The approach of Mitsui & Co Ltd involves eco-habitat methods to mitigate degradation.
# Oracle Corp:
#   1. Oracle Corp implements fair practices to support sustainability.
#   2. Oracle Corp's eco-friendly efforts are focused on waste.
#   3. The eco-conscious approach of Oracle Corp reflects its commitment to positive.
#   4. Thanks to its responsible consumption initiative, Oracle Corp strengthens its commitment to responsible.

# %%
# Sélectionner 100 entreprises au hasard avec leurs ISIN
random_companies = df1[['Company', 'ISIN']].sample(n=100, random_state=42)

# Utiliser la fonction pour générer les phrases
a = 3
b = 5
company_sentences = generate_environmental_communication(random_companies['Company'].tolist(), Dico_env_en, a, b)

# Convertir le dictionnaire company_sentences en DataFrame
df_sentences = pd.DataFrame([(company, sentence) for company, sentences in company_sentences.items() for sentence in sentences], 
                            columns=['Company', 'Sentence'])

# Effectuer une jointure pour ajouter les ISIN à chaque entreprise
df_final = pd.merge(df_sentences, random_companies, on='Company', how='left')

# Afficher les phrases générées par entreprise avec leur ISIN
for idx, row in df_final.iterrows():
    print(f"{row['Company']} (ISIN: {row['ISIN']}):")
    print(f"  {idx + 1}. {row['Sentence']}")
    print('-' * 50)
# Out:
# International Paper Co (ISIN: US4601461035):
#   1. International Paper Co is singled out for its overconsumption.
# --------------------------------------------------
# International Paper Co (ISIN: US4601461035):
#   2. International Paper Co faces scrutiny for its environmental denial approach.
# --------------------------------------------------
# International Paper Co (ISIN: US4601461035):
#   3. As a ecological company, International Paper Co takes measures to encourage eco-efficient.
# --------------------------------------------------
# International Paper Co (ISIN: US4601461035):
#   4. The company International Paper Co is criticized for its lack of commitment to disruption.
# --------------------------------------------------
# China Development Bank Financial Leasing Co Ltd (ISIN: CNE1000027C9):
#   5. China Development Bank Financial Leasing Co Ltd is singled out for its degradation.
# --------------------------------------------------
# China Development Bank Financial Leasing Co Ltd (ISIN: CNE1000027C9):
#   6. China Development Bank Financial Leasing Co Ltd is committed to social responsibility actions and addressing inappropriate.
# --------------------------------------------------
# China Development Bank Financial Leasing Co Ltd (ISIN: CNE1000027C9):
#   7. The company China Development Bank Financial Leasing Co Ltd is researching restorer solutions for pollute.
# --------------------------------------------------
# China Development Bank Financial Leasing Co Ltd (ISIN: CNE1000027C9):
#   8. The company China Development Bank Financial Leasing Co Ltd emphasizes fair practices alongside illegal logging.
# --------------------------------------------------
# China Development Bank Financial Leasing Co Ltd (ISIN: CNE1000027C9):
#   9. China Development Bank Financial Leasing Co Ltd is criticized for its failure to address harmful.
# --------------------------------------------------
# Southern Co (ISIN: US8425871071):
#   10. Southern Co adopts a valorization strategy to promote energy-efficient.
# --------------------------------------------------
# Southern Co (ISIN: US8425871071):
#   11. The company Southern Co is committed to a harmony approach to promote eco-citizen.
# --------------------------------------------------
# Southern Co (ISIN: US8425871071):
#   12. Southern Co faces scrutiny for its catastrophe approach.
# --------------------------------------------------
# Southern Co (ISIN: US8425871071):
#   13. Southern Co is recognized for its eco-habitat approach and its positive impact on energy efficiency.
# --------------------------------------------------
# Sappi Ltd (ISIN: ZAE000006284):
#   14. Thanks to its efficiency initiative, Sappi Ltd strengthens its commitment to well-being.
# --------------------------------------------------
# Sappi Ltd (ISIN: ZAE000006284):
#   15. Sappi Ltd is singled out for its pollute.
# --------------------------------------------------
# Sappi Ltd (ISIN: ZAE000006284):
#   16. Thanks to its renewable energy initiative, Sappi Ltd strengthens its commitment to responsible.
# --------------------------------------------------
# Johnson Controls International PLC (ISIN: IE00BY7QL619):
#   17. Johnson Controls International PLC values its conscious spreading commitment and its respect for restoration.
# --------------------------------------------------
# Johnson Controls International PLC (ISIN: IE00BY7QL619):
#   18. Some question Johnson Controls International PLC's commitment due to its deteriorate.
# --------------------------------------------------
# Johnson Controls International PLC (ISIN: IE00BY7QL619):
#   19. Johnson Controls International PLC is committed to clean energy actions and addressing worrisome.
# --------------------------------------------------
# Johnson Controls International PLC (ISIN: IE00BY7QL619):
#   20. Johnson Controls International PLC implements eco-tourism measures while considering inadequate.
# --------------------------------------------------
# Johnson Controls International PLC (ISIN: IE00BY7QL619):
#   21. The company Johnson Controls International PLC is committed to a efficient approach to promote eco-design.
# --------------------------------------------------
# Skanska AB (ISIN: SE0000113250):
#   22. Skanska AB is criticized for its failure to address environmental degradation.
# --------------------------------------------------
# Skanska AB (ISIN: SE0000113250):
#   23. Thanks to its innovative initiative, Skanska AB strengthens its commitment to eco-innovation.
# --------------------------------------------------
# Skanska AB (ISIN: SE0000113250):
#   24. Skanska AB is under fire for its damaging strategy.
# --------------------------------------------------
# Skanska AB (ISIN: SE0000113250):
#   25. Some question Skanska AB's commitment due to its disturb.
# --------------------------------------------------
# Skanska AB (ISIN: SE0000113250):
#   26. Some question Skanska AB's commitment due to its environmental denial.
# --------------------------------------------------
# Tata Motors Ltd (ISIN: INE155A01022):
#   27. The approach of Tata Motors Ltd involves preservation methods to mitigate environmental degradation.
# --------------------------------------------------
# Tata Motors Ltd (ISIN: INE155A01022):
#   28. The company Tata Motors Ltd is criticized for its lack of commitment to disrespectful.
# --------------------------------------------------
# Tata Motors Ltd (ISIN: INE155A01022):
#   29. The company Tata Motors Ltd is criticized for its lack of commitment to disturb.
# --------------------------------------------------
# Tata Motors Ltd (ISIN: INE155A01022):
#   30. Tata Motors Ltd implements carbon neutral measures while considering risk.
# --------------------------------------------------
# Tata Motors Ltd (ISIN: INE155A01022):
#   31. Tata Motors Ltd faces scrutiny for its deterioration approach.
# --------------------------------------------------
# Alstom SA (ISIN: FR0010220475):
#   32. The approach of Alstom SA involves regenerator methods to mitigate spoil.
# --------------------------------------------------
# Alstom SA (ISIN: FR0010220475):
#   33. Through its restorer actions, Alstom SA aims to improve renewable energy.
# --------------------------------------------------
# Alstom SA (ISIN: FR0010220475):
#   34. Alstom SA is criticized for its failure to address disturb.
# --------------------------------------------------
# Alstom SA (ISIN: FR0010220475):
#   35. Thanks to its continuous improvement initiative, Alstom SA strengthens its commitment to prosperity.
# --------------------------------------------------
# Clear Channel Outdoor Holdings Inc (ISIN: US18453H1068):
#   36. Clear Channel Outdoor Holdings Inc faces scrutiny for its catastrophic approach.
# --------------------------------------------------
# Clear Channel Outdoor Holdings Inc (ISIN: US18453H1068):
#   37. Thanks to its integrity initiative, Clear Channel Outdoor Holdings Inc strengthens its commitment to sustainable mobility.
# --------------------------------------------------
# Clear Channel Outdoor Holdings Inc (ISIN: US18453H1068):
#   38. The company Clear Channel Outdoor Holdings Inc emphasizes conservation practices alongside deterioration.
# --------------------------------------------------
# Clear Channel Outdoor Holdings Inc (ISIN: US18453H1068):
#   39. Clear Channel Outdoor Holdings Inc faces scrutiny for its environmental degradation approach.
# --------------------------------------------------
# Clear Channel Outdoor Holdings Inc (ISIN: US18453H1068):
#   40. As a rehabilitation company, Clear Channel Outdoor Holdings Inc takes measures to encourage eco-friendly.
# --------------------------------------------------
# Marks and Spencer Group PLC (ISIN: GB0031274896):
#   41. Marks and Spencer Group PLC implements innovative measures while considering catastrophe.
# --------------------------------------------------
# Marks and Spencer Group PLC (ISIN: GB0031274896):
#   42. Marks and Spencer Group PLC is developing integrity practices while managing disturb.
# --------------------------------------------------
# Marks and Spencer Group PLC (ISIN: GB0031274896):
#   43. Marks and Spencer Group PLC integrates eco-innovation strategies with climate change management.
# --------------------------------------------------
# Roche Holding AG (ISIN: CH0012032048):
#   44. The company Roche Holding AG is committed to a green energy approach to promote wind energy.
# --------------------------------------------------
# Roche Holding AG (ISIN: CH0012032048):
#   45. Concerns are raised about Roche Holding AG's pollutant practices.
# --------------------------------------------------
# Roche Holding AG (ISIN: CH0012032048):
#   46. Roche Holding AG communicates about its clean commitment and its positive contribution to recycling.
# --------------------------------------------------
# Roche Holding AG (ISIN: CH0012032048):
#   47. Roche Holding AG adopts a fair strategy to promote green.
# --------------------------------------------------
# Roche Holding AG (ISIN: CH0012032048):
#   48. Roche Holding AG implements eco-tourism practices to support green.
# --------------------------------------------------
# Xinjiang Goldwind Science & Technology Co Ltd (ISIN: CNE1000008S5):
#   49. Xinjiang Goldwind Science & Technology Co Ltd's clean energy efforts are focused on deterioration.
# --------------------------------------------------
# Xinjiang Goldwind Science & Technology Co Ltd (ISIN: CNE1000008S5):
#   50. The fair approach of Xinjiang Goldwind Science & Technology Co Ltd reflects its commitment to healthy.
# --------------------------------------------------
# Xinjiang Goldwind Science & Technology Co Ltd (ISIN: CNE1000008S5):
#   51. Xinjiang Goldwind Science & Technology Co Ltd implements eco-conscious practices to support solar energy.
# --------------------------------------------------
# Xinjiang Goldwind Science & Technology Co Ltd (ISIN: CNE1000008S5):
#   52. The approach of Xinjiang Goldwind Science & Technology Co Ltd involves positive methods to mitigate perilous.
# --------------------------------------------------
# Microsoft Corp (ISIN: US5949181045):
#   53. Microsoft Corp is recognized for its renewable approach and its positive impact on renewable energy.
# --------------------------------------------------
# Microsoft Corp (ISIN: US5949181045):
#   54. Microsoft Corp is blamed for its inadequate impact.
# --------------------------------------------------
# Microsoft Corp (ISIN: US5949181045):
#   55. The positive approach of Microsoft Corp reflects its commitment to fulfillment.
# --------------------------------------------------
# Eastman Kodak Co (ISIN: US2774614067):
#   56. The ecological approach of Eastman Kodak Co reflects its commitment to fair.
# --------------------------------------------------
# Eastman Kodak Co (ISIN: US2774614067):
#   57. Eastman Kodak Co implements fulfillment practices to support eco-friendly.
# --------------------------------------------------
# Eastman Kodak Co (ISIN: US2774614067):
#   58. Eastman Kodak Co is exploring social responsibility initiatives to address pollute.
# --------------------------------------------------
# China Steel Corp (ISIN: TW0002002003):
#   59. China Steel Corp is developing ethical practices while managing pollute.
# --------------------------------------------------
# China Steel Corp (ISIN: TW0002002003):
#   60. China Steel Corp integrates recovery strategies with disturb management.
# --------------------------------------------------
# China Steel Corp (ISIN: TW0002002003):
#   61. China Steel Corp adopts a energy-efficient strategy to promote environmentally friendly.
# --------------------------------------------------
# China Steel Corp (ISIN: TW0002002003):
#   62. The company China Steel Corp is criticized for its lack of commitment to resource plundering.
# --------------------------------------------------
# China Steel Corp (ISIN: TW0002002003):
#   63. China Steel Corp is dedicated to social responsibility approaches and pollutant initiatives.
# --------------------------------------------------
# BP plc (ISIN: GB0007980591):
#   64. The approach of BP plc involves fulfillment methods to mitigate destroyed natural habitat.
# --------------------------------------------------
# BP plc (ISIN: GB0007980591):
#   65. Through its continuous improvement actions, BP plc aims to improve responsible.
# --------------------------------------------------
# BP plc (ISIN: GB0007980591):
#   66. BP plc values its agroecology commitment and its respect for renewable energy.
# --------------------------------------------------
# BP plc (ISIN: GB0007980591):
#   67. BP plc's environmentally friendly efforts are focused on catastrophe.
# --------------------------------------------------
# Qualcomm Inc (ISIN: US7475251036):
#   68. Through its agroecology actions, Qualcomm Inc aims to improve clean energy.
# --------------------------------------------------
# Qualcomm Inc (ISIN: US7475251036):
#   69. Qualcomm Inc is recognized for its preservation approach and its positive impact on conscious spreading.
# --------------------------------------------------
# Qualcomm Inc (ISIN: US7475251036):
#   70. Qualcomm Inc is recognized for its integrity approach and its positive impact on eco-citizen.
# --------------------------------------------------
# Estee Lauder Companies Inc (ISIN: US5184391044):
#   71. Estee Lauder Companies Inc is criticized for its failure to address destructive.
# --------------------------------------------------
# Estee Lauder Companies Inc (ISIN: US5184391044):
#   72. Estee Lauder Companies Inc communicates about its renewable commitment and its positive contribution to recovery.
# --------------------------------------------------
# Estee Lauder Companies Inc (ISIN: US5184391044):
#   73. Estee Lauder Companies Inc is dedicated to beneficial approaches and overconsumption initiatives.
# --------------------------------------------------
# Hitachi Ltd (ISIN: JP3788600009):
#   74. Hitachi Ltd is developing social responsibility practices while managing damage.
# --------------------------------------------------
# Hitachi Ltd (ISIN: JP3788600009):
#   75. Hitachi Ltd's resource plundering initiative is viewed with skepticism.
# --------------------------------------------------
# Hitachi Ltd (ISIN: JP3788600009):
#   76. Hitachi Ltd faces scrutiny for its risk approach.
# --------------------------------------------------
# Hitachi Ltd (ISIN: JP3788600009):
#   77. Hitachi Ltd is recognized for its recovery approach and its positive impact on valorization.
# --------------------------------------------------
# Hitachi Ltd (ISIN: JP3788600009):
#   78. The company Hitachi Ltd emphasizes integrity practices alongside perilous.
# --------------------------------------------------
# Weyerhaeuser Co (ISIN: US9621661043):
#   79. Weyerhaeuser Co is under fire for its deteriorate strategy.
# --------------------------------------------------
# Weyerhaeuser Co (ISIN: US9621661043):
#   80. As a eco-label company, Weyerhaeuser Co takes measures to encourage permaculture.
# --------------------------------------------------
# Weyerhaeuser Co (ISIN: US9621661043):
#   81. Weyerhaeuser Co faces scrutiny for its environmental degradation approach.
# --------------------------------------------------
# Weyerhaeuser Co (ISIN: US9621661043):
#   82. Weyerhaeuser Co faces scrutiny for its worrisome approach.
# --------------------------------------------------
# PepsiCo Inc (ISIN: US7134481081):
#   83. The company PepsiCo Inc is criticized for its lack of commitment to damaging.
# --------------------------------------------------
# PepsiCo Inc (ISIN: US7134481081):
#   84. PepsiCo Inc implements revitalization measures while considering spoil.
# --------------------------------------------------
# PepsiCo Inc (ISIN: US7134481081):
#   85. PepsiCo Inc is developing eco-efficient practices while managing wasteful.
# --------------------------------------------------
# Siemens AG (ISIN: DE0007236101):
#   86. The company Siemens AG emphasizes efficiency practices alongside catastrophe.
# --------------------------------------------------
# Siemens AG (ISIN: DE0007236101):
#   87. Siemens AG's damaging initiative is viewed with skepticism.
# --------------------------------------------------
# Siemens AG (ISIN: DE0007236101):
#   88. Siemens AG adopts a valorization strategy to promote responsible.
# --------------------------------------------------
# Stelco Holdings Inc (ISIN: CA8585221051):
#   89. Stelco Holdings Inc adopts a eco-label strategy to promote environmentally friendly.
# --------------------------------------------------
# Stelco Holdings Inc (ISIN: CA8585221051):
#   90. Through its zero waste actions, Stelco Holdings Inc aims to improve renewable.
# --------------------------------------------------
# Stelco Holdings Inc (ISIN: CA8585221051):
#   91. Stelco Holdings Inc is blamed for its worrisome impact.
# --------------------------------------------------
# Stelco Holdings Inc (ISIN: CA8585221051):
#   92. Stelco Holdings Inc communicates about its renewable commitment and its positive contribution to innovative.
# --------------------------------------------------
# Enel Generacion Chile SA (ISIN: CLP3710M1090):
#   93. Enel Generacion Chile SA is committed to eco-efficient actions and addressing harmful.
# --------------------------------------------------
# Enel Generacion Chile SA (ISIN: CLP3710M1090):
#   94. Enel Generacion Chile SA implements well-being measures while considering degradation.
# --------------------------------------------------
# Enel Generacion Chile SA (ISIN: CLP3710M1090):
#   95. Enel Generacion Chile SA implements permaculture practices to support carbon neutral.
# --------------------------------------------------
# Enel Generacion Chile SA (ISIN: CLP3710M1090):
#   96. Some question Enel Generacion Chile SA's commitment due to its overconsumption.
# --------------------------------------------------
# Pfizer Inc (ISIN: US7170811035):
#   97. Pfizer Inc is developing biodiversity practices while managing resource plundering.
# --------------------------------------------------
# Pfizer Inc (ISIN: US7170811035):
#   98. Pfizer Inc is recognized for its innovative approach and its positive impact on fair.
# --------------------------------------------------
# Pfizer Inc (ISIN: US7170811035):
#   99. The agroecology approach of Pfizer Inc reflects its commitment to regeneration.
# --------------------------------------------------
# Fawaz Abdulaziz Alhokair Company SJSC (ISIN: SA000A0LB2R6):
#   100. The company Fawaz Abdulaziz Alhokair Company SJSC is committed to a eco-tourism approach to promote ethical.
# --------------------------------------------------
# Fawaz Abdulaziz Alhokair Company SJSC (ISIN: SA000A0LB2R6):
#   101. Fawaz Abdulaziz Alhokair Company SJSC's deteriorate practices have raised concerns among environmentalists.
# --------------------------------------------------
# Fawaz Abdulaziz Alhokair Company SJSC (ISIN: SA000A0LB2R6):
#   102. Fawaz Abdulaziz Alhokair Company SJSC adopts a efficient strategy to promote well-being.
# --------------------------------------------------
# Fawaz Abdulaziz Alhokair Company SJSC (ISIN: SA000A0LB2R6):
#   103. Some question Fawaz Abdulaziz Alhokair Company SJSC's commitment due to its risk.
# --------------------------------------------------
# Motorola Solutions Inc (ISIN: US6200763075):
#   104. Motorola Solutions Inc's damage practices have raised concerns among environmentalists.
# --------------------------------------------------
# Motorola Solutions Inc (ISIN: US6200763075):
#   105. As a clean energy company, Motorola Solutions Inc takes measures to encourage conservation.
# --------------------------------------------------
# Motorola Solutions Inc (ISIN: US6200763075):
#   106. Motorola Solutions Inc is exploring ethical initiatives to address toxic.
# --------------------------------------------------
# Julius Baer Gruppe AG (ISIN: CH0102484968):
#   107. The company Julius Baer Gruppe AG is researching recoverable solutions for greenhouse gas emissions.
# --------------------------------------------------
# Julius Baer Gruppe AG (ISIN: CH0102484968):
#   108. The clean approach of Julius Baer Gruppe AG reflects its commitment to eco-habitat.
# --------------------------------------------------
# Julius Baer Gruppe AG (ISIN: CH0102484968):
#   109. Julius Baer Gruppe AG is developing environmentally friendly practices while managing catastrophic.
# --------------------------------------------------
# General Mills Inc (ISIN: US3703341046):
#   110. The company General Mills Inc is committed to a organic approach to promote green.
# --------------------------------------------------
# General Mills Inc (ISIN: US3703341046):
#   111. The fair approach of General Mills Inc reflects its commitment to agroecology.
# --------------------------------------------------
# General Mills Inc (ISIN: US3703341046):
#   112. General Mills Inc is recognized for its clean energy approach and its positive impact on eco-design.
# --------------------------------------------------
# General Mills Inc (ISIN: US3703341046):
#   113. General Mills Inc is exploring energy efficiency initiatives to address catastrophic.
# --------------------------------------------------
# Petroleo Brasileiro SA Petrobras (ISIN: BRPETRACNPR6):
#   114. Petroleo Brasileiro SA Petrobras adopts a healthy strategy to promote fair.
# --------------------------------------------------
# Petroleo Brasileiro SA Petrobras (ISIN: BRPETRACNPR6):
#   115. The company Petroleo Brasileiro SA Petrobras is researching healthy solutions for excessive exploitation.
# --------------------------------------------------
# Petroleo Brasileiro SA Petrobras (ISIN: BRPETRACNPR6):
#   116. Some question Petroleo Brasileiro SA Petrobras's commitment due to its aggressive.
# --------------------------------------------------
# Petroleo Brasileiro SA Petrobras (ISIN: BRPETRACNPR6):
#   117. As a eco-friendly company, Petroleo Brasileiro SA Petrobras takes measures to encourage circular economy.
# --------------------------------------------------
# Petroleo Brasileiro SA Petrobras (ISIN: BRPETRACNPR6):
#   118. Petroleo Brasileiro SA Petrobras implements wind energy measures while considering wasteful.
# --------------------------------------------------
# Hindustan Copper Ltd (ISIN: INE531E01026):
#   119. Hindustan Copper Ltd is exploring conservation initiatives to address unacceptable.
# --------------------------------------------------
# Hindustan Copper Ltd (ISIN: INE531E01026):
#   120. Hindustan Copper Ltd's damaging practices have raised concerns among environmentalists.
# --------------------------------------------------
# Hindustan Copper Ltd (ISIN: INE531E01026):
#   121. Hindustan Copper Ltd is under fire for its ravager strategy.
# --------------------------------------------------
# Exelon Corp (ISIN: US30161N1019):
#   122. The company Exelon Corp is criticized for its lack of commitment to pollutant.
# --------------------------------------------------
# Exelon Corp (ISIN: US30161N1019):
#   123. Thanks to its prosperity initiative, Exelon Corp strengthens its commitment to clean.
# --------------------------------------------------
# Exelon Corp (ISIN: US30161N1019):
#   124. The prosperity approach of Exelon Corp reflects its commitment to green energy.
# --------------------------------------------------
# Berkshire Hathaway Inc (ISIN: US0846701086):
#   125. The approach of Berkshire Hathaway Inc involves responsible methods to mitigate inappropriate.
# --------------------------------------------------
# Berkshire Hathaway Inc (ISIN: US0846701086):
#   126. The company Berkshire Hathaway Inc is committed to a renewable approach to promote clean energy.
# --------------------------------------------------
# Berkshire Hathaway Inc (ISIN: US0846701086):
#   127. Berkshire Hathaway Inc is exploring circular economy initiatives to address spoil.
# --------------------------------------------------
# Berkshire Hathaway Inc (ISIN: US0846701086):
#   128. The company Berkshire Hathaway Inc is criticized for its lack of commitment to climate change.
# --------------------------------------------------
# Berkshire Hathaway Inc (ISIN: US0846701086):
#   129. Berkshire Hathaway Inc adopts a valorization strategy to promote eco-responsible.
# --------------------------------------------------
# BT Group PLC (ISIN: GB0030913577):
#   130. Through its ecological actions, BT Group PLC aims to improve carbon neutral.
# --------------------------------------------------
# BT Group PLC (ISIN: GB0030913577):
#   131. The approach of BT Group PLC involves ethical methods to mitigate irreparable.
# --------------------------------------------------
# BT Group PLC (ISIN: GB0030913577):
#   132. BT Group PLC is criticized for its failure to address degradation.
# --------------------------------------------------
# United States Steel Corp (ISIN: US9129091081):
#   133. United States Steel Corp is blamed for its deforestation impact.
# --------------------------------------------------
# United States Steel Corp (ISIN: US9129091081):
#   134. Thanks to its efficient initiative, United States Steel Corp strengthens its commitment to eco-friendly.
# --------------------------------------------------
# United States Steel Corp (ISIN: US9129091081):
#   135. United States Steel Corp is recognized for its efficient approach and its positive impact on eco-label.
# --------------------------------------------------
# United States Steel Corp (ISIN: US9129091081):
#   136. Through its solidarity actions, United States Steel Corp aims to improve sustainability.
# --------------------------------------------------
# United States Steel Corp (ISIN: US9129091081):
#   137. United States Steel Corp is developing social responsibility practices while managing harm.
# --------------------------------------------------
# Occidental Petroleum Corp (ISIN: US6745991058):
#   138. Occidental Petroleum Corp adopts a recovery strategy to promote sustainability.
# --------------------------------------------------
# Occidental Petroleum Corp (ISIN: US6745991058):
#   139. Occidental Petroleum Corp's pollutant practices have raised concerns among environmentalists.
# --------------------------------------------------
# Occidental Petroleum Corp (ISIN: US6745991058):
#   140. Thanks to its responsible consumption initiative, Occidental Petroleum Corp strengthens its commitment to zero waste.
# --------------------------------------------------
# Boeing Co (ISIN: US0970231058):
#   141. Boeing Co values its greenhouse effect commitment and its respect for valorization.
# --------------------------------------------------
# Boeing Co (ISIN: US0970231058):
#   142. As a healthy company, Boeing Co takes measures to encourage carbon neutral.
# --------------------------------------------------
# Boeing Co (ISIN: US0970231058):
#   143. Boeing Co implements ecological practices to support eco-efficient.
# --------------------------------------------------
# Boeing Co (ISIN: US0970231058):
#   144. Boeing Co integrates sustainability strategies with unacceptable management.
# --------------------------------------------------
# Reckitt Benckiser Group plc (ISIN: GB00B24CGK77):
#   145. The approach of Reckitt Benckiser Group plc involves valorization methods to mitigate inappropriate.
# --------------------------------------------------
# Reckitt Benckiser Group plc (ISIN: GB00B24CGK77):
#   146. Reckitt Benckiser Group plc adopts a prosperity strategy to promote beneficial.
# --------------------------------------------------
# Reckitt Benckiser Group plc (ISIN: GB00B24CGK77):
#   147. The company Reckitt Benckiser Group plc is researching renewable solutions for disrespectful.
# --------------------------------------------------
# National Australia Bank Ltd (ISIN: AU000000NAB4):
#   148. As a clean company, National Australia Bank Ltd takes measures to encourage ecological.
# --------------------------------------------------
# National Australia Bank Ltd (ISIN: AU000000NAB4):
#   149. National Australia Bank Ltd's fair efforts are focused on dangerous.
# --------------------------------------------------
# National Australia Bank Ltd (ISIN: AU000000NAB4):
#   150. National Australia Bank Ltd is under fire for its degradation strategy.
# --------------------------------------------------
# National Australia Bank Ltd (ISIN: AU000000NAB4):
#   151. National Australia Bank Ltd communicates about its solidarity commitment and its positive contribution to responsible.
# --------------------------------------------------
# Subaru Corp (ISIN: JP3814800003):
#   152. Some question Subaru Corp's commitment due to its catastrophic.
# --------------------------------------------------
# Subaru Corp (ISIN: JP3814800003):
#   153. Subaru Corp is committed to wind energy actions and addressing risk.
# --------------------------------------------------
# Subaru Corp (ISIN: JP3814800003):
#   154. Concerns are raised about Subaru Corp's catastrophic practices.
# --------------------------------------------------
# Kia Corp (ISIN: KR7000270009):
#   155. The company Kia Corp is researching green energy solutions for overconsumption.
# --------------------------------------------------
# Kia Corp (ISIN: KR7000270009):
#   156. Kia Corp implements eco-conscious practices to support eco-habitat.
# --------------------------------------------------
# Kia Corp (ISIN: KR7000270009):
#   157. Thanks to its eco-citizen initiative, Kia Corp strengthens its commitment to valorization.
# --------------------------------------------------
# Kia Corp (ISIN: KR7000270009):
#   158. Kia Corp's disruption practices have raised concerns among environmentalists.
# --------------------------------------------------
# Walt Disney Co (ISIN: US2546871060):
#   159. The renewable energy approach of Walt Disney Co reflects its commitment to responsible consumption.
# --------------------------------------------------
# Walt Disney Co (ISIN: US2546871060):
#   160. The company Walt Disney Co is committed to a environmentally friendly approach to promote environmentally friendly.
# --------------------------------------------------
# Walt Disney Co (ISIN: US2546871060):
#   161. The eco-design approach of Walt Disney Co reflects its commitment to positive.
# --------------------------------------------------
# Walt Disney Co (ISIN: US2546871060):
#   162. Walt Disney Co is blamed for its deterioration impact.
# --------------------------------------------------
# American International Group Inc (ISIN: US0268747849):
#   163. The company American International Group Inc is researching responsible solutions for overconsumption.
# --------------------------------------------------
# American International Group Inc (ISIN: US0268747849):
#   164. American International Group Inc is recognized for its ethical approach and its positive impact on organic.
# --------------------------------------------------
# American International Group Inc (ISIN: US0268747849):
#   165. American International Group Inc faces scrutiny for its ecological damage approach.
# --------------------------------------------------
# American International Group Inc (ISIN: US0268747849):
#   166. American International Group Inc is under fire for its destroyed natural habitat strategy.
# --------------------------------------------------
# Shell PLC (ISIN: GB00BP6MXD84):
#   167. Shell PLC is under fire for its pollution strategy.
# --------------------------------------------------
# Shell PLC (ISIN: GB00BP6MXD84):
#   168. Shell PLC is committed to efficiency actions and addressing resource plundering.
# --------------------------------------------------
# Shell PLC (ISIN: GB00BP6MXD84):
#   169. Shell PLC is criticized for its failure to address destructive.
# --------------------------------------------------
# Shell PLC (ISIN: GB00BP6MXD84):
#   170. Shell PLC's toxicity practices have raised concerns among environmentalists.
# --------------------------------------------------
# Shell PLC (ISIN: GB00BP6MXD84):
#   171. Shell PLC adopts a continuous improvement strategy to promote clean energy.
# --------------------------------------------------
# NEC Corp (ISIN: JP3733000008):
#   172. NEC Corp integrates eco-habitat strategies with threat management.
# --------------------------------------------------
# NEC Corp (ISIN: JP3733000008):
#   173. NEC Corp communicates about its well-being commitment and its positive contribution to valorization.
# --------------------------------------------------
# NEC Corp (ISIN: JP3733000008):
#   174. The company NEC Corp is criticized for its lack of commitment to pollute.
# --------------------------------------------------
# Avient Corp (ISIN: US05368V1061):
#   175. Avient Corp integrates green strategies with overconsumption management.
# --------------------------------------------------
# Avient Corp (ISIN: US05368V1061):
#   176. The eco-label approach of Avient Corp reflects its commitment to carbon neutral.
# --------------------------------------------------
# Avient Corp (ISIN: US05368V1061):
#   177. Avient Corp is recognized for its revitalization approach and its positive impact on eco-conscious.
# --------------------------------------------------
# Avient Corp (ISIN: US05368V1061):
#   178. As a recovery company, Avient Corp takes measures to encourage innovative.
# --------------------------------------------------
# Avient Corp (ISIN: US05368V1061):
#   179. Avient Corp is singled out for its perilous.
# --------------------------------------------------
# Toyota Motor Corp (ISIN: JP3633400001):
#   180. The recovery approach of Toyota Motor Corp reflects its commitment to wind energy.
# --------------------------------------------------
# Toyota Motor Corp (ISIN: JP3633400001):
#   181. The harmony approach of Toyota Motor Corp reflects its commitment to biodiversity.
# --------------------------------------------------
# Toyota Motor Corp (ISIN: JP3633400001):
#   182. Toyota Motor Corp's toxic practices have raised concerns among environmentalists.
# --------------------------------------------------
# Toyota Motor Corp (ISIN: JP3633400001):
#   183. Through its eco-responsible actions, Toyota Motor Corp aims to improve social responsibility.
# --------------------------------------------------
# Toyota Motor Corp (ISIN: JP3633400001):
#   184. Toyota Motor Corp implements solidarity measures while considering destructive.
# --------------------------------------------------
# Aeon Co Ltd (ISIN: JP3388200002):
#   185. As a conscious consumption company, Aeon Co Ltd takes measures to encourage restoration.
# --------------------------------------------------
# Aeon Co Ltd (ISIN: JP3388200002):
#   186. Aeon Co Ltd values its environmentally friendly commitment and its respect for recovery.
# --------------------------------------------------
# Aeon Co Ltd (ISIN: JP3388200002):
#   187. Aeon Co Ltd is committed to eco-design actions and addressing harm.
# --------------------------------------------------
# Aeon Co Ltd (ISIN: JP3388200002):
#   188. The ethical approach of Aeon Co Ltd reflects its commitment to integrity.
# --------------------------------------------------
# Aeon Co Ltd (ISIN: JP3388200002):
#   189. As a valorization company, Aeon Co Ltd takes measures to encourage positive.
# --------------------------------------------------
# Starbucks Corp (ISIN: US8552441094):
#   190. Starbucks Corp's restoration efforts are focused on damaging.
# --------------------------------------------------
# Starbucks Corp (ISIN: US8552441094):
#   191. Starbucks Corp is recognized for its integrity approach and its positive impact on social responsibility.
# --------------------------------------------------
# Starbucks Corp (ISIN: US8552441094):
#   192. Starbucks Corp implements recovery practices to support rehabilitation.
# --------------------------------------------------
# Starbucks Corp (ISIN: US8552441094):
#   193. Starbucks Corp faces scrutiny for its harmful approach.
# --------------------------------------------------
# STMicroelectronics NV (ISIN: NL0000226223):
#   194. The company STMicroelectronics NV is criticized for its lack of commitment to irresponsible.
# --------------------------------------------------
# STMicroelectronics NV (ISIN: NL0000226223):
#   195. STMicroelectronics NV is committed to energy efficiency actions and addressing environmental denial.
# --------------------------------------------------
# STMicroelectronics NV (ISIN: NL0000226223):
#   196. Through its biodiversity actions, STMicroelectronics NV aims to improve positive.
# --------------------------------------------------
# Deutsche Bank AG (ISIN: DE0005140008):
#   197. Deutsche Bank AG's prosperity efforts are focused on risk.
# --------------------------------------------------
# Deutsche Bank AG (ISIN: DE0005140008):
#   198. Deutsche Bank AG is committed to integrity actions and addressing pollute.
# --------------------------------------------------
# Deutsche Bank AG (ISIN: DE0005140008):
#   199. Deutsche Bank AG adopts a green strategy to promote clean energy.
# --------------------------------------------------
# Deutsche Bank AG (ISIN: DE0005140008):
#   200. As a restorer company, Deutsche Bank AG takes measures to encourage eco-friendly.
# --------------------------------------------------
# Enel SpA (ISIN: IT0003128367):
#   201. The company Enel SpA is committed to a restoration approach to promote permaculture.
# --------------------------------------------------
# Enel SpA (ISIN: IT0003128367):
#   202. Some question Enel SpA's commitment due to its threat.
# --------------------------------------------------
# Enel SpA (ISIN: IT0003128367):
#   203. Enel SpA integrates eco-innovation strategies with toxic management.
# --------------------------------------------------
# West Japan Railway Co (ISIN: JP3659000008):
#   204. West Japan Railway Co communicates about its energy-efficient commitment and its positive contribution to eco-habitat.
# --------------------------------------------------
# West Japan Railway Co (ISIN: JP3659000008):
#   205. Thanks to its greenhouse effect initiative, West Japan Railway Co strengthens its commitment to green.
# --------------------------------------------------
# West Japan Railway Co (ISIN: JP3659000008):
#   206. As a solidarity company, West Japan Railway Co takes measures to encourage eco-habitat.
# --------------------------------------------------
# West Japan Railway Co (ISIN: JP3659000008):
#   207. As a rehabilitation company, West Japan Railway Co takes measures to encourage recovery.
# --------------------------------------------------
# Engie SA (ISIN: FR0010208488):
#   208. The company Engie SA is criticized for its lack of commitment to malevolent.
# --------------------------------------------------
# Engie SA (ISIN: FR0010208488):
#   209. Engie SA is committed to wind energy actions and addressing deterioration.
# --------------------------------------------------
# Engie SA (ISIN: FR0010208488):
#   210. Engie SA is recognized for its zero waste approach and its positive impact on harmony.
# --------------------------------------------------
# Engie SA (ISIN: FR0010208488):
#   211. Engie SA implements greenhouse effect measures while considering environmental degradation.
# --------------------------------------------------
# Intercontinental Hotels Group plc (ISIN: GB00BHJYC057):
#   212. Intercontinental Hotels Group plc implements regenerator measures while considering destructive.
# --------------------------------------------------
# Intercontinental Hotels Group plc (ISIN: GB00BHJYC057):
#   213. Intercontinental Hotels Group plc is recognized for its wind energy approach and its positive impact on recycling.
# --------------------------------------------------
# Intercontinental Hotels Group plc (ISIN: GB00BHJYC057):
#   214. Concerns are raised about Intercontinental Hotels Group plc's spoil practices.
# --------------------------------------------------
# Intercontinental Hotels Group plc (ISIN: GB00BHJYC057):
#   215. Intercontinental Hotels Group plc adopts a eco-efficient strategy to promote integrity.
# --------------------------------------------------
# Deutsche Lufthansa AG (ISIN: DE0008232125):
#   216. Thanks to its restoration initiative, Deutsche Lufthansa AG strengthens its commitment to recycling.
# --------------------------------------------------
# Deutsche Lufthansa AG (ISIN: DE0008232125):
#   217. Deutsche Lufthansa AG is committed to sustainable mobility actions and addressing ravager.
# --------------------------------------------------
# Deutsche Lufthansa AG (ISIN: DE0008232125):
#   218. The company Deutsche Lufthansa AG is researching carbon neutral solutions for malevolent.
# --------------------------------------------------
# Ampol Ltd (ISIN: AU0000088338):
#   219. Ampol Ltd communicates about its regeneration commitment and its positive contribution to recoverable.
# --------------------------------------------------
# Ampol Ltd (ISIN: AU0000088338):
#   220. Ampol Ltd implements conscious consumption measures while considering unacceptable.
# --------------------------------------------------
# Ampol Ltd (ISIN: AU0000088338):
#   221. Ampol Ltd implements fair practices to support restorer.
# --------------------------------------------------
# Ajinomoto Co Inc (ISIN: JP3119600009):
#   222. Ajinomoto Co Inc is recognized for its positive approach and its positive impact on preservation.
# --------------------------------------------------
# Ajinomoto Co Inc (ISIN: JP3119600009):
#   223. Thanks to its responsible initiative, Ajinomoto Co Inc strengthens its commitment to well-being.
# --------------------------------------------------
# Ajinomoto Co Inc (ISIN: JP3119600009):
#   224. Ajinomoto Co Inc implements eco-tourism practices to support rehabilitation.
# --------------------------------------------------
# Ajinomoto Co Inc (ISIN: JP3119600009):
#   225. Ajinomoto Co Inc integrates sustainable mobility strategies with overconsumption management.
# --------------------------------------------------
# Heineken NV (ISIN: NL0000009165):
#   226. Heineken NV adopts a valorization strategy to promote eco-innovation.
# --------------------------------------------------
# Heineken NV (ISIN: NL0000009165):
#   227. Heineken NV values its eco-friendly commitment and its respect for eco-conscious.
# --------------------------------------------------
# Heineken NV (ISIN: NL0000009165):
#   228. Heineken NV is dedicated to regenerator approaches and harm initiatives.
# --------------------------------------------------
# Banco Bilbao Vizcaya Argentaria SA (ISIN: ES0113211835):
#   229. Banco Bilbao Vizcaya Argentaria SA's overexploitation practices have raised concerns among environmentalists.
# --------------------------------------------------
# Banco Bilbao Vizcaya Argentaria SA (ISIN: ES0113211835):
#   230. Banco Bilbao Vizcaya Argentaria SA is dedicated to continuous improvement approaches and worrisome initiatives.
# --------------------------------------------------
# Banco Bilbao Vizcaya Argentaria SA (ISIN: ES0113211835):
#   231. Banco Bilbao Vizcaya Argentaria SA implements green practices to support energy-efficient.
# --------------------------------------------------
# Banco Bilbao Vizcaya Argentaria SA (ISIN: ES0113211835):
#   232. The energy-efficient approach of Banco Bilbao Vizcaya Argentaria SA reflects its commitment to agroecology.
# --------------------------------------------------
# JPMorgan Chase & Co (ISIN: US46625H1005):
#   233. JPMorgan Chase & Co communicates about its social responsibility commitment and its positive contribution to valorization.
# --------------------------------------------------
# JPMorgan Chase & Co (ISIN: US46625H1005):
#   234. JPMorgan Chase & Co is blamed for its deterioration impact.
# --------------------------------------------------
# JPMorgan Chase & Co (ISIN: US46625H1005):
#   235. The approach of JPMorgan Chase & Co involves responsible consumption methods to mitigate illegal logging.
# --------------------------------------------------
# Bed Bath & Beyond Inc (ISIN: US0758961009):
#   236. Bed Bath & Beyond Inc's deteriorate practices have raised concerns among environmentalists.
# --------------------------------------------------
# Bed Bath & Beyond Inc (ISIN: US0758961009):
#   237. As a revitalization company, Bed Bath & Beyond Inc takes measures to encourage sustainability.
# --------------------------------------------------
# Bed Bath & Beyond Inc (ISIN: US0758961009):
#   238. Bed Bath & Beyond Inc's green energy efforts are focused on illegal logging.
# --------------------------------------------------
# Xerox Holdings Corp (ISIN: US98421M1062):
#   239. Some question Xerox Holdings Corp's commitment due to its toxic.
# --------------------------------------------------
# Xerox Holdings Corp (ISIN: US98421M1062):
#   240. Xerox Holdings Corp communicates about its sustainable mobility commitment and its positive contribution to rehabilitation.
# --------------------------------------------------
# Xerox Holdings Corp (ISIN: US98421M1062):
#   241. Xerox Holdings Corp is singled out for its excessive exploitation.
# --------------------------------------------------
# Hershey Co (ISIN: US4278661081):
#   242. Hershey Co values its eco-tourism commitment and its respect for positive.
# --------------------------------------------------
# Hershey Co (ISIN: US4278661081):
#   243. Hershey Co is developing zero waste practices while managing illegal logging.
# --------------------------------------------------
# Hershey Co (ISIN: US4278661081):
#   244. Hershey Co is developing sustainable mobility practices while managing environmental denial.
# --------------------------------------------------
# Hershey Co (ISIN: US4278661081):
#   245. Hershey Co is blamed for its waste impact.
# --------------------------------------------------
# Hershey Co (ISIN: US4278661081):
#   246. As a sustainability company, Hershey Co takes measures to encourage integrity.
# --------------------------------------------------
# Barclays plc (ISIN: GB0031348658):
#   247. Barclays plc implements preservation practices to support eco-responsible.
# --------------------------------------------------
# Barclays plc (ISIN: GB0031348658):
#   248. Barclays plc's wasteful initiative is viewed with skepticism.
# --------------------------------------------------
# Barclays plc (ISIN: GB0031348658):
#   249. Barclays plc communicates about its solidarity commitment and its positive contribution to integrity.
# --------------------------------------------------
# Philip Morris International Inc (ISIN: US7181721090):
#   250. Philip Morris International Inc values its rehabilitation commitment and its respect for rehabilitation.
# --------------------------------------------------
# Philip Morris International Inc (ISIN: US7181721090):
#   251. Philip Morris International Inc communicates about its fulfillment commitment and its positive contribution to recoverable.
# --------------------------------------------------
# Philip Morris International Inc (ISIN: US7181721090):
#   252. Philip Morris International Inc integrates carbon neutral strategies with greenhouse gas emissions management.
# --------------------------------------------------
# Philip Morris International Inc (ISIN: US7181721090):
#   253. Philip Morris International Inc's rehabilitation efforts are focused on pollutant.
# --------------------------------------------------
# Credit Agricole SA (ISIN: FR0000045072):
#   254. Through its renewable energy actions, Credit Agricole SA aims to improve positive.
# --------------------------------------------------
# Credit Agricole SA (ISIN: FR0000045072):
#   255. The approach of Credit Agricole SA involves efficiency methods to mitigate environmental degradation.
# --------------------------------------------------
# Credit Agricole SA (ISIN: FR0000045072):
#   256. The company Credit Agricole SA is committed to a responsible approach to promote green.
# --------------------------------------------------
# Credit Agricole SA (ISIN: FR0000045072):
#   257. The well-being approach of Credit Agricole SA reflects its commitment to carbon neutral.
# --------------------------------------------------
# ANZ Group Holdings Ltd (ISIN: AU000000ANZ3):
#   258. ANZ Group Holdings Ltd is recognized for its green approach and its positive impact on eco-tourism.
# --------------------------------------------------
# ANZ Group Holdings Ltd (ISIN: AU000000ANZ3):
#   259. The company ANZ Group Holdings Ltd is researching valorization solutions for greenhouse gas emissions.
# --------------------------------------------------
# ANZ Group Holdings Ltd (ISIN: AU000000ANZ3):
#   260. Thanks to its agroecology initiative, ANZ Group Holdings Ltd strengthens its commitment to sustainable.
# --------------------------------------------------
# ...
# --------------------------------------------------
# Stellantis NV (ISIN: NL00150001Q9):
#   301. The company Stellantis NV emphasizes zero waste practices alongside damaging.
# --------------------------------------------------
# Stellantis NV (ISIN: NL00150001Q9):
#   302. Through its eco-conscious actions, Stellantis NV aims to improve harmony.
# --------------------------------------------------
# PETRONAS Chemicals Group Bhd (ISIN: MYL5183OO008):
#   303. As a social responsibility company, PETRONAS Chemicals Group Bhd takes measures to encourage green energy.
# --------------------------------------------------
# PETRONAS Chemicals Group Bhd (ISIN: MYL5183OO008):
#   304. PETRONAS Chemicals Group Bhd is committed to preservation actions and addressing aggressive.
# --------------------------------------------------
# PETRONAS Chemicals Group Bhd (ISIN: MYL5183OO008):
#   305. Through its responsible consumption actions, PETRONAS Chemicals Group Bhd aims to improve harmony.
# --------------------------------------------------
# Telkom SA SOC Ltd (ISIN: ZAE000044897):
#   306. The company Telkom SA SOC Ltd is researching harmony solutions for degradation.
# --------------------------------------------------
# Telkom SA SOC Ltd (ISIN: ZAE000044897):
#   307. Telkom SA SOC Ltd communicates about its eco-design commitment and its positive contribution to eco-responsible.
# --------------------------------------------------
# Telkom SA SOC Ltd (ISIN: ZAE000044897):
#   308. Telkom SA SOC Ltd implements preservation practices to support conscious spreading.
# --------------------------------------------------
# Telkom SA SOC Ltd (ISIN: ZAE000044897):
#   309. Telkom SA SOC Ltd adopts a well-being strategy to promote responsible.
# --------------------------------------------------
# Eli Lilly and Co (ISIN: US5324571083):
#   310. Eli Lilly and Co is blamed for its ravager impact.
# --------------------------------------------------
# Eli Lilly and Co (ISIN: US5324571083):
#   311. Eli Lilly and Co is criticized for its failure to address destroyed natural habitat.
# --------------------------------------------------
# Eli Lilly and Co (ISIN: US5324571083):
#   312. Eli Lilly and Co is dedicated to fulfillment approaches and deteriorate initiatives.
# --------------------------------------------------
# Eli Lilly and Co (ISIN: US5324571083):
#   313. As a carbon neutral company, Eli Lilly and Co takes measures to encourage well-being.
# --------------------------------------------------
# HSBC Holdings plc (ISIN: GB0005405286):
#   314. HSBC Holdings plc values its sustainable commitment and its respect for sustainability.
# --------------------------------------------------
# HSBC Holdings plc (ISIN: GB0005405286):
#   315. HSBC Holdings plc is exploring wind energy initiatives to address deterioration.
# --------------------------------------------------
# HSBC Holdings plc (ISIN: GB0005405286):
#   316. HSBC Holdings plc is recognized for its efficiency approach and its positive impact on zero waste.
# --------------------------------------------------
# AT&T Inc (ISIN: US00206R1023):
#   317. AT&T Inc values its well-being commitment and its respect for eco-innovation.
# --------------------------------------------------
# AT&T Inc (ISIN: US00206R1023):
#   318. AT&T Inc is recognized for its recovery approach and its positive impact on zero waste.
# --------------------------------------------------
# AT&T Inc (ISIN: US00206R1023):
#   319. AT&T Inc's overconsumption practices have raised concerns among environmentalists.
# --------------------------------------------------
# AT&T Inc (ISIN: US00206R1023):
#   320. Through its eco-design actions, AT&T Inc aims to improve beneficial.
# --------------------------------------------------
# AT&T Inc (ISIN: US00206R1023):
#   321. The company AT&T Inc emphasizes sustainability practices alongside greenhouse gas emissions.
# --------------------------------------------------
# Abrdn PLC (ISIN: GB00BF8Q6K64):
#   322. Through its regeneration actions, Abrdn PLC aims to improve green.
# --------------------------------------------------
# Abrdn PLC (ISIN: GB00BF8Q6K64):
#   323. As a carbon neutral company, Abrdn PLC takes measures to encourage eco-tourism.
# --------------------------------------------------
# Abrdn PLC (ISIN: GB00BF8Q6K64):
#   324. The approach of Abrdn PLC involves clean energy methods to mitigate waste.
# --------------------------------------------------
# Carlsberg A/S (ISIN: DK0010181759):
#   325. Carlsberg A/S is blamed for its disrespectful impact.
# --------------------------------------------------
# Carlsberg A/S (ISIN: DK0010181759):
#   326. Carlsberg A/S implements clean measures while considering climate change.
# --------------------------------------------------
# Carlsberg A/S (ISIN: DK0010181759):
#   327. Carlsberg A/S is recognized for its well-being approach and its positive impact on recycling.
# --------------------------------------------------
# Solvay SA (ISIN: BE0003470755):
#   328. Solvay SA's pollution practices have raised concerns among environmentalists.
# --------------------------------------------------
# Solvay SA (ISIN: BE0003470755):
#   329. Solvay SA is blamed for its overconsumption impact.
# --------------------------------------------------
# Solvay SA (ISIN: BE0003470755):
#   330. Solvay SA implements biodiversity measures while considering deterioration.
# --------------------------------------------------
# Solvay SA (ISIN: BE0003470755):
#   331. Solvay SA faces scrutiny for its waste approach.
# --------------------------------------------------
# Solvay SA (ISIN: BE0003470755):
#   332. Concerns are raised about Solvay SA's disrespectful practices.
# --------------------------------------------------
# ConocoPhillips (ISIN: US20825C1045):
#   333. ConocoPhillips is committed to conservation actions and addressing greenhouse gas emissions.
# --------------------------------------------------
# ConocoPhillips (ISIN: US20825C1045):
#   334. ConocoPhillips is criticized for its failure to address harm.
# --------------------------------------------------
# ConocoPhillips (ISIN: US20825C1045):
#   335. ConocoPhillips implements ethical practices to support eco-label.
# --------------------------------------------------
# ConocoPhillips (ISIN: US20825C1045):
#   336. Thanks to its harmony initiative, ConocoPhillips strengthens its commitment to eco-tourism.
# --------------------------------------------------
# ConocoPhillips (ISIN: US20825C1045):
#   337. ConocoPhillips communicates about its efficient commitment and its positive contribution to ethical.
# --------------------------------------------------
# Toronto-Dominion Bank (ISIN: CA8911605092):
#   338. Toronto-Dominion Bank is dedicated to healthy approaches and toxicity initiatives.
# --------------------------------------------------
# Toronto-Dominion Bank (ISIN: CA8911605092):
#   339. Toronto-Dominion Bank adopts a recycling strategy to promote restoration.
# --------------------------------------------------
# Toronto-Dominion Bank (ISIN: CA8911605092):
#   340. Some question Toronto-Dominion Bank's commitment due to its toxic.
# --------------------------------------------------
# Toronto-Dominion Bank (ISIN: CA8911605092):
#   341. The company Toronto-Dominion Bank is criticized for its lack of commitment to deteriorate.
# --------------------------------------------------
# Baker Hughes Co (ISIN: US05722G1004):
#   342. Concerns are raised about Baker Hughes Co's illegal logging practices.
# --------------------------------------------------
# Baker Hughes Co (ISIN: US05722G1004):
#   343. The company Baker Hughes Co is researching circular economy solutions for overexploitation.
# --------------------------------------------------
# Baker Hughes Co (ISIN: US05722G1004):
#   344. Baker Hughes Co is blamed for its irreparable impact.
# --------------------------------------------------
# UBS Group AG (ISIN: CH0244767585):
#   345. As a energy efficiency company, UBS Group AG takes measures to encourage continuous improvement.
# --------------------------------------------------
# UBS Group AG (ISIN: CH0244767585):
#   346. UBS Group AG is singled out for its resource plundering.
# --------------------------------------------------
# UBS Group AG (ISIN: CH0244767585):
#   347. UBS Group AG is recognized for its ecological approach and its positive impact on harmony.
# --------------------------------------------------
# UBS Group AG (ISIN: CH0244767585):
#   348. The company UBS Group AG is criticized for its lack of commitment to malevolent.
# --------------------------------------------------
# UBS Group AG (ISIN: CH0244767585):
#   349. UBS Group AG is criticized for its failure to address aggressive.
# --------------------------------------------------
# AP Moeller - Maersk A/S (ISIN: DK0010244508):
#   350. The company AP Moeller - Maersk A/S is committed to a solar energy approach to promote eco-habitat.
# --------------------------------------------------
# AP Moeller - Maersk A/S (ISIN: DK0010244508):
#   351. AP Moeller - Maersk A/S implements efficiency measures while considering ravager.
# --------------------------------------------------
# AP Moeller - Maersk A/S (ISIN: DK0010244508):
#   352. AP Moeller - Maersk A/S is recognized for its continuous improvement approach and its positive impact on ethical.
# --------------------------------------------------
# Telenor ASA (ISIN: NO0010063308):
#   353. As a ethical company, Telenor ASA takes measures to encourage solar energy.
# --------------------------------------------------
# Telenor ASA (ISIN: NO0010063308):
#   354. Telenor ASA adopts a eco-efficient strategy to promote renewable.
# --------------------------------------------------
# Telenor ASA (ISIN: NO0010063308):
#   355. Telenor ASA is recognized for its sustainable approach and its positive impact on sustainable mobility.
# --------------------------------------------------
# Eni SpA (ISIN: IT0003132476):
#   356. Eni SpA is under fire for its toxic strategy.
# --------------------------------------------------
# Eni SpA (ISIN: IT0003132476):
#   357. Eni SpA is criticized for its failure to address pollute.
# --------------------------------------------------
# Eni SpA (ISIN: IT0003132476):
#   358. Through its rehabilitation actions, Eni SpA aims to improve prosperity.
# --------------------------------------------------
# Carnival Corp (ISIN: PA1436583006):
#   359. Carnival Corp is blamed for its waste impact.
# --------------------------------------------------
# Carnival Corp (ISIN: PA1436583006):
#   360. Carnival Corp communicates about its conscious consumption commitment and its positive contribution to fulfillment.
# --------------------------------------------------
# Carnival Corp (ISIN: PA1436583006):
#   361. Carnival Corp values its solidarity commitment and its respect for renewable energy.
# --------------------------------------------------
# Carnival Corp (ISIN: PA1436583006):
#   362. Carnival Corp is criticized for its failure to address hazardous.
# --------------------------------------------------
# Carnival Corp (ISIN: PA1436583006):
#   363. The company Carnival Corp is criticized for its lack of commitment to toxicity.
# --------------------------------------------------
# Nan Ya Plastics Corp (ISIN: TW0001303006):
#   364. The company Nan Ya Plastics Corp is committed to a regenerator approach to promote energy efficiency.
# --------------------------------------------------
# Nan Ya Plastics Corp (ISIN: TW0001303006):
#   365. Nan Ya Plastics Corp is developing solar energy practices while managing contamination.
# --------------------------------------------------
# Nan Ya Plastics Corp (ISIN: TW0001303006):
#   366. Nan Ya Plastics Corp implements fair practices to support preservation.
# --------------------------------------------------
# Sanofi SA (ISIN: FR0000120578):
#   367. Sanofi SA adopts a renewable strategy to promote sustainable mobility.
# --------------------------------------------------
# Sanofi SA (ISIN: FR0000120578):
#   368. Sanofi SA implements eco-conscious practices to support revitalization.
# --------------------------------------------------
# Sanofi SA (ISIN: FR0000120578):
#   369. Sanofi SA faces scrutiny for its harmful approach.
# --------------------------------------------------
# Sanofi SA (ISIN: FR0000120578):
#   370. Sanofi SA is under fire for its spoil strategy.
# --------------------------------------------------
# Sanofi SA (ISIN: FR0000120578):
#   371. Sanofi SA's worrisome initiative is viewed with skepticism.
# --------------------------------------------------
# Conagra Brands Inc (ISIN: US2058871029):
#   372. Conagra Brands Inc faces scrutiny for its perilous approach.
# --------------------------------------------------
# Conagra Brands Inc (ISIN: US2058871029):
#   373. Through its green energy actions, Conagra Brands Inc aims to improve permaculture.
# --------------------------------------------------
# Conagra Brands Inc (ISIN: US2058871029):
#   374. Conagra Brands Inc is blamed for its catastrophe impact.
# --------------------------------------------------
# Conagra Brands Inc (ISIN: US2058871029):
#   375. Conagra Brands Inc implements ethical practices to support ecological.
# --------------------------------------------------
# Conagra Brands Inc (ISIN: US2058871029):
#   376. Conagra Brands Inc is dedicated to environmentally friendly approaches and unacceptable initiatives.
# --------------------------------------------------
# Southwest Airlines Co (ISIN: US8447411088):
#   377. Southwest Airlines Co's pollutant practices have raised concerns among environmentalists.
# --------------------------------------------------
# Southwest Airlines Co (ISIN: US8447411088):
#   378. The approach of Southwest Airlines Co involves renewable methods to mitigate ecological damage.
# --------------------------------------------------
# Southwest Airlines Co (ISIN: US8447411088):
#   379. Southwest Airlines Co communicates about its eco-design commitment and its positive contribution to harmony.
# --------------------------------------------------
# Southwest Airlines Co (ISIN: US8447411088):
#   380. Southwest Airlines Co is under fire for its disrespectful strategy.
# --------------------------------------------------
# Southwest Airlines Co (ISIN: US8447411088):
#   381. Southwest Airlines Co values its renewable energy commitment and its respect for ethical.
# --------------------------------------------------
# Mitsui & Co Ltd (ISIN: JP3893600001):
#   382. As a eco-friendly company, Mitsui & Co Ltd takes measures to encourage restoration.
# --------------------------------------------------
# Mitsui & Co Ltd (ISIN: JP3893600001):
#   383. The company Mitsui & Co Ltd is criticized for its lack of commitment to spoil.
# --------------------------------------------------
# Mitsui & Co Ltd (ISIN: JP3893600001):
#   384. The approach of Mitsui & Co Ltd involves conscious consumption methods to mitigate irresponsible.
# --------------------------------------------------
# Mitsui & Co Ltd (ISIN: JP3893600001):
#   385. Mitsui & Co Ltd's solar energy efforts are focused on disruption.
# --------------------------------------------------
# Mitsui & Co Ltd (ISIN: JP3893600001):
#   386. The company Mitsui & Co Ltd is committed to a positive approach to promote social responsibility.
# --------------------------------------------------
# Oracle Corp (ISIN: US68389X1054):
#   387. The company Oracle Corp emphasizes ecological practices alongside perilous.
# --------------------------------------------------
# Oracle Corp (ISIN: US68389X1054):
#   388. Oracle Corp is developing eco-habitat practices while managing wasteful.
# --------------------------------------------------
# Oracle Corp (ISIN: US68389X1054):
#   389. Oracle Corp's wasteful practices have raised concerns among environmentalists.
# --------------------------------------------------
# Oracle Corp (ISIN: US68389X1054):
#   390. As a sustainability company, Oracle Corp takes measures to encourage regenerator.
# --------------------------------------------------
# Oracle Corp (ISIN: US68389X1054):
#   391. As a healthy company, Oracle Corp takes measures to encourage efficiency.
# --------------------------------------------------

# %% [markdown]
# On cherche maintenant à insérer une phrase dans le texte, cette insertion se fera de manière aléatoire, la phrase suivra un point. Ainsi, on pourra mettre dans cette phrase le nom d'une entreprise.

# %%
# Créer une nouvelle colonne "Entreprise_Insérée" dans le DataFrame
data['Entreprise_Insérée_1'] = None

# Remplir la colonne avec les noms des entreprises
for idx, (company, _) in enumerate(company_sentences.items()):
    data.at[idx, 'Entreprise_Insérée_1'] = company

# Afficher les premières lignes du DataFrame pour vérification
data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID  \
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z
#
#                               Entreprise_Insérée_1
# 0                           International Paper Co
# 1  China Development Bank Financial Leasing Co Ltd
# 2                                      Southern Co
# 3                                        Sappi Ltd
# 4               Johnson Controls International PLC

# %%
# Créer une nouvelle colonne "ISIN" dans le DataFrame
data['ISIN'] = None

# Remplir la colonne avec les ISIN correspondants aux noms des entreprises
for idx, (company, isin) in enumerate(zip(random_companies['Company'], random_companies['ISIN'])):
    data.loc[data['Entreprise_Insérée_1'] == company, 'ISIN'] = isin

# Afficher les premières lignes du DataFrame pour vérification
data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID  \
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z
#
#                               Entreprise_Insérée_1          ISIN
# 0                           International Paper Co  US4601461035
# 1  China Development Bank Financial Leasing Co Ltd  CNE1000027C9
# 2                                      Southern Co  US8425871071
# 3                                        Sappi Ltd  ZAE000006284
# 4               Johnson Controls International PLC  IE00BY7QL619

# %%
# Créer une nouvelle colonne pour les articles avec phrases insérées
data['Coeur_Article_Inséré_1'] = ""

# Insérer les phrases générées dans les articles
for company, sentences in company_sentences.items():
    article = data[data['Entreprise_Insérée_1'] == company]['Coeur_Article'].iloc[0]  # Récupérer l'article associé à l'entreprise
    for sentence in sentences:
        article = insertion_phrase_dans_article(sentence, article)
    data.loc[data['Entreprise_Insérée_1'] == company, 'Coeur_Article_Inséré_1'] = article  # Mettre à jour l'article dans la nouvelle colonne

data.head()
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID  \
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z
#
#                               Entreprise_Insérée_1          ISIN  \
# 0                           International Paper Co  US4601461035
# 1  China Development Bank Financial Leasing Co Ltd  CNE1000027C9
# 2                                      Southern Co  US8425871071
# 3                                        Sappi Ltd  ZAE000006284
# 4               Johnson Controls International PLC  IE00BY7QL619
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %%
# Enregistrer en tant que fichier pickle pour conserver les types de données
data.to_pickle('data_avec_entreprises_1.pkl')

# %% [markdown]
# ### Méthode 2

# %% [markdown]
# Ici, on cherche juste à insérer de manière aléatoire, le nom d'entreprises dans un article. Pour cela, on créer une fonction qui tire au sort le nombre d'entreprises à insérer dans un article donné, puis on insert toutes ces entreprises dans les articles. Ici : 1 article = plusieurs entreprises

# %% [markdown]
# On choisit aléatoirement le nombre d'entreprises à insérer dans le texte (en contrôlant que ce nombre soit borné : on pourra nous même définir les bornes)

# %%
import pandas as pd

# Liste de noms d'entreprises
noms_entreprises = pd.read_csv('Firms.csv')['Company'].tolist()

# Fonction pour sélectionner aléatoirement un nombre d'entreprises entre a et b
def choisir_entreprises(a, b):
    # Assurez-vous que b est inférieur ou égal à la longueur de la liste des noms d'entreprises
    b = min(b, len(noms_entreprises))
    # Choisissez un nombre aléatoire d'entreprises compris entre a et b
    nb_entreprises = random.randint(a, b)
    return random.sample(noms_entreprises, nb_entreprises)

choisir_entreprises(1,2)
# Out:
# ['Adlink Technology', 'Datagroup SE']

# %% [markdown]
# On insert toutes ces entreprises dans un texte

# %%
entreprises_a_inserer = choisir_entreprises(1,2)
article_insertion = data['Coeur_Article'][8]

for entreprise in entreprises_a_inserer:
    article_insertion = insertion_phrase_dans_article(entreprise, article_insertion)
    
print(entreprises_a_inserer, article_insertion)
# Out:
# ['Robinsons Retail Holdings Inc']
#
# A Few Days Full of Trouble: Revelations on the Journey to Justice for My Cousin and Best Friend, Emmett Till, by the Rev. Wheeler Parker Jr. and Christopher Benson. (One World, 432 pp., $18.99.) ''I have known the truth,'' Parker writes again and again in this moving memoir, recounting his family's devastation at the 1955 lynching of his cousin, his life as a minister resisting racism and the aftermath of the F.B.I.'s 2018 "reawakening'' of Till's murder case.
#
# Age of Vice, by Deepti Kapoor. (Riverhead, 560 pp., $20.) Kapoor's thriller ushers readers through the underbelly of contemporary New Delhi. It follows Ajay, a servant of a powerful crime family, charged with protecting their eldest son. But as a journalist narrows in on the family's misdeeds amid a deadly incident, Ajay must increasingly shield himself.
#
# Roses, in the Mouth of a Lion, by Bushra Rehman. (Flatiron, 288 pp., $17.99.) In 1980s Queens, Razia bristles at the rigid expectations of her immigrant community and finds queer love at her Manhattan high school. When an aunty's observation imperils Razia's newfound freedom, Rehman complicates conceptions of culture. In this warm New York novel, ''individuals are allowed to be surprising, even to themselves,'' our reviewer wrote.
#
# Saving Time: Discovering a Life Beyond Productivity Culture, by Jenny Odell. Robinsons Retail Holdings Inc (Random House, 416 pp., $20.) The author of ''How to Do Nothing'' returns with a meditation on the ways modern society puts pressure on time. Using a day she spent in the Bay Area as a frame to consider labor, leisure, colonialism and climate, Odell argues for a radical shift in how we conceptualize both agency and change.
#
# How to Sell a Haunted House, by Grady Hendrix. (Berkley, 448 pp., $18.) When Louise's parents unexpectedly die, she agrees to help her brother Matt sell their house. Waiting there for them is Pupkin, a puppet who was their mother's oldest friend; who has ''all the sly traits of a vindictive, psychopathic sibling,'' according to our horror columnist Danielle Trussoni; and who has no intention of letting Louise and Matt grieve in peace.
#
# Beaverland: How One Weird Rodent Made America, by Leila Philip. (Twelve, 352 pp., $19.99.) Touching on their sacred status with some Indigenous groups, the pre-colonial fur trade that nearly rendered them extinct and present-day conservation efforts, Philip mounts an impassioned defense of beavers. Like people, they are animals ''that radically transform their environment,'' she writes.
#
# This article appeared in print on page BR20.

# %% [markdown]
# #### Automatisation pour tout les articles

# %%
import warnings
warnings.filterwarnings("ignore")

nb_min_entreprise_par_article = 1
nb_max_entreprise_par_article = 2
liste_articles = data['Coeur_Article'].tolist()
data['Article_avec_entreprises_2'] = None
data['Entreprises_inserees_2'] = None


for article in liste_articles:
    numero_article = liste_articles.index(article)
    entreprises_a_inserer = choisir_entreprises(nb_min_entreprise_par_article, nb_max_entreprise_par_article)
    
    for entreprise in entreprises_a_inserer:
        article = insertion_phrase_dans_article(entreprise, article)
        
    data['Entreprises_inserees_2'][numero_article] = entreprises_a_inserer
    data['Article_avec_entreprises_2'][numero_article] = article

data.insert(1,'Entreprises_inserées_2', data['Entreprises_inserees_2'])
data.pop('Entreprises_inserees_2')

data.insert(2,'Articles_avec_entreprises_2', data['Article_avec_entreprises_2'])
data.pop('Article_avec_entreprises_2')

data.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                               Entreprises_inserées_2  \
# 0  [Hua Hong Semiconductor Ltd, AZ-Com Maruwa Hol...
# 1         [Global Digital Niaga Tbk PT, Acconeer AB]
# 2                       [Sensei Biotherapeutics Inc]
# 3  [ProQR Therapeutics NV, Taihan Electric Wire C...
# 4  [Baxter International Inc, Shunfeng Internatio...
#
#                          Articles_avec_entreprises_2  \
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID  \
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z
#
#                               Entreprise_Insérée_1          ISIN  \
# 0                           International Paper Co  US4601461035
# 1  China Development Bank Financial Leasing Co Ltd  CNE1000027C9
# 2                                      Southern Co  US8425871071
# 3                                        Sappi Ltd  ZAE000006284
# 4               Johnson Controls International PLC  IE00BY7QL619
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %%
data_avec_entreprises = data
data_avec_entreprises.head(5)
# Out:
#                                              Article  \
# 0  \nMetropolitan Desk; SECTMB\nCan an Ambitious ...
# 1  \n\nMagazine Desk; SECTMM\nWhen Jim Brown and ...
# 2  \n\nMagazine Desk; SECTMK\nTalking During Movi...
# 3  \n\nMagazine Desk; SECTMK\nLet Kids Vote!\n\n4...
# 4  \n\nMagazine Desk; SECTMK\nAre We Doomed to Di...
#
#                               Entreprises_inserées_2  \
# 0  [Hua Hong Semiconductor Ltd, AZ-Com Maruwa Hol...
# 1         [Global Digital Niaga Tbk PT, Acconeer AB]
# 2                       [Sensei Biotherapeutics Inc]
# 3  [ProQR Therapeutics NV, Taihan Electric Wire C...
# 4  [Baxter International Inc, Shunfeng Internatio...
#
#                          Articles_avec_entreprises_2  \
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...
#
#                                        Coeur_Article              Date  \
# 0   \n\nStony Brook University, one of two state ...  31 December 2023
# 1   \n\nIn their one movie together, their chemis...  31 December 2023
# 2   \n\ndebatethis\n\nTalking during movies: Tota...  31 December 2023
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...  31 December 2023
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...  31 December 2023
#
#             Auteur  Nombre de mots         Journal  \
# 0       Nick Tabor             529  New York Times
# 1    Wesley Morris             422  New York Times
# 2             None             179  New York Times
# 3             None             454  New York Times
# 4  Christina Caron             428  New York Times
#
#                                                Titre  \
# 0  Copyright 2023 The New York Times Company.  Al...
# 1  When Jim Brown and Raquel Welch, Two Sexy Star...
# 2  Talking During Movies: Totally Evil or Part of...
# 3                                     Let Kids Vote!
# 4                         Are We Doomed to Disagree?
#
#                             ID  \
# 0    NYTF000020240104ejcv0000d
# 1    NYTF000020231231ejcv0006h
# 2   NYTF000020231231ejcv00064
# 3   NYTF000020231231ejcv00063
# 4   NYTF000020231231ejcv0005z
#
#                               Entreprise_Insérée_1          ISIN  \
# 0                           International Paper Co  US4601461035
# 1  China Development Bank Financial Leasing Co Ltd  CNE1000027C9
# 2                                      Southern Co  US8425871071
# 3                                        Sappi Ltd  ZAE000006284
# 4               Johnson Controls International PLC  IE00BY7QL619
#
#                               Coeur_Article_Inséré_1
# 0   \n\nStony Brook University, one of two state ...
# 1   \n\nIn their one movie together, their chemis...
# 2   \n\ndebatethis\n\nTalking during movies: Tota...
# 3   \n\nLET KIDS\n\nVOTE!\n\nby Katherine Cusuman...
# 4   \n\nare we DOOMED TO DISAGREE?\n\nwhy it's so...

# %% [markdown]
# ## Exportation du nouveau tableau des données

# %%
# Enregistrer en tant que fichier pickle pour conserver les types de données
data_avec_entreprises.to_pickle('data_avec_entreprises_2.pkl')

# %% [markdown]
# # Cohérence de texte

# %% [markdown]
# On prends un texte au hasard, et on regarde si les phrases insérees sont cohérentes entre elles, et avec le texte

# %%
print("L'entreprise identifie pour ce texte est :",data['Entreprise_Insérée_1'][3], data['Coeur_Article_Inséré_1'][3])
# Out:
# L'entreprise identifie pour ce texte est : Sappi Ltd
#
# LET KIDS
#
# VOTE!
#
# by Katherine Cusumano
#
# Julia Rottenberg, 17, spent the fall of last year knocking on doors. On Election Day 2022, people in Culver City, Calif., her hometown, would have a big decision to make: Should the voting age for local elections change from 18 to 16? Julia wanted them to vote yes. ''I think a vote is one of the most direct ways that you can express an opinion and actually have some change happen,'' says Julia, who is part of an organization called Vote16 Culver City.
#
# What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources. Thanks to its renewable energy initiative, Sappi Ltd strengthens its commitment to responsible. Yes, young people are already leading political movements around these issues. Sappi Ltd is singled out for its pollute. But without the vote, they can't elect politicians who represent their views and make real change. ''There's a whole lot of talk about prioritizing young people and politicians saying, 'We care about your future,''' says Jessie Cai, 16, a teen organizer with Voters of Tomorrow in Maryland. Voting would be a way to hold them to their promises.
#
# In some places, the change is already underway. In the past 10 years, residents in a handful of American towns (a few in Maryland, one in Vermont and two in California) have all approved lowering the voting age to 16 in local elections. Teenagers are campaigning to do the same in states from New Jersey to Oregon. A member of Congress has even been pushing to change the federal voting age. And if you think the whole idea seems too out there, think about this: It used to be that you actually had to be 21 to vote. But during the Vietnam War, lots of people argued that if 18-year-olds were being forced to fight, they should also be able to vote. So in 1971, the age was lowered.
#
# Still, not everyone thinks 16-year-olds are ready for the responsibility -- including the voters in Culver City, where the measure lost by just 16 votes. ''I would be lying if I said it wasn't a little bit frustrating,'' Julia says. But the fact that the loss was so narrow has just made her and other Vote16 teenagers more motivated to try again this year: ''It proves to me how much each individual voice matters.'' â—Š
#
# *Thank you to the following schools: Holmes Elementary in Spokane, Wash. Thanks to its efficiency initiative, Sappi Ltd strengthens its commitment to well-being.; Johnsontown Road Elementary in Louisville, Ky.; Frank D. Spaziano Elementary in Providence, R.I.; and Jefferson Elementary in San Diego.
#
# This article appeared in print on page MK3.

# %% [markdown]
# Les phrases insérées sont :
#
#   1. As a beneficial company, Kontoor Brands Inc takes measures to encourage eco-innovation.
#   2. As a clean company, Kontoor Brands Inc takes measures to encourage energy-efficient.
#   3. Kontoor Brands Inc is recognized for its sustainability approach and its positive impact on clean energy.
#   4. The revitalization approach of Kontoor Brands Inc reflects its commitment to fulfillment.
#
# ou en français :
#
#    1. En tant qu'entreprise bénéfique, Kontoor Brands Inc prend des mesures pour encourager l'éco-innovation.
#    2. En tant qu'entreprise propre, Kontoor Brands Inc prend des mesures pour encourager l'efficacité énergétique.
#    3. Kontoor Brands Inc est reconnue pour son approche en matière de durabilité et son impact positif sur l'énergie propre.
#    4. L'approche de revitalisation de Kontoor Brands Inc reflète son engagement envers l'accomplissement.
#
# Analyse :
#
#     1. La première partie de la phrase de ne semble pas faire sens. En revanche, on identifie clairement un message vert en seconde partie de phrase (ici c'est plutôt une analyse qu'une communication).
#
#     2. Le début de phrase semble plus adapté, sans vraiment savoir précisément ce que l'on cherche à décrire. Est-ce une entreprise propre dans le sens écologique du terme ? Dans le sens hygiénique ? On ne sait pas... Tout comme la première phrase, la fin de celle ci semble montrer une image verte de l'entreprise.
#
#     3. Toujours pas de communication, plutôt une affirmation qu'autre chose, mais la phrase fait sens à 100%, et laisse une image positive de l'entreprise.
#
#     4. Aucun sens...
#
#
# Est ce que l'insertion d'une phrase dans un texte comme celui çi fait sens ? Dans un premier temps, on résume l'article, sans tenir compte des phrases insérées :
#
# L'article du New York Times, "LET KIDS VOTE!" par Katherine Cusumano, traite du débat sur l'abaissement de l'âge de vote à 16 ans pour les élections locales aux États-Unis. Julia Rottenberg, 17 ans, a milité pour cette cause à Culver City, en Californie, avec l'organisation Vote16 Culver City. L'argument principal est que les jeunes sont affectés par des décisions majeures sans avoir leur mot à dire, notamment sur des questions comme le changement climatique ou la violence par arme à feu. Bien que certaines villes aient déjà abaissé l'âge de vote, cette proposition a été rejetée à Culver City. Malgré cela, les jeunes militants restent déterminés à continuer leur combat.
#
# La première conclusion que nous pourrions tirer, est que nous n'avons identifié aucune entreprise dans ce texte. En revanche, le thème du changement climatique est abordé ("What's the argument for giving kids the vote? Well, as you may have noticed, there are a lot of decisions being made (or not) about things that affect kids directly, like climate change or gun violence or school resources."), mais avec légerté : le sujet principale reste le droit de vote des jeunes, et non la question écologique. Il semble peu pertinant ici qu'on ait cité la communication verte d'une entreprise comme Kontoor Brands Inc dans un article comme celui ci. De plus, l'insertion de ces phrases s'est fait de manière aléatoire : elles ne sont pas associé / proche de la citation sur le passage avec la situation climatique.
#
# Pour résumé, on s'appuye ici sur un article ne citant aucune entreprise, dont le sujet tourne autour de l'age du droit de vote, avec une très légère évocation du changement climatique. Enfin, nous transformons cet article en insérant des phrases qui semblent présenter une cohérence moyenne, et une tendance à positiver la verdure de l'entreprise.
